# %%
# %autosave 0
# Out:
# Autosave disabled

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import pandas as pd
import numpy as np
import re
import collections
import pickle
from ast import literal_eval
import random
import scipy
import math
# from concorde_class import Concorde
import datetime
import subprocess

# %% [markdown]
# #Define Path of Files

# %%
# Out:
# Mounted at /content/drive

# %%
# path for the 'Data' folder provided by DP
# global vars

dir_loc = '/content/drive/Shareddrives/Private Unlimited Drive #1/DDS/Analytics Project/AOP_DP_Analytics/Data'

path = '/content/drive/Shareddrives/Private Unlimited Drive #1/DDS/Analytics Project/AOP_DP_Analytics/'

# %% [markdown]
# #Functions

# %%
# generate workflow for file storage /  instance creation

# %%
# create dataframes for a region everyday

def generate_region_volume(region_name):
  # path of folder
  dir_region_instances = dir_loc + '/Instances/' + region_name
  dir_region_volume = dir_loc + '/Volumes/'
  # dir_region_districts = dir_region_instances + '/Districts'

  # load post_object-to-route_pos_id and post_point-to-post_object files 
  po_file = pd.read_csv(dir_region_instances + '/post_order_id_mapping.dat', sep='\t', names=('PostObjectId', 'RoutePosID'))
  pp_file = pd.read_csv(dir_region_instances + '/post_point_information.dat', sep='\t', names=('PostPointId', 'PostObjectId'))

  # pp_file adjustment by splitting list of post object ids
  pp_file['PostObjectId'] = pp_file['PostObjectId'].apply(literal_eval)
  pp_file = pp_file.explode('PostObjectId', ignore_index=True)

  # complete  post object list-district mapping
  region_district_df = generate_region_district(region_name = region_name)
  region_district_df.rename(columns = {'PostObjectID' : 'PostObjectId'}, inplace = True)

  # list of volume file paths
  day_names = []
  vol_path_list = []
  vol_day_map = {}
  day_map = {'mo' : 'Monday',
             'di' : 'Tuesday',
             'mi' : 'Wednesday',
             'do' : 'Thursday',
             'fr' : 'Friday',
             'sa' : 'Saturday'}

  for filename in os.listdir(dir_region_volume):
    vol_path_list.append(dir_region_volume + filename)
    day = filename[-6:-4]
    vol_day_map[filename] = day_map[day]

  # store dataframes of a region, map with post object id
  region_vol_day_dict = {}
  for vol_path in vol_path_list:
    vol_df = pd.read_csv(vol_path, sep = ';')
    vol_df.rename(columns = {'BRIEFE' : 'LETTERS',
                             'PAKETE' : 'PACKAGES',
                             'SONSTIGE' : 'OTHERS',
                             'ROUTEPOS_ID' : 'RoutePosID'},
                  inplace = True)
    
    # combining files to a complete table for a region
    vol_po_df = pd.merge(po_file, vol_df, on = 'RoutePosID', how = 'left')
    vol_po_df = pd.merge(pp_file, vol_po_df, on='PostObjectId', how='right')
    vol_po_df = pd.merge(region_district_df, vol_po_df, on='PostObjectId', how='right')

    # store dataframes in dict
    day_key = vol_day_map[vol_path[-18:]]
    region_vol_day_dict[day_key] = vol_po_df
    
  return region_vol_day_dict

# %%
def generate_region_district(region_name):
  district_path = dir_region_instances = dir_loc + '/Instances/' + region_name + '/Districts'
  region_districts_list = []

  for filename in os.listdir(district_path):
    file_var = re.sub('.dat', '', filename)
    file_district = pd.read_csv(district_path + '/' + filename, sep='\t', skiprows = [0,1],
                                names=('PostObjectID', 'dum_1', 'dum_2', 'dum_3', 'dum_4', 'dum_5')
                                # usecols = [0]
                                )
    file_district['district'] = file_var
    region_districts_list.append(file_district)

  region_districts_df = pd.concat(region_districts_list, ignore_index = True)
  region_districts_df.drop(['dum_1', 'dum_2', 'dum_3', 'dum_4', 'dum_5'], axis = 1, inplace = True)
  
  return region_districts_df

# %%
# generate instances

def generate_instances(region_vol_day, scenario_type, scenario_method, scenario_number, growth_factor):
  # df = region_vol_day.copy() #.copy() used to avoid recopying on the original dataframe
  df = region_vol_day

  sce_letters = 'scenario_' + str(scenario_number) + '_letter'
  sce_packages = 'scenario_' + str(scenario_number) + '_package'
  sce_others = 'scenario_' + str(scenario_number) + '_others'

  df[sce_letters] = df['LETTERS'].apply(lambda x :scenario_type(pos_delivery = x, method = scenario_method, rate_pct = growth_factor ))
  df[sce_packages] = df['PACKAGES'].apply(lambda x :scenario_type(pos_delivery = x, method = scenario_method, rate_pct = growth_factor))
  df[sce_others] = df['OTHERS'].apply(lambda x :scenario_type(pos_delivery = x, method = scenario_method, rate_pct = growth_factor))

  sce_all = 'scenario_' + str(scenario_number) + '_all'
  df[sce_all] = df[sce_letters] + df[sce_packages] + df[sce_others]

  return df

# %%
# generate real instances based on poisson

def random_poisson_instances(pos_delivery, method, rate_pct):
  rate = rate_pct/100
  rng = np.random.default_rng()
  poisson_dist = rng.poisson(lam = pos_delivery * (1 + rate), size = 52)

  if method == 'random':
    return random.choice(poisson_dist)
  if method == 'mode':
    return scipy.stats.mode(poisson_dist, keepdims = True)[0][0]
  else:
    return 'only options : [random, mode]'

# %%
# get start and end node for a district
# delete df_day input

def start_end_points(region_name, district):
    # df_day_district = df_day[df_day['district'] == district]

    # get start and end node
    district_path = dir_loc + '/Instances/' + region_name + '/Districts/' + district + '.dat'
    rows_needed = [1]
    file_district = pd.read_csv(district_path, sep='\t', skiprows = lambda x : x not in rows_needed,
                                names=('dum_0', 'start_point', 'end_point', 'dum_1', 'dum_2', 'dum_3', 'dum_4', 'dum_5', 'dum_6')
                                )
    start_point = file_district['start_point'][0]
    end_point = file_district['end_point'][0]

    points = [start_point, end_point]

    return points

# %%
# generate original distance matrix and mapping for districts

def ori_generate_distance_matrix_map(region_name, save_loc):
      i = 1

      dir_region = save_loc + '/' + region_name + '_original'
      print(dir_region)
      if not os.path.exists(dir_region):
        os.mkdir(dir_region)
        print('dir_region doesnt exist')

      # dir_region_ori = dir_region + '/original'
      # print(dir_region_ori)
      # if not os.path.exists(dir_region):
      #   os.mkdir(dir_region)
      #   print('dir_ori doesnt exist')

      ori_dm_map_dict_region = {}
      # get distance file and dataframes
      distance_path = dir_loc + '/Instances/' + region_name + '/distances/'
      for filename in os.listdir(distance_path):
        ori_dm_map_dict_district = {}
        district_name = re.sub('.dat', '', filename)
        district_name = re.sub('distances_', '', district_name)

        district_distance = pd.read_csv(distance_path + filename,
                                    names=['pp_1', 'pp_2', 'dist']
                                    )
      
        distance_matrix_df = district_distance.pivot(index = 'pp_1', columns = 'pp_2', values = 'dist')

        # generate and revise start and end nodes
        points = start_end_points(region_name = region_name, district = district_name)
        distance_matrix_df[points[0]][points[1]] = 0
        distance_matrix_df[points[1]][points[0]] = 0
        ori_dm_map_dict_district['start_end_points'] = points


        # distance matrix
        distance_matrix_array = distance_matrix_df.to_numpy()
        distance_matrix_array = distance_matrix_array.tolist()
        ori_dm_map_dict_district['dm'] = distance_matrix_array
        pickle.dump(distance_matrix_array, open(dir_region + '/dm_' + "%s.p"%district_name, "wb"))

        # node mapping
        map_val = list(range(0, len(distance_matrix_df)))
        nodes = distance_matrix_df.index.values.tolist()
        mapping = dict(zip(map_val, nodes))
        ori_dm_map_dict_district['map'] = mapping
        pickle.dump(mapping, open(dir_region + '/map_' + "%s_%s.p"%(region_name, district_name), "wb"))

        ori_dm_map_dict_region[district_name] = ori_dm_map_dict_district
        print(i, ':', district_name, ':', len(distance_matrix_array))
        i = i+1

      return ori_dm_map_dict_region

# %%
# generate distance matrix and mapping for a scenario

def generate_distance_matrix_map(region_name, df_day_district, points, sce_col, district):
      scenario = sce_col

      col_use = ['PostPointId']
      col_use.append(scenario)
      df_day_district_scenario = df_day_district[col_use]
      
      # removing nodes with zero demand
      df_day_district_scenario_filtered = df_day_district_scenario[df_day_district_scenario[scenario] != 0]
      pp_id_day_district_scenario = df_day_district_scenario_filtered['PostPointId'].unique().tolist()
      
      # add start and end node if not in node list yet
      for point in points:
        if point not in pp_id_day_district_scenario:
          pp_id_day_district_scenario.append(point)

      # get distance file and dataframes
      distance_path = dir_loc + '/Instances/' + region_name + '/distances'
      district_distance = pd.read_csv(distance_path + '/distances_' + district + '.dat',
                                  names=['pp_1', 'pp_2', 'dist']
                                  )
      # remove unused postpoints
      district_distance_filtered = district_distance[(district_distance['pp_1'].isin(pp_id_day_district_scenario)) & (district_distance['pp_2'].isin(pp_id_day_district_scenario))]
      distance_matrix_df = district_distance_filtered.pivot(index = 'pp_1', columns = 'pp_2', values = 'dist')

      # generate and revise start and end nodes
      points = start_end_points(region_name = region_name, district = district)
      distance_matrix_df[points[0]][points[1]] = 0
      distance_matrix_df[points[1]][points[0]] = 0

      # distance matrix
      distance_matrix_array = distance_matrix_df.to_numpy()
      distance_matrix_array = distance_matrix_array.tolist()

      # node mapping
      map_val = list(range(0, len(distance_matrix_df)))
      nodes = distance_matrix_df.index.values.tolist()
      mapping = dict(zip(map_val, nodes))

      return distance_matrix_array, mapping

# %%
def create_dm_map(region, data, save_loc, rate):
  i = 1
  dir_region = save_loc + '/' + region
  if not os.path.exists(dir_region):
    os.mkdir(dir_region)


  # filter by day
  result_day = {}
  for day in data.keys():
    df_day = data[day]

    # filter by district
    result_district = {}
    for district in df_day['district'].value_counts().index.tolist():
      df_day_district = df_day[df_day['district'] == district]

      scenario_list = df_day_district.columns.tolist()[7:]

      # get start and end node
      points = start_end_points(region_name = region, district = district)
      
      # filter by scenario
      result_mail_demand = {}
      for scenario in scenario_list:
        # get volume
        scenario_volume = df_day_district[scenario].sum()

        # dir of mail
        mail_names = ['letter', 'package', 'others', 'all']
        for mail in mail_names:
          if mail in scenario:
            mail_current = mail

        # dir of demand
        demand_types = ['low', 'medium', 'high']
        for demand in demand_types:
          if demand in scenario:
            demand_current = demand

        # generate mapping and distance matrix
        distance_matrix, mapping = generate_distance_matrix_map(region_name = region, df_day_district = df_day_district,
                                                                points = points, sce_col = scenario, district = district)
        distance_matrix_name = 'dm_' + region + '_' + day + '_' + district + '_' + scenario + '_' + str(rate)
        mapping_name = 'map_' + region + '_' + day + '_' + district + '_' + scenario + '_' + str(rate)
        pickle.dump(distance_matrix, open(dir_region + '/' + "%s.p"%distance_matrix_name, "wb"))
        pickle.dump(mapping, open(dir_region + '/' + "%s.p"%mapping_name, "wb"))

        # log update
        # print(i, ':', distance_matrix_name, ':', distance_matrix.shape)
        print(i, ':', distance_matrix_name, ':', len(distance_matrix))
        i = i+1

        result_end = {}
        result_end['dm'] = distance_matrix
        result_end['map'] = mapping
        result_end['start_end_points'] = points
        result_end['volume'] = scenario_volume
        
        mail_demand = mail_current + '_' + demand_current
        result_mail_demand[mail_demand] = result_end
      result_district[district] = result_mail_demand
    result_day[day] = result_district

  return result_day

# %%
def get_default_route(region, district_name):
    
    #Get directory path of district's assigned PostObjects
    district_po_path = os.path.join(path, 'Data', 'Instances', region, 'Districts', district_name + '.dat')

    #Get directory path of PostPoint-PostObject mapping for the region that district belongs to
    district_pp_po_mapping_path = os.path.join(path, 'Data', 'Instances', region, 'post_point_information' + '.dat')

    #Get directory path of distances between Post Points file fo the district
    district_pp_distances_path = os.path.join(path, 'Data', 'Instances', region, 'distances', 'distances_' + district_name + '.dat')

    #Generate the dataframe for the PostPoint distance combinations
    df_pp_district_distances = pd.read_csv(district_pp_distances_path, sep = ',', header = None, names = ['PostPoint1', 'PostPoint2','Distance'])


    #Generate the needed PostObjects dataframe in their assigned sequence. Also get start and end PostPoints as list
    df_district_po = pd.read_csv(district_po_path, sep = '\t', skiprows= 2, usecols=[0], header = None, names = ['PostObjectId'])

    df_start_end_pp = pd.read_csv(district_po_path, sep = '\t', skiprows= 1, nrows=1, usecols=[1,2], header = None, names = ['StartPostPoint','EndPostPoint'])


    #Get the needed PostPoint-PostObject dataframe for merging
    df_district_pp_po_mapping = pd.read_csv(district_pp_po_mapping_path, sep='\t', names=('PostPointId', 'PostObjectId'))
    df_district_pp_po_mapping['PostObjectId'] = df_district_pp_po_mapping['PostObjectId'].apply(literal_eval)
    df_district_pp_po_mapping = df_district_pp_po_mapping.explode('PostObjectId', ignore_index=True)

    #Create a dataframe of the PostPoint in Order Sequence by merging and preprocessing previous dataframes
    df_district_pp_sequence = merged_data = pd.merge(df_district_po, df_district_pp_po_mapping , on='PostObjectId', how = 'left').drop('PostObjectId', axis=1)

    #Save the value of the amount of PostObject ID Visited
    PO_touching_rate = len(df_district_pp_sequence)
    
    #get the values from start and end PostPoint separately
    start_point = df_start_end_pp.iloc[0,0]
    end_point = df_start_end_pp.iloc[0,1]

    #FUNCTION to Add start and end point on their respective initial and end position on the PostPoint dataframe. Check first if they exist on those positions.
    def add_start_end_point(point_1, point_2, df):
        #for start point
        if df.loc[0,'PostPointId'] == point_1:
            pass
        else: 
           new_row_start = pd.DataFrame([point_1], columns=df.columns)
           df = pd.concat([new_row_start, df], ignore_index=True) 
        #for end point
        if df.loc[len(df)-1,'PostPointId'] == point_2:
            pass
        else: 
            new_row_end = pd.DataFrame([point_2], columns=df.columns)
            df = pd.concat([df, new_row_end], ignore_index=True) 
        return df

    df_district_pp_sequence = add_start_end_point(point_1 = start_point, point_2= end_point, df = df_district_pp_sequence)

    
    #FUNCTION to delete all "consecutive" PostPointId numbers from the list and keep sequence
    #(PostObjectID on the same building being visited consecutively means just one visit to that PostPointID is needed on that trip)

    def delete_consecutive_duplicates(df, column_name):
        #Identify consecutive duplicates by calculating the difference
        differences = df[column_name].diff()

        # Keep the rows where the difference is non-zero
        df = df.loc[differences != 0]
        df = df.reset_index(drop=True)
        
        return df

    df_district_pp_sequence_filtered = delete_consecutive_duplicates(df = df_district_pp_sequence, column_name= 'PostPointId')

    #Save the value of the amount of PostPoint Trips
    PP_visit_rate = len(df_district_pp_sequence)

    #FUNTION to count number of duplicate PostPoints which are not consecutive
    #(if value > 1, PostPoints are visited and then returned in a non consecutive manner on current routing)
    #[Case is 1 if it is a tour when start and end point is the same, Case is 0 if is not a tour])

    def count_repeated_pp(df):
        df2 = df.groupby(['PostPointId'])['PostPointId'].count().to_frame()
        repeated = len(df2[df2['PostPointId']>1])
        return repeated

    repeated_pp_num = count_repeated_pp(df_district_pp_sequence_filtered)
    
    
    #Convert the default sequence to list
    district_pp_sequence_filtered = df_district_pp_sequence_filtered['PostPointId'].values.tolist()
    
    #FUNCTION to calculate total tour length
    def get_tour_length(sequence_list, distance_df):
        tour_length = 0 
        for i in range(len(sequence_list)-1):
            # Specify the specific values for column 1 and column 2
            value_column1 = sequence_list[i]
            value_column2 = sequence_list[i+1]

            # Filter the dataframe based on the specified values
            match_df = distance_df.loc[(distance_df['PostPoint1'] == value_column1) & (distance_df['PostPoint2'] == value_column2)]

            # Retrieve the value in distance column or give error if does not exist
            distance_pp = match_df['Distance'].values[0] if not match_df.empty else 'ERROR: No distance for PostPoint combination'
            tour_length += distance_pp
            
        return round(tour_length,2)

    district_tour_length = get_tour_length(district_pp_sequence_filtered, df_pp_district_distances)

    #Create a dictionary as a mapping of PostPoint to Index Position in list (In case is needed or can be useful)
    mapping_district = dict(zip([i for i in range(len(district_pp_sequence_filtered))] ,district_pp_sequence_filtered))
    
    
    return  district_pp_sequence_filtered, mapping_district, district_tour_length, repeated_pp_num

# %%
#FUNCTION to get the list of all districts on a specific region by looping existing entries in the folder
def get_district_list(region):
    districts_list = []
    districts_name_path = os.path.join(path, 'Data', 'Instances', region, 'Districts')
    for filename in os.listdir(districts_name_path):
        districts_list.append(filename[:-4])
    return districts_list

# %%
#FUNCTION to generate all default route information for an entire region
def get_region_all_default_routes(region_chosen, path_save):

  dir_region = os.path.join(path_save, region_chosen + '_Default_Routes')
  # print(dir_region)
  if not os.path.exists(dir_region):
    os.mkdir(dir_region)

  district_list = get_district_list(region = region_chosen)

  default_route_regions = {}

  for district in district_list:
    district_route_info = {}
    route_list, district_mapping, total_length, repetitions = get_default_route(region = region_chosen, district_name = district)
    #save default route sequence list as pickle file
    pickle.dump(route_list, open(os.path.join(dir_region, district + '_default_route.p'), 'wb'))
    district_route_info['default_route'] = route_list
    district_route_info['mapping'] = district_mapping
    district_route_info['route_cost'] = total_length
    default_route_regions[district] = district_route_info
      
    #save data regarding total length of tour, repeating nodes, and mapping info on .txt file
    file = open(os.path.join(dir_region, district + 'default_route_info.txt'),'w')
    file.write('Total tour length in seconds: \n{}\n'.format(total_length))
    file.write('Total tour length in hours: \n{}\n'.format(round(total_length/3600,1)))
    file.write('Number of PostPoint visited more than once: \n{}\n'.format(repetitions))
    file.write('Mapping: \n{}\n'.format(district_mapping))

    file.close()
  return default_route_regions

# %% [markdown]
# #Generate Instances : Warmsen

# %%
# %%time

# region_list = ['Warmsen', 'Uerze', 'Hannover 92']

# all_regions = {}

# for region in region_list:
region_vol_day_dict = generate_region_volume(region_name = "Warmsen")
  # all_regions[region] = region_vol_day_dict
# Out:
# CPU times: user 12.3 s, sys: 1.58 s, total: 13.9 s
# Wall time: 32.8 s

# %%
region_vol_day_dict['Monday'].head()

# all_regions['Warmsen']['Monday'].head()
# Out:
#   PostObjectId  district  PostPointId                        RoutePosID  \
# 0           16  31606-14           16  AD14E08623FF9F5AD2293E7DEDB4F4B1
# 1           17  31606-14           17  F48CB0CAB0BC117AE030007F0100574C
# 2           18  31606-14           16  F48CB0CAB0C7117AE030007F0100574C
# 3           19  31606-14           18  F48CB0CAB0C8117AE030007F0100574C
# 4           20  31606-14           19  069AE286923C1800E040400A09131416
#
#    LETTERS  PACKAGES  OTHERS
# 0     0.45  0.293333     0.0
# 1     0.45  0.293333     0.0
# 2     0.45  0.293333     0.0
# 3     0.00  0.000000     0.0
# 4     0.00  0.000000     0.0

# %%
# for key_region in all_regions['Warmsen'].keys():
#   print(key_region)

# %%
# %%time
#Creating the complete dictionary of volumes for a region
warmsen_instances = {}

#INPUT Rate of mail change 
# rate in percentage
rate = 50
rate_mapping = {'low' : -rate, 'medium' : 0, 'high' : rate}

# create instances for one region
for key in region_vol_day_dict.keys():
  # create instances per day
  for key_rate in rate_mapping:
    dummy = generate_instances(region_vol_day = region_vol_day_dict[key],
                               scenario_type = random_poisson_instances,
                               scenario_method = 'random',
                               scenario_number = key_rate,
                               growth_factor = rate_mapping[key_rate])
  warmsen_instances[key] = dummy
# Out:
# CPU times: user 15.2 s, sys: 207 ms, total: 15.4 s
# Wall time: 15.6 s

# %%
warmsen_instances['Tuesday'].head()
# Out:
#   PostObjectId  district  PostPointId                        RoutePosID  \
# 0           16  31606-14           16  AD14E08623FF9F5AD2293E7DEDB4F4B1
# 1           17  31606-14           17  F48CB0CAB0BC117AE030007F0100574C
# 2           18  31606-14           16  F48CB0CAB0C7117AE030007F0100574C
# 3           19  31606-14           18  F48CB0CAB0C8117AE030007F0100574C
# 4           20  31606-14           19  069AE286923C1800E040400A09131416
#
#     LETTERS  PACKAGES    OTHERS  scenario_low_letter  scenario_low_package  \
# 0  5.796667      0.69  0.273333                    1                     1
# 1  5.796667      0.69  0.273333                    1                     0
# 2  5.796667      0.69  0.273333                    2                     0
# 3  0.000000      0.00  0.000000                    0                     0
# 4  0.000000      0.00  0.000000                    0                     0
#
#    scenario_low_others  scenario_low_all  scenario_medium_letter  \
# 0                    0                 2                      10
# 1                    0                 1                       4
# 2                    0                 2                       7
# 3                    0                 0                       0
# 4                    0                 0                       0
#
#    scenario_medium_package  scenario_medium_others  scenario_medium_all  \
# 0                        0                       0                   10
# 1                        0                       0                    4
# 2                        0                       1                    8
# 3                        0                       0                    0
# 4                        0                       0                    0
#
#    scenario_high_letter  scenario_high_package  scenario_high_others  \
# 0                     5                      1                     0
# 1                    13                      0                     0
# 2                     6                      1                     0
# 3                     0                      0                     0
# 4                     0                      0                     0
#
#    scenario_high_all
# 0                  6
# 1                 13
# 2                  7
# 3                  0
# 4                  0

# %%
print(warmsen_instances['Tuesday']['scenario_low_all'].sum())
print(warmsen_instances['Tuesday']['scenario_medium_all'].sum())
print(warmsen_instances['Tuesday']['scenario_high_all'].sum())

# print(all_instances['Uerze']['Monday']['scenario_low_all'].sum())
# print(all_instances['Uerze']['Monday']['scenario_medium_all'].sum())
# print(all_instances['Uerze']['Monday']['scenario_high_all'].sum())
# Out:
# 4556
# 9150
# 13880

# %%
z = warmsen_instances['Tuesday']


print(z[z['district'] == '31606-14']['scenario_low_all'].sum())
print(z[z['district'] == '31606-14']['scenario_medium_all'].sum())
print(z[z['district'] == '31606-14']['scenario_high_all'].sum())

# z = all_regions['Uerze']['Monday']


# print(z[z['district'] == '31311-01']['scenario_low_all'].sum())
# print(z[z['district'] == '31311-01']['scenario_medium_all'].sum())
# print(z[z['district'] == '31311-01']['scenario_high_all'].sum())
# Out:
# 263
# 529
# 845

# %%
# %%time

# growth_rate_map_50 = {'high' : 'inc_50', 'low' : 'dec_50', 'medium' : 'base'}

result_region = create_dm_map(region = 'Warmsen', data = warmsen_instances,
                              save_loc = '/content/drive/Shareddrives/Private Unlimited Drive #1/DDS/Analytics Project/Coding/',
                              rate = rate)
# Out:
# 1 : dm_Warmsen_Tuesday_31603-06_scenario_low_letter_50 : 161
# 2 : dm_Warmsen_Tuesday_31603-06_scenario_low_package_50 : 32
# 3 : dm_Warmsen_Tuesday_31603-06_scenario_low_others_50 : 123
# 4 : dm_Warmsen_Tuesday_31603-06_scenario_low_all_50 : 248
# 5 : dm_Warmsen_Tuesday_31603-06_scenario_medium_letter_50 : 241
# 6 : dm_Warmsen_Tuesday_31603-06_scenario_medium_package_50 : 65
# 7 : dm_Warmsen_Tuesday_31603-06_scenario_medium_others_50 : 189
# 8 : dm_Warmsen_Tuesday_31603-06_scenario_medium_all_50 : 328
# 9 : dm_Warmsen_Tuesday_31603-06_scenario_high_letter_50 : 315
# 10 : dm_Warmsen_Tuesday_31603-06_scenario_high_package_50 : 97
# 11 : dm_Warmsen_Tuesday_31603-06_scenario_high_others_50 : 236
# 12 : dm_Warmsen_Tuesday_31603-06_scenario_high_all_50 : 379
# 13 : dm_Warmsen_Tuesday_31600-01_scenario_low_letter_50 : 144
# 14 : dm_Warmsen_Tuesday_31600-01_scenario_low_package_50 : 38
# 15 : dm_Warmsen_Tuesday_31600-01_scenario_low_others_50 : 60
# 16 : dm_Warmsen_Tuesday_31600-01_scenario_low_all_50 : 193
# 17 : dm_Warmsen_Tuesday_31600-01_scenario_medium_letter_50 : 226
# 18 : dm_Warmsen_Tuesday_31600-01_scenario_medium_package_50 : 64
# 19 : dm_Warmsen_Tuesday_31600-01_scenario_medium_others_50 : 127
# 20 : dm_Warmsen_Tuesday_31600-01_scenario_medium_all_50 : 281
# 21 : dm_Warmsen_Tuesday_31600-01_scenario_high_letter_50 : 274
# 22 : dm_Warmsen_Tuesday_31600-01_scenario_high_package_50 : 71
# 23 : dm_Warmsen_Tuesday_31600-01_scenario_high_others_50 : 160
# 24 : dm_Warmsen_Tuesday_31600-01_scenario_high_all_50 : 318
# 25 : dm_Warmsen_Tuesday_31606-12_scenario_low_letter_50 : 164
# 26 : dm_Warmsen_Tuesday_31606-12_scenario_low_package_50 : 40
# 27 : dm_Warmsen_Tuesday_31606-12_scenario_low_others_50 : 93
# 28 : dm_Warmsen_Tuesday_31606-12_scenario_low_all_50 : 222
# 29 : dm_Warmsen_Tuesday_31606-12_scenario_medium_letter_50 : 237
# 30 : dm_Warmsen_Tuesday_31606-12_scenario_medium_package_50 : 69
# 31 : dm_Warmsen_Tuesday_31606-12_scenario_medium_others_50 : 120
# 32 : dm_Warmsen_Tuesday_31606-12_scenario_medium_all_50 : 300
# 33 : dm_Warmsen_Tuesday_31606-12_scenario_high_letter_50 : 287
# 34 : dm_Warmsen_Tuesday_31606-12_scenario_high_package_50 : 95
# 35 : dm_Warmsen_Tuesday_31606-12_scenario_high_others_50 : 192
# 36 : dm_Warmsen_Tuesday_31606-12_scenario_high_all_50 : 350
# 37 : dm_Warmsen_Tuesday_31600-02_scenario_low_letter_50 : 130
# 38 : dm_Warmsen_Tuesday_31600-02_scenario_low_package_50 : 40
# 39 : dm_Warmsen_Tuesday_31600-02_scenario_low_others_50 : 92
# 40 : dm_Warmsen_Tuesday_31600-02_scenario_low_all_50 : 206
# 41 : dm_Warmsen_Tuesday_31600-02_scenario_medium_letter_50 : 200
# 42 : dm_Warmsen_Tuesday_31600-02_scenario_medium_package_50 : 67
# 43 : dm_Warmsen_Tuesday_31600-02_scenario_medium_others_50 : 157
# 44 : dm_Warmsen_Tuesday_31600-02_scenario_medium_all_50 : 282
# 45 : dm_Warmsen_Tuesday_31600-02_scenario_high_letter_50 : 259
# 46 : dm_Warmsen_Tuesday_31600-02_scenario_high_package_50 : 90
# 47 : dm_Warmsen_Tuesday_31600-02_scenario_high_others_50 : 199
# 48 : dm_Warmsen_Tuesday_31600-02_scenario_high_all_50 : 330
# 49 : dm_Warmsen_Tuesday_31604-09_scenario_low_letter_50 : 152
# 50 : dm_Warmsen_Tuesday_31604-09_scenario_low_package_50 : 52
# 51 : dm_Warmsen_Tuesday_31604-09_scenario_low_others_50 : 77
# 52 : dm_Warmsen_Tuesday_31604-09_scenario_low_all_50 : 222
# 53 : dm_Warmsen_Tuesday_31604-09_scenario_medium_letter_50 : 220
# 54 : dm_Warmsen_Tuesday_31604-09_scenario_medium_package_50 : 72
# 55 : dm_Warmsen_Tuesday_31604-09_scenario_medium_others_50 : 126
# 56 : dm_Warmsen_Tuesday_31604-09_scenario_medium_all_50 : 289
# 57 : dm_Warmsen_Tuesday_31604-09_scenario_high_letter_50 : 285
# 58 : dm_Warmsen_Tuesday_31604-09_scenario_high_package_50 : 121
# 59 : dm_Warmsen_Tuesday_31604-09_scenario_high_others_50 : 187
# 60 : dm_Warmsen_Tuesday_31604-09_scenario_high_all_50 : 344
# 61 : dm_Warmsen_Tuesday_31603-07_scenario_low_letter_50 : 155
# 62 : dm_Warmsen_Tuesday_31603-07_scenario_low_package_50 : 43
# 63 : dm_Warmsen_Tuesday_31603-07_scenario_low_others_50 : 88
# 64 : dm_Warmsen_Tuesday_31603-07_scenario_low_all_50 : 229
# 65 : dm_Warmsen_Tuesday_31603-07_scenario_medium_letter_50 : 259
# 66 : dm_Warmsen_Tuesday_31603-07_scenario_medium_package_50 : 71
# 67 : dm_Warmsen_Tuesday_31603-07_scenario_medium_others_50 : 180
# 68 : dm_Warmsen_Tuesday_31603-07_scenario_medium_all_50 : 333
# 69 : dm_Warmsen_Tuesday_31603-07_scenario_high_letter_50 : 309
# 70 : dm_Warmsen_Tuesday_31603-07_scenario_high_package_50 : 91
# 71 : dm_Warmsen_Tuesday_31603-07_scenario_high_others_50 : 221
# 72 : dm_Warmsen_Tuesday_31603-07_scenario_high_all_50 : 359
# 73 : dm_Warmsen_Tuesday_31604-10_scenario_low_letter_50 : 139
# 74 : dm_Warmsen_Tuesday_31604-10_scenario_low_package_50 : 34
# 75 : dm_Warmsen_Tuesday_31604-10_scenario_low_others_50 : 77
# 76 : dm_Warmsen_Tuesday_31604-10_scenario_low_all_50 : 199
# 77 : dm_Warmsen_Tuesday_31604-10_scenario_medium_letter_50 : 235
# 78 : dm_Warmsen_Tuesday_31604-10_scenario_medium_package_50 : 69
# 79 : dm_Warmsen_Tuesday_31604-10_scenario_medium_others_50 : 141
# 80 : dm_Warmsen_Tuesday_31604-10_scenario_medium_all_50 : 290
# 81 : dm_Warmsen_Tuesday_31604-10_scenario_high_letter_50 : 283
# 82 : dm_Warmsen_Tuesday_31604-10_scenario_high_package_50 : 100
# 83 : dm_Warmsen_Tuesday_31604-10_scenario_high_others_50 : 183
# 84 : dm_Warmsen_Tuesday_31604-10_scenario_high_all_50 : 328
# 85 : dm_Warmsen_Tuesday_31600-03_scenario_low_letter_50 : 153
# 86 : dm_Warmsen_Tuesday_31600-03_scenario_low_package_50 : 33
# 87 : dm_Warmsen_Tuesday_31600-03_scenario_low_others_50 : 74
# 88 : dm_Warmsen_Tuesday_31600-03_scenario_low_all_50 : 191
# 89 : dm_Warmsen_Tuesday_31600-03_scenario_medium_letter_50 : 226
# 90 : dm_Warmsen_Tuesday_31600-03_scenario_medium_package_50 : 75
# 91 : dm_Warmsen_Tuesday_31600-03_scenario_medium_others_50 : 137
# 92 : dm_Warmsen_Tuesday_31600-03_scenario_medium_all_50 : 285
# 93 : dm_Warmsen_Tuesday_31600-03_scenario_high_letter_50 : 253
# 94 : dm_Warmsen_Tuesday_31600-03_scenario_high_package_50 : 94
# 95 : dm_Warmsen_Tuesday_31600-03_scenario_high_others_50 : 183
# 96 : dm_Warmsen_Tuesday_31600-03_scenario_high_all_50 : 309
# 97 : dm_Warmsen_Tuesday_31603-05_scenario_low_letter_50 : 169
# 98 : dm_Warmsen_Tuesday_31603-05_scenario_low_package_50 : 29
# 99 : dm_Warmsen_Tuesday_31603-05_scenario_low_others_50 : 98
# 100 : dm_Warmsen_Tuesday_31603-05_scenario_low_all_50 : 227
# 101 : dm_Warmsen_Tuesday_31603-05_scenario_medium_letter_50 : 257
# 102 : dm_Warmsen_Tuesday_31603-05_scenario_medium_package_50 : 66
# 103 : dm_Warmsen_Tuesday_31603-05_scenario_medium_others_50 : 179
# 104 : dm_Warmsen_Tuesday_31603-05_scenario_medium_all_50 : 319
# 105 : dm_Warmsen_Tuesday_31603-05_scenario_high_letter_50 : 275
# 106 : dm_Warmsen_Tuesday_31603-05_scenario_high_package_50 : 94
# 107 : dm_Warmsen_Tuesday_31603-05_scenario_high_others_50 : 231
# 108 : dm_Warmsen_Tuesday_31603-05_scenario_high_all_50 : 334
# 109 : dm_Warmsen_Tuesday_31603-08_scenario_low_letter_50 : 151
# 110 : dm_Warmsen_Tuesday_31603-08_scenario_low_package_50 : 50
# 111 : dm_Warmsen_Tuesday_31603-08_scenario_low_others_50 : 78
# 112 : dm_Warmsen_Tuesday_31603-08_scenario_low_all_50 : 207
# 113 : dm_Warmsen_Tuesday_31603-08_scenario_medium_letter_50 : 228
# 114 : dm_Warmsen_Tuesday_31603-08_scenario_medium_package_50 : 74
# 115 : dm_Warmsen_Tuesday_31603-08_scenario_medium_others_50 : 169
# 116 : dm_Warmsen_Tuesday_31603-08_scenario_medium_all_50 : 288
# 117 : dm_Warmsen_Tuesday_31603-08_scenario_high_letter_50 : 280
# 118 : dm_Warmsen_Tuesday_31603-08_scenario_high_package_50 : 101
# 119 : dm_Warmsen_Tuesday_31603-08_scenario_high_others_50 : 203
# 120 : dm_Warmsen_Tuesday_31603-08_scenario_high_all_50 : 321
# 121 : dm_Warmsen_Tuesday_31606-11_scenario_low_letter_50 : 161
# 122 : dm_Warmsen_Tuesday_31606-11_scenario_low_package_50 : 24
# 123 : dm_Warmsen_Tuesday_31606-11_scenario_low_others_50 : 55
# 124 : dm_Warmsen_Tuesday_31606-11_scenario_low_all_50 : 196
# 125 : dm_Warmsen_Tuesday_31606-11_scenario_medium_letter_50 : 228
# 126 : dm_Warmsen_Tuesday_31606-11_scenario_medium_package_50 : 52
# 127 : dm_Warmsen_Tuesday_31606-11_scenario_medium_others_50 : 115
# 128 : dm_Warmsen_Tuesday_31606-11_scenario_medium_all_50 : 268
# 129 : dm_Warmsen_Tuesday_31606-11_scenario_high_letter_50 : 270
# 130 : dm_Warmsen_Tuesday_31606-11_scenario_high_package_50 : 84
# 131 : dm_Warmsen_Tuesday_31606-11_scenario_high_others_50 : 162
# 132 : dm_Warmsen_Tuesday_31606-11_scenario_high_all_50 : 300
# 133 : dm_Warmsen_Tuesday_31606-14_scenario_low_letter_50 : 108
# 134 : dm_Warmsen_Tuesday_31606-14_scenario_low_package_50 : 39
# 135 : dm_Warmsen_Tuesday_31606-14_scenario_low_others_50 : 60
# 136 : dm_Warmsen_Tuesday_31606-14_scenario_low_all_50 : 159
# 137 : dm_Warmsen_Tuesday_31606-14_scenario_medium_letter_50 : 191
# 138 : dm_Warmsen_Tuesday_31606-14_scenario_medium_package_50 : 56
# 139 : dm_Warmsen_Tuesday_31606-14_scenario_medium_others_50 : 90
# 140 : dm_Warmsen_Tuesday_31606-14_scenario_medium_all_50 : 236
# 141 : dm_Warmsen_Tuesday_31606-14_scenario_high_letter_50 : 232
# 142 : dm_Warmsen_Tuesday_31606-14_scenario_high_package_50 : 88
# 143 : dm_Warmsen_Tuesday_31606-14_scenario_high_others_50 : 131
# 144 : dm_Warmsen_Tuesday_31606-14_scenario_high_all_50 : 257
# 145 : dm_Warmsen_Tuesday_31606-13_scenario_low_letter_50 : 133
# 146 : dm_Warmsen_Tuesday_31606-13_scenario_low_package_50 : 36
# 147 : dm_Warmsen_Tuesday_31606-13_scenario_low_others_50 : 67
# 148 : dm_Warmsen_Tuesday_31606-13_scenario_low_all_50 : 175
# 149 : dm_Warmsen_Tuesday_31606-13_scenario_medium_letter_50 : 180
# 150 : dm_Warmsen_Tuesday_31606-13_scenario_medium_package_50 : 73
# 151 : dm_Warmsen_Tuesday_31606-13_scenario_medium_others_50 : 102
# 152 : dm_Warmsen_Tuesday_31606-13_scenario_medium_all_50 : 236
# 153 : dm_Warmsen_Tuesday_31606-13_scenario_high_letter_50 : 223
# 154 : dm_Warmsen_Tuesday_31606-13_scenario_high_package_50 : 77
# 155 : dm_Warmsen_Tuesday_31606-13_scenario_high_others_50 : 140
# 156 : dm_Warmsen_Tuesday_31606-13_scenario_high_all_50 : 263
# 157 : dm_Warmsen_Tuesday_31600-04_scenario_low_letter_50 : 90
# 158 : dm_Warmsen_Tuesday_31600-04_scenario_low_package_50 : 28
# 159 : dm_Warmsen_Tuesday_31600-04_scenario_low_others_50 : 62
# 160 : dm_Warmsen_Tuesday_31600-04_scenario_low_all_50 : 144
# 161 : dm_Warmsen_Tuesday_31600-04_scenario_medium_letter_50 : 150
# 162 : dm_Warmsen_Tuesday_31600-04_scenario_medium_package_50 : 43
# 163 : dm_Warmsen_Tuesday_31600-04_scenario_medium_others_50 : 104
# 164 : dm_Warmsen_Tuesday_31600-04_scenario_medium_all_50 : 206
# 165 : dm_Warmsen_Tuesday_31600-04_scenario_high_letter_50 : 188
# 166 : dm_Warmsen_Tuesday_31600-04_scenario_high_package_50 : 82
# 167 : dm_Warmsen_Tuesday_31600-04_scenario_high_others_50 : 127
# 168 : dm_Warmsen_Tuesday_31600-04_scenario_high_all_50 : 234
# 169 : dm_Warmsen_Thursday_31603-06_scenario_low_letter_50 : 192
# 170 : dm_Warmsen_Thursday_31603-06_scenario_low_package_50 : 33
# 171 : dm_Warmsen_Thursday_31603-06_scenario_low_others_50 : 92
# 172 : dm_Warmsen_Thursday_31603-06_scenario_low_all_50 : 249
# 173 : dm_Warmsen_Thursday_31603-06_scenario_medium_letter_50 : 275
# 174 : dm_Warmsen_Thursday_31603-06_scenario_medium_package_50 : 64
# 175 : dm_Warmsen_Thursday_31603-06_scenario_medium_others_50 : 140
# 176 : dm_Warmsen_Thursday_31603-06_scenario_medium_all_50 : 326
# 177 : dm_Warmsen_Thursday_31603-06_scenario_high_letter_50 : 349
# 178 : dm_Warmsen_Thursday_31603-06_scenario_high_package_50 : 92
# 179 : dm_Warmsen_Thursday_31603-06_scenario_high_others_50 : 182
# 180 : dm_Warmsen_Thursday_31603-06_scenario_high_all_50 : 381
# 181 : dm_Warmsen_Thursday_31600-01_scenario_low_letter_50 : 181
# 182 : dm_Warmsen_Thursday_31600-01_scenario_low_package_50 : 35
# 183 : dm_Warmsen_Thursday_31600-01_scenario_low_others_50 : 47
# 184 : dm_Warmsen_Thursday_31600-01_scenario_low_all_50 : 221
# 185 : dm_Warmsen_Thursday_31600-01_scenario_medium_letter_50 : 260
# 186 : dm_Warmsen_Thursday_31600-01_scenario_medium_package_50 : 64
# 187 : dm_Warmsen_Thursday_31600-01_scenario_medium_others_50 : 99
# 188 : dm_Warmsen_Thursday_31600-01_scenario_medium_all_50 : 308
# 189 : dm_Warmsen_Thursday_31600-01_scenario_high_letter_50 : 317
# 190 : dm_Warmsen_Thursday_31600-01_scenario_high_package_50 : 92
# 191 : dm_Warmsen_Thursday_31600-01_scenario_high_others_50 : 130
# 192 : dm_Warmsen_Thursday_31600-01_scenario_high_all_50 : 338
# 193 : dm_Warmsen_Thursday_31606-12_scenario_low_letter_50 : 186
# 194 : dm_Warmsen_Thursday_31606-12_scenario_low_package_50 : 40
# 195 : dm_Warmsen_Thursday_31606-12_scenario_low_others_50 : 55
# 196 : dm_Warmsen_Thursday_31606-12_scenario_low_all_50 : 234
# 197 : dm_Warmsen_Thursday_31606-12_scenario_medium_letter_50 : 269
# 198 : dm_Warmsen_Thursday_31606-12_scenario_medium_package_50 : 66
# 199 : dm_Warmsen_Thursday_31606-12_scenario_medium_others_50 : 82
# 200 : dm_Warmsen_Thursday_31606-12_scenario_medium_all_50 : 309
# 201 : dm_Warmsen_Thursday_31606-12_scenario_high_letter_50 : 317
# 202 : dm_Warmsen_Thursday_31606-12_scenario_high_package_50 : 110
# 203 : dm_Warmsen_Thursday_31606-12_scenario_high_others_50 : 126
# 204 : dm_Warmsen_Thursday_31606-12_scenario_high_all_50 : 351
# 205 : dm_Warmsen_Thursday_31600-02_scenario_low_letter_50 : 176
# 206 : dm_Warmsen_Thursday_31600-02_scenario_low_package_50 : 43
# 207 : dm_Warmsen_Thursday_31600-02_scenario_low_others_50 : 67
# 208 : dm_Warmsen_Thursday_31600-02_scenario_low_all_50 : 231
# 209 : dm_Warmsen_Thursday_31600-02_scenario_medium_letter_50 : 235
# 210 : dm_Warmsen_Thursday_31600-02_scenario_medium_package_50 : 71
# 211 : dm_Warmsen_Thursday_31600-02_scenario_medium_others_50 : 110
# 212 : dm_Warmsen_Thursday_31600-02_scenario_medium_all_50 : 303
# 213 : dm_Warmsen_Thursday_31600-02_scenario_high_letter_50 : 296
# 214 : dm_Warmsen_Thursday_31600-02_scenario_high_package_50 : 87
# 215 : dm_Warmsen_Thursday_31600-02_scenario_high_others_50 : 140
# 216 : dm_Warmsen_Thursday_31600-02_scenario_high_all_50 : 339
# 217 : dm_Warmsen_Thursday_31604-09_scenario_low_letter_50 : 176
# 218 : dm_Warmsen_Thursday_31604-09_scenario_low_package_50 : 46
# 219 : dm_Warmsen_Thursday_31604-09_scenario_low_others_50 : 52
# 220 : dm_Warmsen_Thursday_31604-09_scenario_low_all_50 : 219
# 221 : dm_Warmsen_Thursday_31604-09_scenario_medium_letter_50 : 271
# 222 : dm_Warmsen_Thursday_31604-09_scenario_medium_package_50 : 81
# 223 : dm_Warmsen_Thursday_31604-09_scenario_medium_others_50 : 94
# 224 : dm_Warmsen_Thursday_31604-09_scenario_medium_all_50 : 319
# 225 : dm_Warmsen_Thursday_31604-09_scenario_high_letter_50 : 327
# 226 : dm_Warmsen_Thursday_31604-09_scenario_high_package_50 : 107
# 227 : dm_Warmsen_Thursday_31604-09_scenario_high_others_50 : 132
# 228 : dm_Warmsen_Thursday_31604-09_scenario_high_all_50 : 359
# 229 : dm_Warmsen_Thursday_31603-07_scenario_low_letter_50 : 189
# 230 : dm_Warmsen_Thursday_31603-07_scenario_low_package_50 : 38
# 231 : dm_Warmsen_Thursday_31603-07_scenario_low_others_50 : 63
# 232 : dm_Warmsen_Thursday_31603-07_scenario_low_all_50 : 232
# 233 : dm_Warmsen_Thursday_31603-07_scenario_medium_letter_50 : 272
# 234 : dm_Warmsen_Thursday_31603-07_scenario_medium_package_50 : 62
# 235 : dm_Warmsen_Thursday_31603-07_scenario_medium_others_50 : 136
# 236 : dm_Warmsen_Thursday_31603-07_scenario_medium_all_50 : 313
# 237 : dm_Warmsen_Thursday_31603-07_scenario_high_letter_50 : 325
# 238 : dm_Warmsen_Thursday_31603-07_scenario_high_package_50 : 96
# 239 : dm_Warmsen_Thursday_31603-07_scenario_high_others_50 : 193
# 240 : dm_Warmsen_Thursday_31603-07_scenario_high_all_50 : 354
# 241 : dm_Warmsen_Thursday_31604-10_scenario_low_letter_50 : 179
# 242 : dm_Warmsen_Thursday_31604-10_scenario_low_package_50 : 47
# 243 : dm_Warmsen_Thursday_31604-10_scenario_low_others_50 : 40
# 244 : dm_Warmsen_Thursday_31604-10_scenario_low_all_50 : 223
# 245 : dm_Warmsen_Thursday_31604-10_scenario_medium_letter_50 : 268
# 246 : dm_Warmsen_Thursday_31604-10_scenario_medium_package_50 : 78
# 247 : dm_Warmsen_Thursday_31604-10_scenario_medium_others_50 : 76
# 248 : dm_Warmsen_Thursday_31604-10_scenario_medium_all_50 : 302
# 249 : dm_Warmsen_Thursday_31604-10_scenario_high_letter_50 : 316
# 250 : dm_Warmsen_Thursday_31604-10_scenario_high_package_50 : 114
# 251 : dm_Warmsen_Thursday_31604-10_scenario_high_others_50 : 120
# 252 : dm_Warmsen_Thursday_31604-10_scenario_high_all_50 : 336
# 253 : dm_Warmsen_Thursday_31600-03_scenario_low_letter_50 : 210
# 254 : dm_Warmsen_Thursday_31600-03_scenario_low_package_50 : 40
# 255 : dm_Warmsen_Thursday_31600-03_scenario_low_others_50 : 60
# 256 : dm_Warmsen_Thursday_31600-03_scenario_low_all_50 : 242
# 257 : dm_Warmsen_Thursday_31600-03_scenario_medium_letter_50 : 247
# 258 : dm_Warmsen_Thursday_31600-03_scenario_medium_package_50 : 66
# 259 : dm_Warmsen_Thursday_31600-03_scenario_medium_others_50 : 107
# 260 : dm_Warmsen_Thursday_31600-03_scenario_medium_all_50 : 282
# 261 : dm_Warmsen_Thursday_31600-03_scenario_high_letter_50 : 291
# 262 : dm_Warmsen_Thursday_31600-03_scenario_high_package_50 : 109
# 263 : dm_Warmsen_Thursday_31600-03_scenario_high_others_50 : 137
# 264 : dm_Warmsen_Thursday_31600-03_scenario_high_all_50 : 319
# 265 : dm_Warmsen_Thursday_31603-05_scenario_low_letter_50 : 193
# 266 : dm_Warmsen_Thursday_31603-05_scenario_low_package_50 : 29
# 267 : dm_Warmsen_Thursday_31603-05_scenario_low_others_50 : 79
# 268 : dm_Warmsen_Thursday_31603-05_scenario_low_all_50 : 232
# 269 : dm_Warmsen_Thursday_31603-05_scenario_medium_letter_50 : 276
# 270 : dm_Warmsen_Thursday_31603-05_scenario_medium_package_50 : 58
# 271 : dm_Warmsen_Thursday_31603-05_scenario_medium_others_50 : 117
# 272 : dm_Warmsen_Thursday_31603-05_scenario_medium_all_50 : 320
# 273 : dm_Warmsen_Thursday_31603-05_scenario_high_letter_50 : 309
# 274 : dm_Warmsen_Thursday_31603-05_scenario_high_package_50 : 80
# 275 : dm_Warmsen_Thursday_31603-05_scenario_high_others_50 : 177
# 276 : dm_Warmsen_Thursday_31603-05_scenario_high_all_50 : 339
# 277 : dm_Warmsen_Thursday_31603-08_scenario_low_letter_50 : 156
# 278 : dm_Warmsen_Thursday_31603-08_scenario_low_package_50 : 45
# 279 : dm_Warmsen_Thursday_31603-08_scenario_low_others_50 : 67
# 280 : dm_Warmsen_Thursday_31603-08_scenario_low_all_50 : 210
# 281 : dm_Warmsen_Thursday_31603-08_scenario_medium_letter_50 : 255
# 282 : dm_Warmsen_Thursday_31603-08_scenario_medium_package_50 : 75
# 283 : dm_Warmsen_Thursday_31603-08_scenario_medium_others_50 : 123
# 284 : dm_Warmsen_Thursday_31603-08_scenario_medium_all_50 : 293
# 285 : dm_Warmsen_Thursday_31603-08_scenario_high_letter_50 : 296
# 286 : dm_Warmsen_Thursday_31603-08_scenario_high_package_50 : 94
# 287 : dm_Warmsen_Thursday_31603-08_scenario_high_others_50 : 154
# 288 : dm_Warmsen_Thursday_31603-08_scenario_high_all_50 : 331
# 289 : dm_Warmsen_Thursday_31606-11_scenario_low_letter_50 : 184
# 290 : dm_Warmsen_Thursday_31606-11_scenario_low_package_50 : 35
# 291 : dm_Warmsen_Thursday_31606-11_scenario_low_others_50 : 33
# 292 : dm_Warmsen_Thursday_31606-11_scenario_low_all_50 : 215
# 293 : dm_Warmsen_Thursday_31606-11_scenario_medium_letter_50 : 263
# 294 : dm_Warmsen_Thursday_31606-11_scenario_medium_package_50 : 56
# 295 : dm_Warmsen_Thursday_31606-11_scenario_medium_others_50 : 84
# 296 : dm_Warmsen_Thursday_31606-11_scenario_medium_all_50 : 284
# 297 : dm_Warmsen_Thursday_31606-11_scenario_high_letter_50 : 290
# 298 : dm_Warmsen_Thursday_31606-11_scenario_high_package_50 : 95
# 299 : dm_Warmsen_Thursday_31606-11_scenario_high_others_50 : 101
# 300 : dm_Warmsen_Thursday_31606-11_scenario_high_all_50 : 310
# 301 : dm_Warmsen_Thursday_31606-14_scenario_low_letter_50 : 153
# 302 : dm_Warmsen_Thursday_31606-14_scenario_low_package_50 : 27
# 303 : dm_Warmsen_Thursday_31606-14_scenario_low_others_50 : 38
# 304 : dm_Warmsen_Thursday_31606-14_scenario_low_all_50 : 179
# 305 : dm_Warmsen_Thursday_31606-14_scenario_medium_letter_50 : 233
# 306 : dm_Warmsen_Thursday_31606-14_scenario_medium_package_50 : 72
# 307 : dm_Warmsen_Thursday_31606-14_scenario_medium_others_50 : 63
# 308 : dm_Warmsen_Thursday_31606-14_scenario_medium_all_50 : 250
# 309 : dm_Warmsen_Thursday_31606-14_scenario_high_letter_50 : 251
# 310 : dm_Warmsen_Thursday_31606-14_scenario_high_package_50 : 93
# 311 : dm_Warmsen_Thursday_31606-14_scenario_high_others_50 : 100
# 312 : dm_Warmsen_Thursday_31606-14_scenario_high_all_50 : 278
# 313 : dm_Warmsen_Thursday_31606-13_scenario_low_letter_50 : 157
# 314 : dm_Warmsen_Thursday_31606-13_scenario_low_package_50 : 32
# 315 : dm_Warmsen_Thursday_31606-13_scenario_low_others_50 : 36
# 316 : dm_Warmsen_Thursday_31606-13_scenario_low_all_50 : 181
# 317 : dm_Warmsen_Thursday_31606-13_scenario_medium_letter_50 : 227
# 318 : dm_Warmsen_Thursday_31606-13_scenario_medium_package_50 : 70
# 319 : dm_Warmsen_Thursday_31606-13_scenario_medium_others_50 : 71
# 320 : dm_Warmsen_Thursday_31606-13_scenario_medium_all_50 : 249
# 321 : dm_Warmsen_Thursday_31606-13_scenario_high_letter_50 : 234
# 322 : dm_Warmsen_Thursday_31606-13_scenario_high_package_50 : 83
# 323 : dm_Warmsen_Thursday_31606-13_scenario_high_others_50 : 105
# 324 : dm_Warmsen_Thursday_31606-13_scenario_high_all_50 : 268
# 325 : dm_Warmsen_Thursday_31600-04_scenario_low_letter_50 : 117
# 326 : dm_Warmsen_Thursday_31600-04_scenario_low_package_50 : 27
# 327 : dm_Warmsen_Thursday_31600-04_scenario_low_others_50 : 54
# 328 : dm_Warmsen_Thursday_31600-04_scenario_low_all_50 : 156
# 329 : dm_Warmsen_Thursday_31600-04_scenario_medium_letter_50 : 189
# 330 : dm_Warmsen_Thursday_31600-04_scenario_medium_package_50 : 49
# 331 : dm_Warmsen_Thursday_31600-04_scenario_medium_others_50 : 60
# 332 : dm_Warmsen_Thursday_31600-04_scenario_medium_all_50 : 219
# 333 : dm_Warmsen_Thursday_31600-04_scenario_high_letter_50 : 219
# 334 : dm_Warmsen_Thursday_31600-04_scenario_high_package_50 : 67
# 335 : dm_Warmsen_Thursday_31600-04_scenario_high_others_50 : 97
# 336 : dm_Warmsen_Thursday_31600-04_scenario_high_all_50 : 248
# 337 : dm_Warmsen_Friday_31603-06_scenario_low_letter_50 : 162
# 338 : dm_Warmsen_Friday_31603-06_scenario_low_package_50 : 34
# 339 : dm_Warmsen_Friday_31603-06_scenario_low_others_50 : 115
# 340 : dm_Warmsen_Friday_31603-06_scenario_low_all_50 : 242
# 341 : dm_Warmsen_Friday_31603-06_scenario_medium_letter_50 : 274
# 342 : dm_Warmsen_Friday_31603-06_scenario_medium_package_50 : 70
# 343 : dm_Warmsen_Friday_31603-06_scenario_medium_others_50 : 166
# 344 : dm_Warmsen_Friday_31603-06_scenario_medium_all_50 : 338
# 345 : dm_Warmsen_Friday_31603-06_scenario_high_letter_50 : 323
# 346 : dm_Warmsen_Friday_31603-06_scenario_high_package_50 : 94
# 347 : dm_Warmsen_Friday_31603-06_scenario_high_others_50 : 233
# 348 : dm_Warmsen_Friday_31603-06_scenario_high_all_50 : 374
# 349 : dm_Warmsen_Friday_31600-01_scenario_low_letter_50 : 184
# 350 : dm_Warmsen_Friday_31600-01_scenario_low_package_50 : 23
# 351 : dm_Warmsen_Friday_31600-01_scenario_low_others_50 : 84
# 352 : dm_Warmsen_Friday_31600-01_scenario_low_all_50 : 231
# 353 : dm_Warmsen_Friday_31600-01_scenario_medium_letter_50 : 256
# 354 : dm_Warmsen_Friday_31600-01_scenario_medium_package_50 : 53
# 355 : dm_Warmsen_Friday_31600-01_scenario_medium_others_50 : 169
# 356 : dm_Warmsen_Friday_31600-01_scenario_medium_all_50 : 309
# 357 : dm_Warmsen_Friday_31600-01_scenario_high_letter_50 : 309
# 358 : dm_Warmsen_Friday_31600-01_scenario_high_package_50 : 79
# 359 : dm_Warmsen_Friday_31600-01_scenario_high_others_50 : 222
# 360 : dm_Warmsen_Friday_31600-01_scenario_high_all_50 : 351
# 361 : dm_Warmsen_Friday_31606-12_scenario_low_letter_50 : 151
# 362 : dm_Warmsen_Friday_31606-12_scenario_low_package_50 : 42
# 363 : dm_Warmsen_Friday_31606-12_scenario_low_others_50 : 104
# 364 : dm_Warmsen_Friday_31606-12_scenario_low_all_50 : 226
# 365 : dm_Warmsen_Friday_31606-12_scenario_medium_letter_50 : 264
# 366 : dm_Warmsen_Friday_31606-12_scenario_medium_package_50 : 65
# 367 : dm_Warmsen_Friday_31606-12_scenario_medium_others_50 : 181
# 368 : dm_Warmsen_Friday_31606-12_scenario_medium_all_50 : 331
# 369 : dm_Warmsen_Friday_31606-12_scenario_high_letter_50 : 295
# 370 : dm_Warmsen_Friday_31606-12_scenario_high_package_50 : 100
# 371 : dm_Warmsen_Friday_31606-12_scenario_high_others_50 : 228
# 372 : dm_Warmsen_Friday_31606-12_scenario_high_all_50 : 357
# 373 : dm_Warmsen_Friday_31600-02_scenario_low_letter_50 : 152
# 374 : dm_Warmsen_Friday_31600-02_scenario_low_package_50 : 32
# 375 : dm_Warmsen_Friday_31600-02_scenario_low_others_50 : 109
# 376 : dm_Warmsen_Friday_31600-02_scenario_low_all_50 : 222
# 377 : dm_Warmsen_Friday_31600-02_scenario_medium_letter_50 : 240
# 378 : dm_Warmsen_Friday_31600-02_scenario_medium_package_50 : 51
# 379 : dm_Warmsen_Friday_31600-02_scenario_medium_others_50 : 184
# 380 : dm_Warmsen_Friday_31600-02_scenario_medium_all_50 : 317
# 381 : dm_Warmsen_Friday_31600-02_scenario_high_letter_50 : 283
# 382 : dm_Warmsen_Friday_31600-02_scenario_high_package_50 : 84
# 383 : dm_Warmsen_Friday_31600-02_scenario_high_others_50 : 243
# 384 : dm_Warmsen_Friday_31600-02_scenario_high_all_50 : 355
# 385 : dm_Warmsen_Friday_31604-09_scenario_low_letter_50 : 171
# 386 : dm_Warmsen_Friday_31604-09_scenario_low_package_50 : 37
# 387 : dm_Warmsen_Friday_31604-09_scenario_low_others_50 : 118
# 388 : dm_Warmsen_Friday_31604-09_scenario_low_all_50 : 246
# 389 : dm_Warmsen_Friday_31604-09_scenario_medium_letter_50 : 267
# 390 : dm_Warmsen_Friday_31604-09_scenario_medium_package_50 : 63
# 391 : dm_Warmsen_Friday_31604-09_scenario_medium_others_50 : 198
# 392 : dm_Warmsen_Friday_31604-09_scenario_medium_all_50 : 330
# 393 : dm_Warmsen_Friday_31604-09_scenario_high_letter_50 : 315
# 394 : dm_Warmsen_Friday_31604-09_scenario_high_package_50 : 108
# 395 : dm_Warmsen_Friday_31604-09_scenario_high_others_50 : 228
# 396 : dm_Warmsen_Friday_31604-09_scenario_high_all_50 : 366
# 397 : dm_Warmsen_Friday_31603-07_scenario_low_letter_50 : 186
# 398 : dm_Warmsen_Friday_31603-07_scenario_low_package_50 : 34
# 399 : dm_Warmsen_Friday_31603-07_scenario_low_others_50 : 107
# 400 : dm_Warmsen_Friday_31603-07_scenario_low_all_50 : 241
# 401 : dm_Warmsen_Friday_31603-07_scenario_medium_letter_50 : 272
# 402 : dm_Warmsen_Friday_31603-07_scenario_medium_package_50 : 61
# 403 : dm_Warmsen_Friday_31603-07_scenario_medium_others_50 : 160
# 404 : dm_Warmsen_Friday_31603-07_scenario_medium_all_50 : 321
# 405 : dm_Warmsen_Friday_31603-07_scenario_high_letter_50 : 314
# 406 : dm_Warmsen_Friday_31603-07_scenario_high_package_50 : 99
# 407 : dm_Warmsen_Friday_31603-07_scenario_high_others_50 : 216
# 408 : dm_Warmsen_Friday_31603-07_scenario_high_all_50 : 351
# 409 : dm_Warmsen_Friday_31604-10_scenario_low_letter_50 : 164
# 410 : dm_Warmsen_Friday_31604-10_scenario_low_package_50 : 32
# 411 : dm_Warmsen_Friday_31604-10_scenario_low_others_50 : 97
# 412 : dm_Warmsen_Friday_31604-10_scenario_low_all_50 : 222
# 413 : dm_Warmsen_Friday_31604-10_scenario_medium_letter_50 : 263
# 414 : dm_Warmsen_Friday_31604-10_scenario_medium_package_50 : 74
# 415 : dm_Warmsen_Friday_31604-10_scenario_medium_others_50 : 170
# 416 : dm_Warmsen_Friday_31604-10_scenario_medium_all_50 : 315
# 417 : dm_Warmsen_Friday_31604-10_scenario_high_letter_50 : 299
# 418 : dm_Warmsen_Friday_31604-10_scenario_high_package_50 : 75
# 419 : dm_Warmsen_Friday_31604-10_scenario_high_others_50 : 238
# 420 : dm_Warmsen_Friday_31604-10_scenario_high_all_50 : 344
# 421 : dm_Warmsen_Friday_31600-03_scenario_low_letter_50 : 163
# 422 : dm_Warmsen_Friday_31600-03_scenario_low_package_50 : 33
# 423 : dm_Warmsen_Friday_31600-03_scenario_low_others_50 : 93
# 424 : dm_Warmsen_Friday_31600-03_scenario_low_all_50 : 217
# 425 : dm_Warmsen_Friday_31600-03_scenario_medium_letter_50 : 252
# 426 : dm_Warmsen_Friday_31600-03_scenario_medium_package_50 : 64
# 427 : dm_Warmsen_Friday_31600-03_scenario_medium_others_50 : 155
# 428 : dm_Warmsen_Friday_31600-03_scenario_medium_all_50 : 303
# 429 : dm_Warmsen_Friday_31600-03_scenario_high_letter_50 : 282
# 430 : dm_Warmsen_Friday_31600-03_scenario_high_package_50 : 90
# 431 : dm_Warmsen_Friday_31600-03_scenario_high_others_50 : 212
# 432 : dm_Warmsen_Friday_31600-03_scenario_high_all_50 : 323
# 433 : dm_Warmsen_Friday_31603-05_scenario_low_letter_50 : 184
# 434 : dm_Warmsen_Friday_31603-05_scenario_low_package_50 : 41
# 435 : dm_Warmsen_Friday_31603-05_scenario_low_others_50 : 100
# 436 : dm_Warmsen_Friday_31603-05_scenario_low_all_50 : 245
# 437 : dm_Warmsen_Friday_31603-05_scenario_medium_letter_50 : 256
# 438 : dm_Warmsen_Friday_31603-05_scenario_medium_package_50 : 57
# 439 : dm_Warmsen_Friday_31603-05_scenario_medium_others_50 : 166
# 440 : dm_Warmsen_Friday_31603-05_scenario_medium_all_50 : 303
# 441 : dm_Warmsen_Friday_31603-05_scenario_high_letter_50 : 313
# 442 : dm_Warmsen_Friday_31603-05_scenario_high_package_50 : 73
# 443 : dm_Warmsen_Friday_31603-05_scenario_high_others_50 : 213
# 444 : dm_Warmsen_Friday_31603-05_scenario_high_all_50 : 343
# 445 : dm_Warmsen_Friday_31603-08_scenario_low_letter_50 : 169
# 446 : dm_Warmsen_Friday_31603-08_scenario_low_package_50 : 38
# 447 : dm_Warmsen_Friday_31603-08_scenario_low_others_50 : 94
# 448 : dm_Warmsen_Friday_31603-08_scenario_low_all_50 : 227
# 449 : dm_Warmsen_Friday_31603-08_scenario_medium_letter_50 : 244
# 450 : dm_Warmsen_Friday_31603-08_scenario_medium_package_50 : 79
# 451 : dm_Warmsen_Friday_31603-08_scenario_medium_others_50 : 155
# 452 : dm_Warmsen_Friday_31603-08_scenario_medium_all_50 : 296
# 453 : dm_Warmsen_Friday_31603-08_scenario_high_letter_50 : 286
# 454 : dm_Warmsen_Friday_31603-08_scenario_high_package_50 : 99
# 455 : dm_Warmsen_Friday_31603-08_scenario_high_others_50 : 195
# 456 : dm_Warmsen_Friday_31603-08_scenario_high_all_50 : 320
# 457 : dm_Warmsen_Friday_31606-11_scenario_low_letter_50 : 163
# 458 : dm_Warmsen_Friday_31606-11_scenario_low_package_50 : 29
# 459 : dm_Warmsen_Friday_31606-11_scenario_low_others_50 : 107
# 460 : dm_Warmsen_Friday_31606-11_scenario_low_all_50 : 227
# 461 : dm_Warmsen_Friday_31606-11_scenario_medium_letter_50 : 244
# 462 : dm_Warmsen_Friday_31606-11_scenario_medium_package_50 : 61
# 463 : dm_Warmsen_Friday_31606-11_scenario_medium_others_50 : 159
# 464 : dm_Warmsen_Friday_31606-11_scenario_medium_all_50 : 286
# 465 : dm_Warmsen_Friday_31606-11_scenario_high_letter_50 : 286
# 466 : dm_Warmsen_Friday_31606-11_scenario_high_package_50 : 91
# 467 : dm_Warmsen_Friday_31606-11_scenario_high_others_50 : 208
# 468 : dm_Warmsen_Friday_31606-11_scenario_high_all_50 : 313
# 469 : dm_Warmsen_Friday_31606-14_scenario_low_letter_50 : 142
# 470 : dm_Warmsen_Friday_31606-14_scenario_low_package_50 : 19
# 471 : dm_Warmsen_Friday_31606-14_scenario_low_others_50 : 92
# 472 : dm_Warmsen_Friday_31606-14_scenario_low_all_50 : 195
# 473 : dm_Warmsen_Friday_31606-14_scenario_medium_letter_50 : 215
# 474 : dm_Warmsen_Friday_31606-14_scenario_medium_package_50 : 56
# 475 : dm_Warmsen_Friday_31606-14_scenario_medium_others_50 : 143
# 476 : dm_Warmsen_Friday_31606-14_scenario_medium_all_50 : 254
# 477 : dm_Warmsen_Friday_31606-14_scenario_high_letter_50 : 255
# 478 : dm_Warmsen_Friday_31606-14_scenario_high_package_50 : 76
# 479 : dm_Warmsen_Friday_31606-14_scenario_high_others_50 : 182
# 480 : dm_Warmsen_Friday_31606-14_scenario_high_all_50 : 284
# 481 : dm_Warmsen_Friday_31606-13_scenario_low_letter_50 : 133
# 482 : dm_Warmsen_Friday_31606-13_scenario_low_package_50 : 22
# 483 : dm_Warmsen_Friday_31606-13_scenario_low_others_50 : 78
# 484 : dm_Warmsen_Friday_31606-13_scenario_low_all_50 : 180
# 485 : dm_Warmsen_Friday_31606-13_scenario_medium_letter_50 : 205
# 486 : dm_Warmsen_Friday_31606-13_scenario_medium_package_50 : 62
# 487 : dm_Warmsen_Friday_31606-13_scenario_medium_others_50 : 141
# 488 : dm_Warmsen_Friday_31606-13_scenario_medium_all_50 : 248
# 489 : dm_Warmsen_Friday_31606-13_scenario_high_letter_50 : 246
# 490 : dm_Warmsen_Friday_31606-13_scenario_high_package_50 : 74
# 491 : dm_Warmsen_Friday_31606-13_scenario_high_others_50 : 181
# 492 : dm_Warmsen_Friday_31606-13_scenario_high_all_50 : 279
# 493 : dm_Warmsen_Friday_31600-04_scenario_low_letter_50 : 120
# 494 : dm_Warmsen_Friday_31600-04_scenario_low_package_50 : 29
# 495 : dm_Warmsen_Friday_31600-04_scenario_low_others_50 : 80
# 496 : dm_Warmsen_Friday_31600-04_scenario_low_all_50 : 178
# 497 : dm_Warmsen_Friday_31600-04_scenario_medium_letter_50 : 174
# 498 : dm_Warmsen_Friday_31600-04_scenario_medium_package_50 : 50
# 499 : dm_Warmsen_Friday_31600-04_scenario_medium_others_50 : 126
# 500 : dm_Warmsen_Friday_31600-04_scenario_medium_all_50 : 223
# 501 : dm_Warmsen_Friday_31600-04_scenario_high_letter_50 : 208
# 502 : dm_Warmsen_Friday_31600-04_scenario_high_package_50 : 46
# 503 : dm_Warmsen_Friday_31600-04_scenario_high_others_50 : 157
# 504 : dm_Warmsen_Friday_31600-04_scenario_high_all_50 : 244
# 505 : dm_Warmsen_Wednesday_31603-06_scenario_low_letter_50 : 185
# 506 : dm_Warmsen_Wednesday_31603-06_scenario_low_package_50 : 31
# 507 : dm_Warmsen_Wednesday_31603-06_scenario_low_others_50 : 102
# 508 : dm_Warmsen_Wednesday_31603-06_scenario_low_all_50 : 240
# 509 : dm_Warmsen_Wednesday_31603-06_scenario_medium_letter_50 : 284
# 510 : dm_Warmsen_Wednesday_31603-06_scenario_medium_package_50 : 79
# 511 : dm_Warmsen_Wednesday_31603-06_scenario_medium_others_50 : 178
# 512 : dm_Warmsen_Wednesday_31603-06_scenario_medium_all_50 : 361
# 513 : dm_Warmsen_Wednesday_31603-06_scenario_high_letter_50 : 341
# 514 : dm_Warmsen_Wednesday_31603-06_scenario_high_package_50 : 111
# 515 : dm_Warmsen_Wednesday_31603-06_scenario_high_others_50 : 234
# 516 : dm_Warmsen_Wednesday_31603-06_scenario_high_all_50 : 383
# 517 : dm_Warmsen_Wednesday_31600-01_scenario_low_letter_50 : 175
# 518 : dm_Warmsen_Wednesday_31600-01_scenario_low_package_50 : 34
# 519 : dm_Warmsen_Wednesday_31600-01_scenario_low_others_50 : 54
# 520 : dm_Warmsen_Wednesday_31600-01_scenario_low_all_50 : 212
# 521 : dm_Warmsen_Wednesday_31600-01_scenario_medium_letter_50 : 269
# 522 : dm_Warmsen_Wednesday_31600-01_scenario_medium_package_50 : 73
# 523 : dm_Warmsen_Wednesday_31600-01_scenario_medium_others_50 : 92
# 524 : dm_Warmsen_Wednesday_31600-01_scenario_medium_all_50 : 301
# 525 : dm_Warmsen_Wednesday_31600-01_scenario_high_letter_50 : 301
# 526 : dm_Warmsen_Wednesday_31600-01_scenario_high_package_50 : 89
# 527 : dm_Warmsen_Wednesday_31600-01_scenario_high_others_50 : 146
# 528 : dm_Warmsen_Wednesday_31600-01_scenario_high_all_50 : 334
# 529 : dm_Warmsen_Wednesday_31606-12_scenario_low_letter_50 : 162
# 530 : dm_Warmsen_Wednesday_31606-12_scenario_low_package_50 : 40
# 531 : dm_Warmsen_Wednesday_31606-12_scenario_low_others_50 : 59
# 532 : dm_Warmsen_Wednesday_31606-12_scenario_low_all_50 : 214
# 533 : dm_Warmsen_Wednesday_31606-12_scenario_medium_letter_50 : 257
# 534 : dm_Warmsen_Wednesday_31606-12_scenario_medium_package_50 : 81
# 535 : dm_Warmsen_Wednesday_31606-12_scenario_medium_others_50 : 120
# 536 : dm_Warmsen_Wednesday_31606-12_scenario_medium_all_50 : 300
# 537 : dm_Warmsen_Wednesday_31606-12_scenario_high_letter_50 : 329
# 538 : dm_Warmsen_Wednesday_31606-12_scenario_high_package_50 : 119
# 539 : dm_Warmsen_Wednesday_31606-12_scenario_high_others_50 : 179
# 540 : dm_Warmsen_Wednesday_31606-12_scenario_high_all_50 : 367
# 541 : dm_Warmsen_Wednesday_31600-02_scenario_low_letter_50 : 162
# 542 : dm_Warmsen_Wednesday_31600-02_scenario_low_package_50 : 43
# 543 : dm_Warmsen_Wednesday_31600-02_scenario_low_others_50 : 73
# 544 : dm_Warmsen_Wednesday_31600-02_scenario_low_all_50 : 212
# 545 : dm_Warmsen_Wednesday_31600-02_scenario_medium_letter_50 : 255
# 546 : dm_Warmsen_Wednesday_31600-02_scenario_medium_package_50 : 67
# 547 : dm_Warmsen_Wednesday_31600-02_scenario_medium_others_50 : 122
# 548 : dm_Warmsen_Wednesday_31600-02_scenario_medium_all_50 : 307
# 549 : dm_Warmsen_Wednesday_31600-02_scenario_high_letter_50 : 310
# 550 : dm_Warmsen_Wednesday_31600-02_scenario_high_package_50 : 91
# 551 : dm_Warmsen_Wednesday_31600-02_scenario_high_others_50 : 159
# 552 : dm_Warmsen_Wednesday_31600-02_scenario_high_all_50 : 347
# 553 : dm_Warmsen_Wednesday_31604-09_scenario_low_letter_50 : 167
# 554 : dm_Warmsen_Wednesday_31604-09_scenario_low_package_50 : 48
# 555 : dm_Warmsen_Wednesday_31604-09_scenario_low_others_50 : 51
# 556 : dm_Warmsen_Wednesday_31604-09_scenario_low_all_50 : 213
# 557 : dm_Warmsen_Wednesday_31604-09_scenario_medium_letter_50 : 275
# 558 : dm_Warmsen_Wednesday_31604-09_scenario_medium_package_50 : 96
# 559 : dm_Warmsen_Wednesday_31604-09_scenario_medium_others_50 : 109
# 560 : dm_Warmsen_Wednesday_31604-09_scenario_medium_all_50 : 319
# 561 : dm_Warmsen_Wednesday_31604-09_scenario_high_letter_50 : 329
# 562 : dm_Warmsen_Wednesday_31604-09_scenario_high_package_50 : 112
# 563 : dm_Warmsen_Wednesday_31604-09_scenario_high_others_50 : 145
# 564 : dm_Warmsen_Wednesday_31604-09_scenario_high_all_50 : 365
# 565 : dm_Warmsen_Wednesday_31603-07_scenario_low_letter_50 : 209
# 566 : dm_Warmsen_Wednesday_31603-07_scenario_low_package_50 : 40
# 567 : dm_Warmsen_Wednesday_31603-07_scenario_low_others_50 : 109
# 568 : dm_Warmsen_Wednesday_31603-07_scenario_low_all_50 : 266
# 569 : dm_Warmsen_Wednesday_31603-07_scenario_medium_letter_50 : 266
# 570 : dm_Warmsen_Wednesday_31603-07_scenario_medium_package_50 : 65
# 571 : dm_Warmsen_Wednesday_31603-07_scenario_medium_others_50 : 163
# 572 : dm_Warmsen_Wednesday_31603-07_scenario_medium_all_50 : 324
# 573 : dm_Warmsen_Wednesday_31603-07_scenario_high_letter_50 : 309
# 574 : dm_Warmsen_Wednesday_31603-07_scenario_high_package_50 : 105
# 575 : dm_Warmsen_Wednesday_31603-07_scenario_high_others_50 : 208
# 576 : dm_Warmsen_Wednesday_31603-07_scenario_high_all_50 : 349
# 577 : dm_Warmsen_Wednesday_31604-10_scenario_low_letter_50 : 178
# 578 : dm_Warmsen_Wednesday_31604-10_scenario_low_package_50 : 39
# 579 : dm_Warmsen_Wednesday_31604-10_scenario_low_others_50 : 58
# 580 : dm_Warmsen_Wednesday_31604-10_scenario_low_all_50 : 218
# 581 : dm_Warmsen_Wednesday_31604-10_scenario_medium_letter_50 : 259
# 582 : dm_Warmsen_Wednesday_31604-10_scenario_medium_package_50 : 80
# 583 : dm_Warmsen_Wednesday_31604-10_scenario_medium_others_50 : 101
# 584 : dm_Warmsen_Wednesday_31604-10_scenario_medium_all_50 : 291
# 585 : dm_Warmsen_Wednesday_31604-10_scenario_high_letter_50 : 291
# 586 : dm_Warmsen_Wednesday_31604-10_scenario_high_package_50 : 101
# 587 : dm_Warmsen_Wednesday_31604-10_scenario_high_others_50 : 136
# 588 : dm_Warmsen_Wednesday_31604-10_scenario_high_all_50 : 323
# 589 : dm_Warmsen_Wednesday_31600-03_scenario_low_letter_50 : 171
# 590 : dm_Warmsen_Wednesday_31600-03_scenario_low_package_50 : 45
# 591 : dm_Warmsen_Wednesday_31600-03_scenario_low_others_50 : 64
# 592 : dm_Warmsen_Wednesday_31600-03_scenario_low_all_50 : 211
# 593 : dm_Warmsen_Wednesday_31600-03_scenario_medium_letter_50 : 240
# 594 : dm_Warmsen_Wednesday_31600-03_scenario_medium_package_50 : 76
# 595 : dm_Warmsen_Wednesday_31600-03_scenario_medium_others_50 : 112
# 596 : dm_Warmsen_Wednesday_31600-03_scenario_medium_all_50 : 278
# 597 : dm_Warmsen_Wednesday_31600-03_scenario_high_letter_50 : 283
# 598 : dm_Warmsen_Wednesday_31600-03_scenario_high_package_50 : 114
# 599 : dm_Warmsen_Wednesday_31600-03_scenario_high_others_50 : 136
# 600 : dm_Warmsen_Wednesday_31600-03_scenario_high_all_50 : 307
# 601 : dm_Warmsen_Wednesday_31603-05_scenario_low_letter_50 : 174
# 602 : dm_Warmsen_Wednesday_31603-05_scenario_low_package_50 : 41
# 603 : dm_Warmsen_Wednesday_31603-05_scenario_low_others_50 : 97
# 604 : dm_Warmsen_Wednesday_31603-05_scenario_low_all_50 : 232
# 605 : dm_Warmsen_Wednesday_31603-05_scenario_medium_letter_50 : 256
# 606 : dm_Warmsen_Wednesday_31603-05_scenario_medium_package_50 : 71
# 607 : dm_Warmsen_Wednesday_31603-05_scenario_medium_others_50 : 184
# 608 : dm_Warmsen_Wednesday_31603-05_scenario_medium_all_50 : 316
# 609 : dm_Warmsen_Wednesday_31603-05_scenario_high_letter_50 : 315
# 610 : dm_Warmsen_Wednesday_31603-05_scenario_high_package_50 : 101
# 611 : dm_Warmsen_Wednesday_31603-05_scenario_high_others_50 : 206
# 612 : dm_Warmsen_Wednesday_31603-05_scenario_high_all_50 : 344
# 613 : dm_Warmsen_Wednesday_31603-08_scenario_low_letter_50 : 176
# 614 : dm_Warmsen_Wednesday_31603-08_scenario_low_package_50 : 58
# 615 : dm_Warmsen_Wednesday_31603-08_scenario_low_others_50 : 80
# 616 : dm_Warmsen_Wednesday_31603-08_scenario_low_all_50 : 233
# 617 : dm_Warmsen_Wednesday_31603-08_scenario_medium_letter_50 : 252
# 618 : dm_Warmsen_Wednesday_31603-08_scenario_medium_package_50 : 63
# 619 : dm_Warmsen_Wednesday_31603-08_scenario_medium_others_50 : 155
# 620 : dm_Warmsen_Wednesday_31603-08_scenario_medium_all_50 : 299
# 621 : dm_Warmsen_Wednesday_31603-08_scenario_high_letter_50 : 293
# 622 : dm_Warmsen_Wednesday_31603-08_scenario_high_package_50 : 98
# 623 : dm_Warmsen_Wednesday_31603-08_scenario_high_others_50 : 209
# 624 : dm_Warmsen_Wednesday_31603-08_scenario_high_all_50 : 334
# 625 : dm_Warmsen_Wednesday_31606-11_scenario_low_letter_50 : 180
# 626 : dm_Warmsen_Wednesday_31606-11_scenario_low_package_50 : 37
# 627 : dm_Warmsen_Wednesday_31606-11_scenario_low_others_50 : 75
# 628 : dm_Warmsen_Wednesday_31606-11_scenario_low_all_50 : 224
# 629 : dm_Warmsen_Wednesday_31606-11_scenario_medium_letter_50 : 245
# 630 : dm_Warmsen_Wednesday_31606-11_scenario_medium_package_50 : 71
# 631 : dm_Warmsen_Wednesday_31606-11_scenario_medium_others_50 : 123
# 632 : dm_Warmsen_Wednesday_31606-11_scenario_medium_all_50 : 279
# 633 : dm_Warmsen_Wednesday_31606-11_scenario_high_letter_50 : 284
# 634 : dm_Warmsen_Wednesday_31606-11_scenario_high_package_50 : 84
# 635 : dm_Warmsen_Wednesday_31606-11_scenario_high_others_50 : 160
# 636 : dm_Warmsen_Wednesday_31606-11_scenario_high_all_50 : 307
# 637 : dm_Warmsen_Wednesday_31606-14_scenario_low_letter_50 : 149
# 638 : dm_Warmsen_Wednesday_31606-14_scenario_low_package_50 : 38
# 639 : dm_Warmsen_Wednesday_31606-14_scenario_low_others_50 : 66
# 640 : dm_Warmsen_Wednesday_31606-14_scenario_low_all_50 : 197
# 641 : dm_Warmsen_Wednesday_31606-14_scenario_medium_letter_50 : 220
# 642 : dm_Warmsen_Wednesday_31606-14_scenario_medium_package_50 : 68
# 643 : dm_Warmsen_Wednesday_31606-14_scenario_medium_others_50 : 125
# 644 : dm_Warmsen_Wednesday_31606-14_scenario_medium_all_50 : 267
# 645 : dm_Warmsen_Wednesday_31606-14_scenario_high_letter_50 : 244
# 646 : dm_Warmsen_Wednesday_31606-14_scenario_high_package_50 : 74
# 647 : dm_Warmsen_Wednesday_31606-14_scenario_high_others_50 : 136
# 648 : dm_Warmsen_Wednesday_31606-14_scenario_high_all_50 : 270
# 649 : dm_Warmsen_Wednesday_31606-13_scenario_low_letter_50 : 159
# 650 : dm_Warmsen_Wednesday_31606-13_scenario_low_package_50 : 32
# 651 : dm_Warmsen_Wednesday_31606-13_scenario_low_others_50 : 65
# 652 : dm_Warmsen_Wednesday_31606-13_scenario_low_all_50 : 201
# 653 : dm_Warmsen_Wednesday_31606-13_scenario_medium_letter_50 : 223
# 654 : dm_Warmsen_Wednesday_31606-13_scenario_medium_package_50 : 75
# 655 : dm_Warmsen_Wednesday_31606-13_scenario_medium_others_50 : 95
# 656 : dm_Warmsen_Wednesday_31606-13_scenario_medium_all_50 : 251
# 657 : dm_Warmsen_Wednesday_31606-13_scenario_high_letter_50 : 244
# 658 : dm_Warmsen_Wednesday_31606-13_scenario_high_package_50 : 77
# 659 : dm_Warmsen_Wednesday_31606-13_scenario_high_others_50 : 137
# 660 : dm_Warmsen_Wednesday_31606-13_scenario_high_all_50 : 275
# 661 : dm_Warmsen_Wednesday_31600-04_scenario_low_letter_50 : 109
# 662 : dm_Warmsen_Wednesday_31600-04_scenario_low_package_50 : 28
# 663 : dm_Warmsen_Wednesday_31600-04_scenario_low_others_50 : 40
# 664 : dm_Warmsen_Wednesday_31600-04_scenario_low_all_50 : 142
# 665 : dm_Warmsen_Wednesday_31600-04_scenario_medium_letter_50 : 177
# 666 : dm_Warmsen_Wednesday_31600-04_scenario_medium_package_50 : 53
# 667 : dm_Warmsen_Wednesday_31600-04_scenario_medium_others_50 : 78
# 668 : dm_Warmsen_Wednesday_31600-04_scenario_medium_all_50 : 214
# 669 : dm_Warmsen_Wednesday_31600-04_scenario_high_letter_50 : 205
# 670 : dm_Warmsen_Wednesday_31600-04_scenario_high_package_50 : 72
# 671 : dm_Warmsen_Wednesday_31600-04_scenario_high_others_50 : 115
# 672 : dm_Warmsen_Wednesday_31600-04_scenario_high_all_50 : 242
# 673 : dm_Warmsen_Monday_31603-06_scenario_low_letter_50 : 26
# 674 : dm_Warmsen_Monday_31603-06_scenario_low_package_50 : 14
# 675 : dm_Warmsen_Monday_31603-06_scenario_low_others_50 : 2
# 676 : dm_Warmsen_Monday_31603-06_scenario_low_all_50 : 38
# 677 : dm_Warmsen_Monday_31603-06_scenario_medium_letter_50 : 61
# 678 : dm_Warmsen_Monday_31603-06_scenario_medium_package_50 : 25
# 679 : dm_Warmsen_Monday_31603-06_scenario_medium_others_50 : 2
# 680 : dm_Warmsen_Monday_31603-06_scenario_medium_all_50 : 80
# 681 : dm_Warmsen_Monday_31603-06_scenario_high_letter_50 : 64
# 682 : dm_Warmsen_Monday_31603-06_scenario_high_package_50 : 32
# 683 : dm_Warmsen_Monday_31603-06_scenario_high_others_50 : 2
# 684 : dm_Warmsen_Monday_31603-06_scenario_high_all_50 : 85
# 685 : dm_Warmsen_Monday_31600-01_scenario_low_letter_50 : 32
# 686 : dm_Warmsen_Monday_31600-01_scenario_low_package_50 : 13
# 687 : dm_Warmsen_Monday_31600-01_scenario_low_others_50 : 1
# 688 : dm_Warmsen_Monday_31600-01_scenario_low_all_50 : 43
# 689 : dm_Warmsen_Monday_31600-01_scenario_medium_letter_50 : 52
# 690 : dm_Warmsen_Monday_31600-01_scenario_medium_package_50 : 25
# 691 : dm_Warmsen_Monday_31600-01_scenario_medium_others_50 : 1
# 692 : dm_Warmsen_Monday_31600-01_scenario_medium_all_50 : 74
# 693 : dm_Warmsen_Monday_31600-01_scenario_high_letter_50 : 64
# 694 : dm_Warmsen_Monday_31600-01_scenario_high_package_50 : 28
# 695 : dm_Warmsen_Monday_31600-01_scenario_high_others_50 : 1
# 696 : dm_Warmsen_Monday_31600-01_scenario_high_all_50 : 84
# 697 : dm_Warmsen_Monday_31606-12_scenario_low_letter_50 : 32
# 698 : dm_Warmsen_Monday_31606-12_scenario_low_package_50 : 14
# 699 : dm_Warmsen_Monday_31606-12_scenario_low_others_50 : 2
# 700 : dm_Warmsen_Monday_31606-12_scenario_low_all_50 : 44
# 701 : dm_Warmsen_Monday_31606-12_scenario_medium_letter_50 : 46
# 702 : dm_Warmsen_Monday_31606-12_scenario_medium_package_50 : 23
# 703 : dm_Warmsen_Monday_31606-12_scenario_medium_others_50 : 2
# 704 : dm_Warmsen_Monday_31606-12_scenario_medium_all_50 : 65
# 705 : dm_Warmsen_Monday_31606-12_scenario_high_letter_50 : 64
# 706 : dm_Warmsen_Monday_31606-12_scenario_high_package_50 : 37
# 707 : dm_Warmsen_Monday_31606-12_scenario_high_others_50 : 2
# 708 : dm_Warmsen_Monday_31606-12_scenario_high_all_50 : 93
# 709 : dm_Warmsen_Monday_31600-02_scenario_low_letter_50 : 27
# 710 : dm_Warmsen_Monday_31600-02_scenario_low_package_50 : 16
# 711 : dm_Warmsen_Monday_31600-02_scenario_low_others_50 : 1
# 712 : dm_Warmsen_Monday_31600-02_scenario_low_all_50 : 41
# 713 : dm_Warmsen_Monday_31600-02_scenario_medium_letter_50 : 55
# 714 : dm_Warmsen_Monday_31600-02_scenario_medium_package_50 : 22
# 715 : dm_Warmsen_Monday_31600-02_scenario_medium_others_50 : 1
# 716 : dm_Warmsen_Monday_31600-02_scenario_medium_all_50 : 71
# 717 : dm_Warmsen_Monday_31600-02_scenario_high_letter_50 : 48
# 718 : dm_Warmsen_Monday_31600-02_scenario_high_package_50 : 35
# 719 : dm_Warmsen_Monday_31600-02_scenario_high_others_50 : 1
# 720 : dm_Warmsen_Monday_31600-02_scenario_high_all_50 : 77
# 721 : dm_Warmsen_Monday_31604-09_scenario_low_letter_50 : 18
# 722 : dm_Warmsen_Monday_31604-09_scenario_low_package_50 : 18
# 723 : dm_Warmsen_Monday_31604-09_scenario_low_others_50 : 2
# 724 : dm_Warmsen_Monday_31604-09_scenario_low_all_50 : 32
# 725 : dm_Warmsen_Monday_31604-09_scenario_medium_letter_50 : 51
# 726 : dm_Warmsen_Monday_31604-09_scenario_medium_package_50 : 34
# 727 : dm_Warmsen_Monday_31604-09_scenario_medium_others_50 : 2
# 728 : dm_Warmsen_Monday_31604-09_scenario_medium_all_50 : 77
# 729 : dm_Warmsen_Monday_31604-09_scenario_high_letter_50 : 63
# 730 : dm_Warmsen_Monday_31604-09_scenario_high_package_50 : 43
# 731 : dm_Warmsen_Monday_31604-09_scenario_high_others_50 : 2
# 732 : dm_Warmsen_Monday_31604-09_scenario_high_all_50 : 99
# 733 : dm_Warmsen_Monday_31603-07_scenario_low_letter_50 : 33
# 734 : dm_Warmsen_Monday_31603-07_scenario_low_package_50 : 12
# 735 : dm_Warmsen_Monday_31603-07_scenario_low_others_50 : 2
# 736 : dm_Warmsen_Monday_31603-07_scenario_low_all_50 : 42
# 737 : dm_Warmsen_Monday_31603-07_scenario_medium_letter_50 : 46
# 738 : dm_Warmsen_Monday_31603-07_scenario_medium_package_50 : 19
# 739 : dm_Warmsen_Monday_31603-07_scenario_medium_others_50 : 2
# 740 : dm_Warmsen_Monday_31603-07_scenario_medium_all_50 : 62
# 741 : dm_Warmsen_Monday_31603-07_scenario_high_letter_50 : 75
# 742 : dm_Warmsen_Monday_31603-07_scenario_high_package_50 : 29
# 743 : dm_Warmsen_Monday_31603-07_scenario_high_others_50 : 2
# 744 : dm_Warmsen_Monday_31603-07_scenario_high_all_50 : 95
# 745 : dm_Warmsen_Monday_31604-10_scenario_low_letter_50 : 39
# 746 : dm_Warmsen_Monday_31604-10_scenario_low_package_50 : 13
# 747 : dm_Warmsen_Monday_31604-10_scenario_low_others_50 : 2
# 748 : dm_Warmsen_Monday_31604-10_scenario_low_all_50 : 47
# 749 : dm_Warmsen_Monday_31604-10_scenario_medium_letter_50 : 51
# 750 : dm_Warmsen_Monday_31604-10_scenario_medium_package_50 : 23
# 751 : dm_Warmsen_Monday_31604-10_scenario_medium_others_50 : 2
# 752 : dm_Warmsen_Monday_31604-10_scenario_medium_all_50 : 72
# 753 : dm_Warmsen_Monday_31604-10_scenario_high_letter_50 : 83
# 754 : dm_Warmsen_Monday_31604-10_scenario_high_package_50 : 42
# ...
# 759 : dm_Warmsen_Monday_31600-03_scenario_low_others_50 : 2
# 760 : dm_Warmsen_Monday_31600-03_scenario_low_all_50 : 41
# 761 : dm_Warmsen_Monday_31600-03_scenario_medium_letter_50 : 37
# 762 : dm_Warmsen_Monday_31600-03_scenario_medium_package_50 : 20
# 763 : dm_Warmsen_Monday_31600-03_scenario_medium_others_50 : 2
# 764 : dm_Warmsen_Monday_31600-03_scenario_medium_all_50 : 53
# 765 : dm_Warmsen_Monday_31600-03_scenario_high_letter_50 : 67
# 766 : dm_Warmsen_Monday_31600-03_scenario_high_package_50 : 36
# 767 : dm_Warmsen_Monday_31600-03_scenario_high_others_50 : 2
# 768 : dm_Warmsen_Monday_31600-03_scenario_high_all_50 : 93
# 769 : dm_Warmsen_Monday_31603-05_scenario_low_letter_50 : 34
# 770 : dm_Warmsen_Monday_31603-05_scenario_low_package_50 : 17
# 771 : dm_Warmsen_Monday_31603-05_scenario_low_others_50 : 2
# 772 : dm_Warmsen_Monday_31603-05_scenario_low_all_50 : 47
# 773 : dm_Warmsen_Monday_31603-05_scenario_medium_letter_50 : 50
# 774 : dm_Warmsen_Monday_31603-05_scenario_medium_package_50 : 21
# 775 : dm_Warmsen_Monday_31603-05_scenario_medium_others_50 : 2
# 776 : dm_Warmsen_Monday_31603-05_scenario_medium_all_50 : 68
# 777 : dm_Warmsen_Monday_31603-05_scenario_high_letter_50 : 70
# 778 : dm_Warmsen_Monday_31603-05_scenario_high_package_50 : 30
# 779 : dm_Warmsen_Monday_31603-05_scenario_high_others_50 : 2
# 780 : dm_Warmsen_Monday_31603-05_scenario_high_all_50 : 91
# 781 : dm_Warmsen_Monday_31603-08_scenario_low_letter_50 : 26
# 782 : dm_Warmsen_Monday_31603-08_scenario_low_package_50 : 21
# 783 : dm_Warmsen_Monday_31603-08_scenario_low_others_50 : 2
# 784 : dm_Warmsen_Monday_31603-08_scenario_low_all_50 : 41
# 785 : dm_Warmsen_Monday_31603-08_scenario_medium_letter_50 : 49
# 786 : dm_Warmsen_Monday_31603-08_scenario_medium_package_50 : 34
# 787 : dm_Warmsen_Monday_31603-08_scenario_medium_others_50 : 2
# 788 : dm_Warmsen_Monday_31603-08_scenario_medium_all_50 : 73
# 789 : dm_Warmsen_Monday_31603-08_scenario_high_letter_50 : 59
# 790 : dm_Warmsen_Monday_31603-08_scenario_high_package_50 : 38
# 791 : dm_Warmsen_Monday_31603-08_scenario_high_others_50 : 2
# 792 : dm_Warmsen_Monday_31603-08_scenario_high_all_50 : 86
# 793 : dm_Warmsen_Monday_31606-11_scenario_low_letter_50 : 29
# 794 : dm_Warmsen_Monday_31606-11_scenario_low_package_50 : 14
# 795 : dm_Warmsen_Monday_31606-11_scenario_low_others_50 : 2
# 796 : dm_Warmsen_Monday_31606-11_scenario_low_all_50 : 37
# 797 : dm_Warmsen_Monday_31606-11_scenario_medium_letter_50 : 56
# 798 : dm_Warmsen_Monday_31606-11_scenario_medium_package_50 : 17
# 799 : dm_Warmsen_Monday_31606-11_scenario_medium_others_50 : 2
# 800 : dm_Warmsen_Monday_31606-11_scenario_medium_all_50 : 68
# 801 : dm_Warmsen_Monday_31606-11_scenario_high_letter_50 : 66
# 802 : dm_Warmsen_Monday_31606-11_scenario_high_package_50 : 27
# 803 : dm_Warmsen_Monday_31606-11_scenario_high_others_50 : 2
# 804 : dm_Warmsen_Monday_31606-11_scenario_high_all_50 : 85
# 805 : dm_Warmsen_Monday_31606-14_scenario_low_letter_50 : 27
# 806 : dm_Warmsen_Monday_31606-14_scenario_low_package_50 : 10
# 807 : dm_Warmsen_Monday_31606-14_scenario_low_others_50 : 2
# 808 : dm_Warmsen_Monday_31606-14_scenario_low_all_50 : 34
# 809 : dm_Warmsen_Monday_31606-14_scenario_medium_letter_50 : 37
# 810 : dm_Warmsen_Monday_31606-14_scenario_medium_package_50 : 34
# 811 : dm_Warmsen_Monday_31606-14_scenario_medium_others_50 : 2
# 812 : dm_Warmsen_Monday_31606-14_scenario_medium_all_50 : 67
# 813 : dm_Warmsen_Monday_31606-14_scenario_high_letter_50 : 65
# 814 : dm_Warmsen_Monday_31606-14_scenario_high_package_50 : 35
# 815 : dm_Warmsen_Monday_31606-14_scenario_high_others_50 : 2
# 816 : dm_Warmsen_Monday_31606-14_scenario_high_all_50 : 93
# 817 : dm_Warmsen_Monday_31606-13_scenario_low_letter_50 : 36
# 818 : dm_Warmsen_Monday_31606-13_scenario_low_package_50 : 12
# 819 : dm_Warmsen_Monday_31606-13_scenario_low_others_50 : 2
# 820 : dm_Warmsen_Monday_31606-13_scenario_low_all_50 : 44
# 821 : dm_Warmsen_Monday_31606-13_scenario_medium_letter_50 : 43
# 822 : dm_Warmsen_Monday_31606-13_scenario_medium_package_50 : 20
# 823 : dm_Warmsen_Monday_31606-13_scenario_medium_others_50 : 2
# 824 : dm_Warmsen_Monday_31606-13_scenario_medium_all_50 : 58
# 825 : dm_Warmsen_Monday_31606-13_scenario_high_letter_50 : 60
# 826 : dm_Warmsen_Monday_31606-13_scenario_high_package_50 : 31
# 827 : dm_Warmsen_Monday_31606-13_scenario_high_others_50 : 2
# 828 : dm_Warmsen_Monday_31606-13_scenario_high_all_50 : 81
# 829 : dm_Warmsen_Monday_31600-04_scenario_low_letter_50 : 12
# 830 : dm_Warmsen_Monday_31600-04_scenario_low_package_50 : 6
# 831 : dm_Warmsen_Monday_31600-04_scenario_low_others_50 : 1
# 832 : dm_Warmsen_Monday_31600-04_scenario_low_all_50 : 17
# 833 : dm_Warmsen_Monday_31600-04_scenario_medium_letter_50 : 29
# 834 : dm_Warmsen_Monday_31600-04_scenario_medium_package_50 : 21
# 835 : dm_Warmsen_Monday_31600-04_scenario_medium_others_50 : 1
# 836 : dm_Warmsen_Monday_31600-04_scenario_medium_all_50 : 48
# 837 : dm_Warmsen_Monday_31600-04_scenario_high_letter_50 : 39
# 838 : dm_Warmsen_Monday_31600-04_scenario_high_package_50 : 22
# 839 : dm_Warmsen_Monday_31600-04_scenario_high_others_50 : 1
# 840 : dm_Warmsen_Monday_31600-04_scenario_high_all_50 : 57
# 841 : dm_Warmsen_Saturday_31603-06_scenario_low_letter_50 : 178
# 842 : dm_Warmsen_Saturday_31603-06_scenario_low_package_50 : 25
# 843 : dm_Warmsen_Saturday_31603-06_scenario_low_others_50 : 102
# 844 : dm_Warmsen_Saturday_31603-06_scenario_low_all_50 : 233
# 845 : dm_Warmsen_Saturday_31603-06_scenario_medium_letter_50 : 276
# 846 : dm_Warmsen_Saturday_31603-06_scenario_medium_package_50 : 57
# 847 : dm_Warmsen_Saturday_31603-06_scenario_medium_others_50 : 164
# 848 : dm_Warmsen_Saturday_31603-06_scenario_medium_all_50 : 339
# 849 : dm_Warmsen_Saturday_31603-06_scenario_high_letter_50 : 324
# 850 : dm_Warmsen_Saturday_31603-06_scenario_high_package_50 : 87
# 851 : dm_Warmsen_Saturday_31603-06_scenario_high_others_50 : 212
# 852 : dm_Warmsen_Saturday_31603-06_scenario_high_all_50 : 369
# 853 : dm_Warmsen_Saturday_31600-01_scenario_low_letter_50 : 178
# 854 : dm_Warmsen_Saturday_31600-01_scenario_low_package_50 : 32
# 855 : dm_Warmsen_Saturday_31600-01_scenario_low_others_50 : 87
# 856 : dm_Warmsen_Saturday_31600-01_scenario_low_all_50 : 228
# 857 : dm_Warmsen_Saturday_31600-01_scenario_medium_letter_50 : 244
# 858 : dm_Warmsen_Saturday_31600-01_scenario_medium_package_50 : 54
# 859 : dm_Warmsen_Saturday_31600-01_scenario_medium_others_50 : 171
# 860 : dm_Warmsen_Saturday_31600-01_scenario_medium_all_50 : 306
# 861 : dm_Warmsen_Saturday_31600-01_scenario_high_letter_50 : 293
# 862 : dm_Warmsen_Saturday_31600-01_scenario_high_package_50 : 74
# 863 : dm_Warmsen_Saturday_31600-01_scenario_high_others_50 : 212
# 864 : dm_Warmsen_Saturday_31600-01_scenario_high_all_50 : 342
# 865 : dm_Warmsen_Saturday_31606-12_scenario_low_letter_50 : 164
# 866 : dm_Warmsen_Saturday_31606-12_scenario_low_package_50 : 34
# 867 : dm_Warmsen_Saturday_31606-12_scenario_low_others_50 : 90
# 868 : dm_Warmsen_Saturday_31606-12_scenario_low_all_50 : 223
# 869 : dm_Warmsen_Saturday_31606-12_scenario_medium_letter_50 : 237
# 870 : dm_Warmsen_Saturday_31606-12_scenario_medium_package_50 : 53
# 871 : dm_Warmsen_Saturday_31606-12_scenario_medium_others_50 : 179
# 872 : dm_Warmsen_Saturday_31606-12_scenario_medium_all_50 : 318
# 873 : dm_Warmsen_Saturday_31606-12_scenario_high_letter_50 : 300
# 874 : dm_Warmsen_Saturday_31606-12_scenario_high_package_50 : 86
# 875 : dm_Warmsen_Saturday_31606-12_scenario_high_others_50 : 223
# 876 : dm_Warmsen_Saturday_31606-12_scenario_high_all_50 : 359
# 877 : dm_Warmsen_Saturday_31600-02_scenario_low_letter_50 : 156
# 878 : dm_Warmsen_Saturday_31600-02_scenario_low_package_50 : 39
# 879 : dm_Warmsen_Saturday_31600-02_scenario_low_others_50 : 101
# 880 : dm_Warmsen_Saturday_31600-02_scenario_low_all_50 : 234
# 881 : dm_Warmsen_Saturday_31600-02_scenario_medium_letter_50 : 220
# 882 : dm_Warmsen_Saturday_31600-02_scenario_medium_package_50 : 53
# 883 : dm_Warmsen_Saturday_31600-02_scenario_medium_others_50 : 169
# 884 : dm_Warmsen_Saturday_31600-02_scenario_medium_all_50 : 297
# 885 : dm_Warmsen_Saturday_31600-02_scenario_high_letter_50 : 263
# 886 : dm_Warmsen_Saturday_31600-02_scenario_high_package_50 : 70
# 887 : dm_Warmsen_Saturday_31600-02_scenario_high_others_50 : 226
# 888 : dm_Warmsen_Saturday_31600-02_scenario_high_all_50 : 341
# 889 : dm_Warmsen_Saturday_31604-09_scenario_low_letter_50 : 156
# 890 : dm_Warmsen_Saturday_31604-09_scenario_low_package_50 : 44
# 891 : dm_Warmsen_Saturday_31604-09_scenario_low_others_50 : 91
# 892 : dm_Warmsen_Saturday_31604-09_scenario_low_all_50 : 221
# 893 : dm_Warmsen_Saturday_31604-09_scenario_medium_letter_50 : 234
# 894 : dm_Warmsen_Saturday_31604-09_scenario_medium_package_50 : 66
# 895 : dm_Warmsen_Saturday_31604-09_scenario_medium_others_50 : 173
# 896 : dm_Warmsen_Saturday_31604-09_scenario_medium_all_50 : 314
# 897 : dm_Warmsen_Saturday_31604-09_scenario_high_letter_50 : 301
# 898 : dm_Warmsen_Saturday_31604-09_scenario_high_package_50 : 80
# 899 : dm_Warmsen_Saturday_31604-09_scenario_high_others_50 : 222
# 900 : dm_Warmsen_Saturday_31604-09_scenario_high_all_50 : 346
# 901 : dm_Warmsen_Saturday_31603-07_scenario_low_letter_50 : 170
# 902 : dm_Warmsen_Saturday_31603-07_scenario_low_package_50 : 32
# 903 : dm_Warmsen_Saturday_31603-07_scenario_low_others_50 : 106
# 904 : dm_Warmsen_Saturday_31603-07_scenario_low_all_50 : 234
# 905 : dm_Warmsen_Saturday_31603-07_scenario_medium_letter_50 : 255
# 906 : dm_Warmsen_Saturday_31603-07_scenario_medium_package_50 : 45
# 907 : dm_Warmsen_Saturday_31603-07_scenario_medium_others_50 : 167
# 908 : dm_Warmsen_Saturday_31603-07_scenario_medium_all_50 : 312
# 909 : dm_Warmsen_Saturday_31603-07_scenario_high_letter_50 : 301
# 910 : dm_Warmsen_Saturday_31603-07_scenario_high_package_50 : 88
# 911 : dm_Warmsen_Saturday_31603-07_scenario_high_others_50 : 212
# 912 : dm_Warmsen_Saturday_31603-07_scenario_high_all_50 : 350
# 913 : dm_Warmsen_Saturday_31604-10_scenario_low_letter_50 : 166
# 914 : dm_Warmsen_Saturday_31604-10_scenario_low_package_50 : 30
# 915 : dm_Warmsen_Saturday_31604-10_scenario_low_others_50 : 96
# 916 : dm_Warmsen_Saturday_31604-10_scenario_low_all_50 : 230
# 917 : dm_Warmsen_Saturday_31604-10_scenario_medium_letter_50 : 247
# 918 : dm_Warmsen_Saturday_31604-10_scenario_medium_package_50 : 66
# 919 : dm_Warmsen_Saturday_31604-10_scenario_medium_others_50 : 166
# 920 : dm_Warmsen_Saturday_31604-10_scenario_medium_all_50 : 304
# 921 : dm_Warmsen_Saturday_31604-10_scenario_high_letter_50 : 292
# 922 : dm_Warmsen_Saturday_31604-10_scenario_high_package_50 : 77
# 923 : dm_Warmsen_Saturday_31604-10_scenario_high_others_50 : 214
# 924 : dm_Warmsen_Saturday_31604-10_scenario_high_all_50 : 334
# 925 : dm_Warmsen_Saturday_31600-03_scenario_low_letter_50 : 168
# 926 : dm_Warmsen_Saturday_31600-03_scenario_low_package_50 : 31
# 927 : dm_Warmsen_Saturday_31600-03_scenario_low_others_50 : 88
# 928 : dm_Warmsen_Saturday_31600-03_scenario_low_all_50 : 213
# 929 : dm_Warmsen_Saturday_31600-03_scenario_medium_letter_50 : 234
# 930 : dm_Warmsen_Saturday_31600-03_scenario_medium_package_50 : 67
# 931 : dm_Warmsen_Saturday_31600-03_scenario_medium_others_50 : 148
# 932 : dm_Warmsen_Saturday_31600-03_scenario_medium_all_50 : 286
# 933 : dm_Warmsen_Saturday_31600-03_scenario_high_letter_50 : 281
# 934 : dm_Warmsen_Saturday_31600-03_scenario_high_package_50 : 78
# 935 : dm_Warmsen_Saturday_31600-03_scenario_high_others_50 : 210
# 936 : dm_Warmsen_Saturday_31600-03_scenario_high_all_50 : 321
# 937 : dm_Warmsen_Saturday_31603-05_scenario_low_letter_50 : 171
# 938 : dm_Warmsen_Saturday_31603-05_scenario_low_package_50 : 21
# 939 : dm_Warmsen_Saturday_31603-05_scenario_low_others_50 : 105
# 940 : dm_Warmsen_Saturday_31603-05_scenario_low_all_50 : 229
# 941 : dm_Warmsen_Saturday_31603-05_scenario_medium_letter_50 : 256
# 942 : dm_Warmsen_Saturday_31603-05_scenario_medium_package_50 : 57
# 943 : dm_Warmsen_Saturday_31603-05_scenario_medium_others_50 : 176
# 944 : dm_Warmsen_Saturday_31603-05_scenario_medium_all_50 : 315
# 945 : dm_Warmsen_Saturday_31603-05_scenario_high_letter_50 : 300
# 946 : dm_Warmsen_Saturday_31603-05_scenario_high_package_50 : 76
# 947 : dm_Warmsen_Saturday_31603-05_scenario_high_others_50 : 226
# 948 : dm_Warmsen_Saturday_31603-05_scenario_high_all_50 : 340
# 949 : dm_Warmsen_Saturday_31603-08_scenario_low_letter_50 : 149
# 950 : dm_Warmsen_Saturday_31603-08_scenario_low_package_50 : 32
# 951 : dm_Warmsen_Saturday_31603-08_scenario_low_others_50 : 87
# 952 : dm_Warmsen_Saturday_31603-08_scenario_low_all_50 : 203
# 953 : dm_Warmsen_Saturday_31603-08_scenario_medium_letter_50 : 249
# 954 : dm_Warmsen_Saturday_31603-08_scenario_medium_package_50 : 47
# 955 : dm_Warmsen_Saturday_31603-08_scenario_medium_others_50 : 140
# 956 : dm_Warmsen_Saturday_31603-08_scenario_medium_all_50 : 294
# 957 : dm_Warmsen_Saturday_31603-08_scenario_high_letter_50 : 280
# 958 : dm_Warmsen_Saturday_31603-08_scenario_high_package_50 : 72
# 959 : dm_Warmsen_Saturday_31603-08_scenario_high_others_50 : 198
# 960 : dm_Warmsen_Saturday_31603-08_scenario_high_all_50 : 315
# 961 : dm_Warmsen_Saturday_31606-11_scenario_low_letter_50 : 160
# 962 : dm_Warmsen_Saturday_31606-11_scenario_low_package_50 : 31
# 963 : dm_Warmsen_Saturday_31606-11_scenario_low_others_50 : 100
# 964 : dm_Warmsen_Saturday_31606-11_scenario_low_all_50 : 219
# 965 : dm_Warmsen_Saturday_31606-11_scenario_medium_letter_50 : 222
# 966 : dm_Warmsen_Saturday_31606-11_scenario_medium_package_50 : 54
# 967 : dm_Warmsen_Saturday_31606-11_scenario_medium_others_50 : 156
# 968 : dm_Warmsen_Saturday_31606-11_scenario_medium_all_50 : 276
# 969 : dm_Warmsen_Saturday_31606-11_scenario_high_letter_50 : 269
# 970 : dm_Warmsen_Saturday_31606-11_scenario_high_package_50 : 67
# 971 : dm_Warmsen_Saturday_31606-11_scenario_high_others_50 : 204
# 972 : dm_Warmsen_Saturday_31606-11_scenario_high_all_50 : 308
# 973 : dm_Warmsen_Saturday_31606-14_scenario_low_letter_50 : 137
# 974 : dm_Warmsen_Saturday_31606-14_scenario_low_package_50 : 29
# 975 : dm_Warmsen_Saturday_31606-14_scenario_low_others_50 : 69
# 976 : dm_Warmsen_Saturday_31606-14_scenario_low_all_50 : 183
# 977 : dm_Warmsen_Saturday_31606-14_scenario_medium_letter_50 : 201
# 978 : dm_Warmsen_Saturday_31606-14_scenario_medium_package_50 : 48
# 979 : dm_Warmsen_Saturday_31606-14_scenario_medium_others_50 : 135
# 980 : dm_Warmsen_Saturday_31606-14_scenario_medium_all_50 : 255
# 981 : dm_Warmsen_Saturday_31606-14_scenario_high_letter_50 : 242
# 982 : dm_Warmsen_Saturday_31606-14_scenario_high_package_50 : 72
# 983 : dm_Warmsen_Saturday_31606-14_scenario_high_others_50 : 195
# 984 : dm_Warmsen_Saturday_31606-14_scenario_high_all_50 : 284
# 985 : dm_Warmsen_Saturday_31606-13_scenario_low_letter_50 : 134
# 986 : dm_Warmsen_Saturday_31606-13_scenario_low_package_50 : 38
# 987 : dm_Warmsen_Saturday_31606-13_scenario_low_others_50 : 85
# 988 : dm_Warmsen_Saturday_31606-13_scenario_low_all_50 : 179
# 989 : dm_Warmsen_Saturday_31606-13_scenario_medium_letter_50 : 200
# 990 : dm_Warmsen_Saturday_31606-13_scenario_medium_package_50 : 39
# 991 : dm_Warmsen_Saturday_31606-13_scenario_medium_others_50 : 137
# 992 : dm_Warmsen_Saturday_31606-13_scenario_medium_all_50 : 247
# 993 : dm_Warmsen_Saturday_31606-13_scenario_high_letter_50 : 230
# 994 : dm_Warmsen_Saturday_31606-13_scenario_high_package_50 : 58
# 995 : dm_Warmsen_Saturday_31606-13_scenario_high_others_50 : 170
# 996 : dm_Warmsen_Saturday_31606-13_scenario_high_all_50 : 263
# 997 : dm_Warmsen_Saturday_31600-04_scenario_low_letter_50 : 120
# 998 : dm_Warmsen_Saturday_31600-04_scenario_low_package_50 : 24
# 999 : dm_Warmsen_Saturday_31600-04_scenario_low_others_50 : 66
# 1000 : dm_Warmsen_Saturday_31600-04_scenario_low_all_50 : 159
# 1001 : dm_Warmsen_Saturday_31600-04_scenario_medium_letter_50 : 169
# 1002 : dm_Warmsen_Saturday_31600-04_scenario_medium_package_50 : 53
# 1003 : dm_Warmsen_Saturday_31600-04_scenario_medium_others_50 : 121
# 1004 : dm_Warmsen_Saturday_31600-04_scenario_medium_all_50 : 223
# 1005 : dm_Warmsen_Saturday_31600-04_scenario_high_letter_50 : 215
# 1006 : dm_Warmsen_Saturday_31600-04_scenario_high_package_50 : 51
# 1007 : dm_Warmsen_Saturday_31600-04_scenario_high_others_50 : 161
# 1008 : dm_Warmsen_Saturday_31600-04_scenario_high_all_50 : 248
# CPU times: user 1min 20s, sys: 9.93 s, total: 1min 30s
# Wall time: 8min 51s

# %%
# result_region

name = 'warmsen_instances'

pickle.dump(result_region, open('/content/drive/Shareddrives/Private Unlimited Drive #1/DDS/Analytics Project/Coding/Results' + '/' + "%s.p"%name, "wb"))

# %%
warmze_instances= pickle.load(open("/content/drive/Shareddrives/Private Unlimited Drive #1/DDS/Analytics Project/Coding/Results/warmsen_instances.p", "rb"))

# %%
warmze_instances.keys()
# Out:
# dict_keys(['Tuesday', 'Thursday', 'Friday', 'Wednesday', 'Monday', 'Saturday'])

# %%
warmze_instances['Saturday'].keys()
# Out:
# dict_keys(['31603-06', '31600-01', '31606-12', '31600-02', '31604-09', '31603-07', '31604-10', '31600-03', '31603-05', '31603-08', '31606-11', '31606-14', '31606-13', '31600-04'])

# %%
warmze_instances['Saturday']['31603-06'].keys()
# Out:
# dict_keys(['letter_low', 'package_low', 'others_low', 'all_low', 'letter_medium', 'package_medium', 'others_medium', 'all_medium', 'letter_high', 'package_high', 'others_high', 'all_high'])

# %%
warmze_instances['Saturday']['31603-06']['all_high'].keys()
# Out:
# dict_keys(['dm', 'map', 'start_end_points', 'volume'])

# %%
# len(warmze_instances['Saturday']['31603-06']['all_high']['dm'])
# warmze_instances['Saturday']['31603-06']['all_high']['map']
# warmze_instances['Saturday']['31603-06']['letter_high']['start_end_points']
warmze_instances['Saturday']['31603-06']['letter_high']['volume']
# Out:
# 736

# %%
datetime.datetime.now()
# Out:
# datetime.datetime(2023, 5, 28, 19, 46, 29, 707498)

# %% [markdown]
# #Default Tours

# %%
# %%time

region_list = ['Warmsen', 'Uerze', 'Hannover 92']

all_default = {}

for region in region_list:
  region_default = get_region_all_default_routes(region_chosen = region, path_save = '/content/drive/Shareddrives/Private Unlimited Drive #1/DDS/Analytics Project/Coding/Default Tours')
  all_default[region] = region_default
# Out:
# CPU times: user 31.2 s, sys: 719 ms, total: 31.9 s
# Wall time: 53.5 s

# %%
all_default.keys()
# Out:
# dict_keys(['Warmsen', 'Uerze', 'Hannover 92'])

# %%
pickle.dump(all_default, open("/content/drive/Shareddrives/Private Unlimited Drive #1/DDS/Analytics Project/Coding/Results/all_default_tours.p", "wb"))

# %%
all_default['Uerze'].keys()
# Out:
# dict_keys(['31311-04', '31311-24', '31311-25', '31311-31', '31311-03', '31311-07', '31311-42', '31311-62', '31311-51', '31311-21', '31311-05', '31311-08', '31311-61', '31311-01', '31311-81', '31311-22', '31311-02'])

# %%
all_default['Warmsen'].keys()
# Out:
# dict_keys(['31603-06', '31604-10', '31600-01', '31603-08', '31606-12', '31606-11', '31600-02', '31600-03', '31600-04', '31603-05', '31603-07', '31606-13', '31604-09', '31606-14'])

# %%
all_default['Warmsen']['31606-14'].keys()
# Out:
# dict_keys(['default_route', 'mapping', 'route_cost'])

# %%
all_default['Warmsen']['31606-14']['route_cost']
# Out:
# 30342.02

# %%
30342/3600
# Out:
# 8.428333333333333
