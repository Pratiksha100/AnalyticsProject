# %%
# %autosave 0
# Out:
# Autosave disabled

# %%
# %pip install git+https://github.com/jvkersch/pyconcorde
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting git+https://github.com/jvkersch/pyconcorde
#   Cloning https://github.com/jvkersch/pyconcorde to /tmp/pip-req-build-i1c_uyal
#   Running command git clone --filter=blob:none --quiet https://github.com/jvkersch/pyconcorde /tmp/pip-req-build-i1c_uyal
#   Resolved https://github.com/jvkersch/pyconcorde to commit 71232a8043a3ca79a7a6da2f48e9d89d81d37163
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: cython>=0.22.0 in /usr/local/lib/python3.10/dist-packages (from pyconcorde==0.1.0) (0.29.34)
# Requirement already satisfied: numpy>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from pyconcorde==0.1.0) (1.22.4)
# Building wheels for collected packages: pyconcorde
#   Building wheel for pyconcorde (pyproject.toml) ... done
#   Created wheel for pyconcorde: filename=pyconcorde-0.1.0-cp310-cp310-linux_x86_64.whl size=2494568 sha256=b8d9749ceb5303fb99e29956963a33513e00f1b1572422887fd5f31e43b2998c
#   Stored in directory: /tmp/pip-ephem-wheel-cache-08df_52w/wheels/be/9f/eb/e4f95e06e62f057a045679e4940e536d1b251d1ab4859c6dcc
# Successfully built pyconcorde
# Installing collected packages: pyconcorde
# Successfully installed pyconcorde-0.1.0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# install tweak file
# %cp '/content/drive/Shareddrives/Private Unlimited Drive #1/DDS/Analytics Project/Concorde/concorde_class.py' '/content'
# %cp '/content/drive/Shareddrives/Private Unlimited Drive #1/DDS/Analytics Project/Concorde/test.py' '/content'
# %cp '/content/drive/Shareddrives/Private Unlimited Drive #1/DDS/Analytics Project/Concorde/concorde_to_replace/tsp.py' '/usr/local/lib/python3.10/dist-packages/concorde'
# %cp '/content/drive/Shareddrives/Private Unlimited Drive #1/DDS/Analytics Project/Concorde/concorde_to_replace/util.py' '/usr/local/lib/python3.10/dist-packages/concorde'

# %%
import os
import pandas as pd
import numpy as np
import re
import collections
import pickle
from ast import literal_eval
import random
import scipy
import math
from concorde_class import Concorde
import datetime
import subprocess

# %% [markdown]
# #Define Path of Files

# %%
# Out:
# Mounted at /content/drive

# %%
# path for the 'Data' folder provided by DP
dir_loc = '/content/drive/Shareddrives/Private Unlimited Drive #1/DDS/Analytics Project/AOP_DP_Analytics/Data'

# %% [markdown]
# #Functions

# %%
# generate workflow for file storage /  instance creation

# %% [markdown]
# ## Volume Matrix Manipulation and Poisson Instances Generation

# %%
# create dataframes for a region everyday

def generate_region_volume(region_name):
  # path of folder
  dir_region_instances = dir_loc + '/Instances/' + region_name
  dir_region_volume = dir_loc + '/Volumes/'
  # dir_region_districts = dir_region_instances + '/Districts'

  # load post_object-to-route_pos_id and post_point-to-post_object files 
  po_file = pd.read_csv(dir_region_instances + '/post_order_id_mapping.dat', sep='\t', names=('PostObjectId', 'RoutePosID'))
  pp_file = pd.read_csv(dir_region_instances + '/post_point_information.dat', sep='\t', names=('PostPointId', 'PostObjectId'))

  # pp_file adjustment by splitting list of post object ids
  pp_file['PostObjectId'] = pp_file['PostObjectId'].apply(literal_eval)
  pp_file = pp_file.explode('PostObjectId', ignore_index=True)

  # complete  post object list-district mapping
  region_district_df = generate_region_district(region_name = region_name)
  region_district_df.rename(columns = {'PostObjectID' : 'PostObjectId'}, inplace = True)

  # list of volume file paths
  day_names = []
  vol_path_list = []
  vol_day_map = {}
  day_map = {'mo' : 'Monday',
             'di' : 'Tuesday',
             'mi' : 'Wednesday',
             'do' : 'Thursday',
             'fr' : 'Friday',
             'sa' : 'Saturday'}

  for filename in os.listdir(dir_region_volume):
    vol_path_list.append(dir_region_volume + filename)
    day = filename[-6:-4]
    vol_day_map[filename] = day_map[day]

  # store dataframes of a region, map with post object id
  region_vol_day_dict = {}
  for vol_path in vol_path_list:
    vol_df = pd.read_csv(vol_path, sep = ';')
    vol_df.rename(columns = {'BRIEFE' : 'LETTERS',
                             'PAKETE' : 'PACKAGES',
                             'SONSTIGE' : 'OTHERS',
                             'ROUTEPOS_ID' : 'RoutePosID'},
                  inplace = True)
    
    # combining files to a complete table for a region
    vol_po_df = pd.merge(po_file, vol_df, on = 'RoutePosID', how = 'left')
    vol_po_df = pd.merge(pp_file, vol_po_df, on='PostObjectId', how='right')
    vol_po_df = pd.merge(region_district_df, vol_po_df, on='PostObjectId', how='right')

    # store dataframes in dict
    day_key = vol_day_map[vol_path[-18:]]
    region_vol_day_dict[day_key] = vol_po_df
    
  return region_vol_day_dict

# %%
def generate_region_district(region_name):
  district_path = dir_region_instances = dir_loc + '/Instances/' + region_name + '/Districts'
  region_districts_list = []

  for filename in os.listdir(district_path):
    file_var = re.sub('.dat', '', filename)
    file_district = pd.read_csv(district_path + '/' + filename, sep='\t', skiprows = [0,1],
                                names=('PostObjectID', 'dum_1', 'dum_2', 'dum_3', 'dum_4', 'dum_5')
                                # usecols = [0]
                                )
    file_district['district'] = file_var
    region_districts_list.append(file_district)

  region_districts_df = pd.concat(region_districts_list, ignore_index = True)
  region_districts_df.drop(['dum_1', 'dum_2', 'dum_3', 'dum_4', 'dum_5'], axis = 1, inplace = True)
  
  return region_districts_df

# %%
# generate instances

def generate_instances(region_vol_day, scenario_type, scenario_method, scenario_number, growth_factor):
  # df = region_vol_day.copy() #.copy() used to avoid recopying on the original dataframe
  df = region_vol_day

  sce_letters = 'scenario_' + str(scenario_number) + '_letter'
  sce_packages = 'scenario_' + str(scenario_number) + '_package'
  sce_others = 'scenario_' + str(scenario_number) + '_others'

  df[sce_letters] = df['LETTERS'].apply(lambda x :scenario_type(pos_delivery = x, method = scenario_method, rate_pct = growth_factor ))
  df[sce_packages] = df['PACKAGES'].apply(lambda x :scenario_type(pos_delivery = x, method = scenario_method, rate_pct = growth_factor))
  df[sce_others] = df['OTHERS'].apply(lambda x :scenario_type(pos_delivery = x, method = scenario_method, rate_pct = growth_factor))

  sce_all = 'scenario_' + str(scenario_number) + '_all'
  df[sce_all] = df[sce_letters] + df[sce_packages] + df[sce_others]

  return df

# %%
# generate real instances based on poisson

def random_poisson_instances(pos_delivery, method, rate_pct):
  rate = rate_pct/100
  rng = np.random.default_rng()
  poisson_dist = rng.poisson(lam = pos_delivery * (1 + rate), size = 52)

  if method == 'random':
    return random.choice(poisson_dist)
  if method == 'mode':
    return scipy.stats.mode(poisson_dist, keepdims = True)[0][0]
  else:
    return 'only options : [random, mode]'

# %%
# get start and end node for a district

def start_end_points(region_name, district, df_day):
    df_day_district = df_day[df_day['district'] == district]

    # get start and end node
    district_path = dir_loc + '/Instances/' + region_name + '/Districts/' + district + '.dat'
    rows_needed = [1]
    file_district = pd.read_csv(district_path, sep='\t', skiprows = lambda x : x not in rows_needed,
                                names=('dum_0', 'start_point', 'end_point', 'dum_1', 'dum_2', 'dum_3', 'dum_4', 'dum_5', 'dum_6')
                                )
    start_point = file_district['start_point'][0]
    end_point = file_district['end_point'][0]

    points = [start_point, end_point]

    return points

# %%
# generate original distance matrix and mapping for districts

def ori_generate_distance_matrix_map(region_name, save_loc):
      i = 1

      dir_region = save_loc + '/' + region_name + '_original'
      print(dir_region)
      if not os.path.exists(dir_region):
        os.mkdir(dir_region)
        print('dir_region doesnt exist')

      # dir_region_ori = dir_region + '/original'
      # print(dir_region_ori)
      # if not os.path.exists(dir_region):
      #   os.mkdir(dir_region)
      #   print('dir_ori doesnt exist')

      ori_dm_map_dict_region = {}
      # get distance file and dataframes
      distance_path = dir_loc + '/Instances/' + region_name + '/distances/'
      for filename in os.listdir(distance_path):
        ori_dm_map_dict_district = {}
        district_name = re.sub('.dat', '', filename)
        district_name = re.sub('distances_', '', district_name)

        district_distance = pd.read_csv(distance_path + filename,
                                    names=['pp_1', 'pp_2', 'dist']
                                    )
      
        distance_matrix_df = district_distance.pivot(index = 'pp_1', columns = 'pp_2', values = 'dist')

        # distance matrix
        distance_matrix_array = distance_matrix_df.to_numpy()
        distance_matrix_array = distance_matrix_array.tolist()
        ori_dm_map_dict_district['dm'] = distance_matrix_array
        pickle.dump(distance_matrix_array, open(dir_region + '/dm_' + "%s.p"%district_name, "wb"))

        # node mapping
        map_val = list(range(0, len(distance_matrix_df)))
        nodes = distance_matrix_df.index.values.tolist()
        mapping = dict(zip(map_val, nodes))
        ori_dm_map_dict_district['map'] = mapping
        pickle.dump(mapping, open(dir_region + '/map_' + "%s.p"%district_name, "wb"))

        ori_dm_map_dict_region[district_name] = ori_dm_map_dict_district
        print(i, ':', district_name, ':', len(distance_matrix_array))
        i = i+1

      return ori_dm_map_dict_region

# %%
# generate distance matrix and mapping for a scenario

def generate_distance_matrix_map(region_name, df_day_district, points, sce_col, district):
      scenario = sce_col

      col_use = ['PostPointId']
      col_use.append(scenario)
      df_day_district_scenario = df_day_district[col_use]
      
      # removing nodes with zero demand
      df_day_district_scenario_filtered = df_day_district_scenario[df_day_district_scenario[scenario] != 0]
      pp_id_day_district_scenario = df_day_district_scenario_filtered['PostPointId'].unique().tolist()
      
      # add start and end node if not in node list yet
      for point in points:
        if point not in pp_id_day_district_scenario:
          pp_id_day_district_scenario.append(point)

      # get distance file and dataframes
      distance_path = dir_loc + '/Instances/' + region_name + '/distances'
      district_distance = pd.read_csv(distance_path + '/distances_' + district + '.dat',
                                  names=['pp_1', 'pp_2', 'dist']
                                  )
      # remove unused postpoints
      district_distance_filtered = district_distance[(district_distance['pp_1'].isin(pp_id_day_district_scenario)) & (district_distance['pp_2'].isin(pp_id_day_district_scenario))]
      distance_matrix_df = district_distance_filtered.pivot(index = 'pp_1', columns = 'pp_2', values = 'dist')

      # distance matrix
      distance_matrix_array = distance_matrix_df.to_numpy()
      distance_matrix_array = distance_matrix_array.tolist()

      # node mapping
      map_val = list(range(0, len(distance_matrix_df)))
      nodes = distance_matrix_df.index.values.tolist()
      mapping = dict(zip(map_val, nodes))

      return distance_matrix_array, mapping

# %%
def create_dm_map(region, data, save_loc, rate):
  i = 1
  dir_region = save_loc + '/' + region
  if not os.path.exists(dir_region):
    os.mkdir(dir_region)


  # filter by day
  result_day = {}
  for day in data.keys():
    df_day = data[day]

    # filter by district
    result_district = {}
    for district in df_day['district'].value_counts().index.tolist():
      df_day_district = df_day[df_day['district'] == district]

      scenario_list = df_day_district.columns.tolist()[7:]

      # get start and end node
      points = start_end_points(region_name = region, district = district, df_day = df_day)
      
      # filter by scenario
      result_mail_demand = {}
      for scenario in scenario_list:
        # dir of mail
        mail_names = ['letter', 'package', 'others', 'all']
        for mail in mail_names:
          if mail in scenario:
            mail_current = mail

        # dir of demand
        demand_types = ['low', 'medium', 'high']
        for demand in demand_types:
          if demand in scenario:
            demand_current = demand

        # generate mapping and distance matrix
        distance_matrix, mapping = generate_distance_matrix_map(region_name = region, df_day_district = df_day_district,
                                                                points = points, sce_col = scenario, district = district)
        distance_matrix_name = 'dm_' + region + '_' + day + '_' + district + '_' + scenario + '_' + str(rate)
        mapping_name = 'map_' + region + '_' + day + '_' + district + '_' + scenario + '_' + str(rate)
        pickle.dump(distance_matrix, open(dir_region + '/' + "%s.p"%distance_matrix_name, "wb"))
        pickle.dump(mapping, open(dir_region + '/' + "%s.p"%mapping_name, "wb"))

        # log update
        print(i, ':', distance_matrix_name, ':', distance_matrix.shape)
        i = i+1

        result_end = {}
        result_end['dm'] = distance_matrix
        result_end['map'] = mapping
        
        mail_demand = mail_current + '_' + demand_current
        result_mail_demand[mail_demand] = result_end
      result_district[district] = result_mail_demand
    result_day[day] = result_district

  return result_day

# %%
# exact solution with concord
# no mapping yet

def concord_solver(distance_matrix):
  concorde = Concorde()
  concorde_sol = concorde.run_ProbATSP(distance_matrix)
  return concorde.route, concorde.optimal_value

# %%
# heuristic solution with LKH solver
# no mapping yet

class lkh:
    def __init__(self , dist_mat_pic_file):
        self.dist_mat_pic_file = dist_mat_pic_file
        self.dist_mat_file_name = dist_mat_pic_file.split(".")[0]
        print(self.dist_mat_file_name)

    def solve(self):
        '''
        solves the TSP instance using .exe file
        '''
        # Generate the .par file
        self.generate_parameter_file(self.dist_mat_file_name)

        # Generate the .atsp file
        dist_mat = self.read_pickle(self.dist_mat_pic_file)
        self.generate_atsp_file(dist_mat , self.dist_mat_file_name)

        try :    
            # Replace "E3k.0.par" with the actual parameter for your .exe file
            result = subprocess.check_output(["LKH-2.exe", f"{self.dist_mat_file_name}.par", "-S" , f"{self.dist_mat_file_name}_start.txt" ], stdin=subprocess.DEVNULL , timeout = 300)
            #result = subprocess.check_output(["LKH-2.exe", f"{self.dist_mat_file_name}.par", "-S" , f"{self.dist_mat_file_name}_start.txt" ], stdin=subprocess.DEVNULL , timeout = 300)
        
        except subprocess.TimeoutExpired:
            print("Execution timed out. Terminating the process.")
            # print(output)
        
        result_file_name = self.dist_mat_file_name + '.txt'
        print("Result is saved in : ",result_file_name)
        length , tour_section = self.get_obj_val_and_tour(result_file_name)
        length_rescaled = length/100

        print("Objective function value : ", length_rescaled)
        print("The routing : " , tour_section)

        return length_rescaled, tour_section

    
    def get_obj_val_and_tour(self , tour_file):
        """
        Extracts the length and tour section from a tour file.

        Args:
            tour_file (str): Path to the tour file.

        Returns:
            tuple: A tuple containing the length and tour section as a list.
        """
        length = None
        tour_section = []

        with open(tour_file, "r") as file:
            for line in file:
                line = line.strip()

                if line.startswith("COMMENT : Length"):
                    length = int(line.split("=")[1].strip())
                elif line == "TOUR_SECTION":
                    # Start reading the tour section
                    for tour_line in file:
                        tour_line = tour_line.strip()
                        if tour_line == "-1":
                            # End of tour section
                            break
                        tour_section.append(int(tour_line))

        return length, tour_section


    def get_obj_val(self , output):
        '''
        returns the objective value from the  long output value
        '''
        # Assuming `output` contains the captured output
        cost_min_match = re.search(r'Cost\.min = (\d+)', output)

        if cost_min_match:
            cost_min_value = int(cost_min_match.group(1))
            return cost_min_value
        else:
            print("Cost.min not found in the output.")
            return 0    
    
    def get_routing(self , filename):
        '''
        returns the routing in a numpy array
        '''
        start_keyword = 'TOUR_SECTION'
        end_keyword = '-1'
        with open(filename, 'r') as file:
            lines = []
            read_flag = False
            for line in file:
                if start_keyword in line:
                    read_flag = True
                    continue  # skip this line
                if read_flag:
                        if end_keyword in line:
                            read_flag = False
                            break
                        else:
                            lines.append(line.strip())

        lines = np.array(lines)
        return lines
    
    def generate_parameter_file(self , filename):
        runs = 1
        filename_atsp = filename + ".atsp"
        filename_txt = filename + ".txt"  
        filename_par = filename + ".par"

        with open(filename_par, 'w') as f:
            f.write(f"PROBLEM_FILE = {filename_atsp}\n")
            f.write(f"OUTPUT_TOUR_FILE = {filename_txt}\n")
            f.write(f"OPTIMUM = 40634081 \n")
            f.write(f"INITIAL_PERIOD = 1000 \n")
            f.write(f"MAX_CANDIDATES = 6 \n")
            f.write(f"MAX_TRIALS = 1000 \n")
            f.write(f"MOVE_TYPE = 6 \n")
            f.write(f"PATCHING_C = 6 \n")
            f.write(f"PATCHING_A = 5 \n")
            f.write(f"RECOMBINATION = GPX2 \n")
            f.write(f"RUNS = {runs} \n")

    
    def multiply_round_up(self , lst):
        '''
        input : list of lists having non integral values
        output : list of lists having integral values.
        Function to multiply, round up numbers,  and return as integers
        '''
        rounded_lst = np.rint(np.array(lst)*100).astype(int)
        rounded_lst = rounded_lst.tolist()
        return rounded_lst


    def read_pickle(self,pickle_path):
        # Open the pickle file in read-binary mode
        with open(pickle_path, 'rb') as f:
            # Load the object from the pickle file
            pic_obj = pickle.load(f)
        pic_obj = self.multiply_round_up(pic_obj)
        return pic_obj
    
    def generate_atsp_file(self , dist_mat, filename):   
        '''
        input : 
        a symmentric matrix  
        directory of a .tsp file you want to generate
        number of cities in the TSP

        Output : 
        a .tsp file generated in the filename directory
        '''
        # Defining the number of cities
        num_cities = len(dist_mat)

        # Write the coordinates to a .atsp file
        # fname = filename.split("/")[-1].split(".")[0]
        fname = filename 
        with open(filename+".atsp", 'w') as f:
            f.write(f"NAME: {fname}\n")
            # f.write("COMMENT: Randomly generated TSP instance\n")
            f.write("TYPE: TSP (M.~Hofmeister)\n")
            f.write(f"DIMENSION: {num_cities}\n") #becase the distance matrix doubles in size when converted to a symmentric instance
            f.write("EDGE_WEIGHT_TYPE: EXPLICIT\n")
            f.write("EDGE_WEIGHT_FORMAT: FULL_MATRIX\n")
            # f.write("NODE_COORD_SECTION\n")
            f.write("DISPLAY_DATA_TYPE: NO_DISPLAY\n")
            f.write("EDGE_WEIGHT_SECTION\n")
            for i in range(len(dist_mat)):
                for j in range(len(dist_mat)):
                    f.write(f'{str(dist_mat[i][j])}\t')
                f.write("\n")
            f.write("EOF\n")

# %%
lst = [[0.456] , [0.1156], [6.3]]
# lst = np.array(np.array([0.456 , 0.1156, 6.3]))

rounded_lst = np.rint(np.array(lst)*100).astype(int)
rounded_lst = rounded_lst.tolist()
rounded_lst
# Out:
# [[46], [12], [630]]

# %% [markdown]
# #Process Examples (Using Functions)

# %%
# %%time
# ['Warmsen', 'Uerze', 'Hannover 92']

region_vol_day_dict = generate_region_volume(region_name = "Warmsen")
# Out:
# CPU times: user 11.4 s, sys: 1.2 s, total: 12.6 s
# Wall time: 28.5 s

# %%
region_vol_day_dict['Monday'].head()
# Out:
#   PostObjectId  district  PostPointId                        RoutePosID  \
# 0           16  31606-14           16  AD14E08623FF9F5AD2293E7DEDB4F4B1
# 1           17  31606-14           17  F48CB0CAB0BC117AE030007F0100574C
# 2           18  31606-14           16  F48CB0CAB0C7117AE030007F0100574C
# 3           19  31606-14           18  F48CB0CAB0C8117AE030007F0100574C
# 4           20  31606-14           19  069AE286923C1800E040400A09131416
#
#    LETTERS  PACKAGES  OTHERS
# 0     0.45  0.293333     0.0
# 1     0.45  0.293333     0.0
# 2     0.45  0.293333     0.0
# 3     0.00  0.000000     0.0
# 4     0.00  0.000000     0.0

# %%
# %%time
#Creating the complete dictionary of volumes for a region
warmsen_instances = {}

#INPUT Rate of mail change 
# rate in percentage
rate = 50
rate_mapping = {'low' : -rate, 'medium' : 0, 'high' : rate}

# create instances for one region
for key in region_vol_day_dict.keys():
  # create instances per day
  for key_rate in rate_mapping:
    dummy = generate_instances(region_vol_day = region_vol_day_dict[key],
                               scenario_type = random_poisson_instances,
                               scenario_method = 'random',
                               scenario_number = key_rate,
                               growth_factor = rate_mapping[key_rate])
  warmsen_instances[key] = dummy
# Out:
# CPU times: user 15 s, sys: 234 ms, total: 15.2 s
# Wall time: 15.5 s

# %%
warmsen_instances['Tuesday'].head()
# Out:
#   PostObjectId  district  PostPointId                        RoutePosID  \
# 0           16  31606-14           16  AD14E08623FF9F5AD2293E7DEDB4F4B1
# 1           17  31606-14           17  F48CB0CAB0BC117AE030007F0100574C
# 2           18  31606-14           16  F48CB0CAB0C7117AE030007F0100574C
# 3           19  31606-14           18  F48CB0CAB0C8117AE030007F0100574C
# 4           20  31606-14           19  069AE286923C1800E040400A09131416
#
#     LETTERS  PACKAGES    OTHERS  scenario_low_letter  scenario_low_package  \
# 0  5.796667      0.69  0.273333                    3                     0
# 1  5.796667      0.69  0.273333                    2                     0
# 2  5.796667      0.69  0.273333                    3                     1
# 3  0.000000      0.00  0.000000                    0                     0
# 4  0.000000      0.00  0.000000                    0                     0
#
#    scenario_low_others  scenario_low_all  scenario_medium_letter  \
# 0                    0                 3                       5
# 1                    0                 2                       1
# 2                    2                 6                       5
# 3                    0                 0                       0
# 4                    0                 0                       0
#
#    scenario_medium_package  scenario_medium_others  scenario_medium_all  \
# 0                        0                       0                    5
# 1                        0                       2                    3
# 2                        0                       0                    5
# 3                        0                       0                    0
# 4                        0                       0                    0
#
#    scenario_high_letter  scenario_high_package  scenario_high_others  \
# 0                    10                      1                     0
# 1                    11                      0                     0
# 2                     5                      1                     0
# 3                     0                      0                     0
# 4                     0                      0                     0
#
#    scenario_high_all
# 0                 11
# 1                 11
# 2                  6
# 3                  0
# 4                  0

# %%
print(warmsen_instances['Tuesday']['scenario_low_all'].sum())
print(warmsen_instances['Tuesday']['scenario_medium_all'].sum())
print(warmsen_instances['Tuesday']['scenario_high_all'].sum())
# Out:
# 4593
# 9279
# 13750

# %%
z = warmsen_instances['Tuesday']


print(z[z['district'] == '31606-14']['scenario_low_all'].sum())
print(z[z['district'] == '31606-14']['scenario_medium_all'].sum())
print(z[z['district'] == '31606-14']['scenario_high_all'].sum())
# Out:
# 262
# 566
# 859

# %%
# %%time

# growth_rate_map_50 = {'high' : 'inc_50', 'low' : 'dec_50', 'medium' : 'base'}

result_region = create_dm_map(region = 'Warmsen', data = warmsen_instances,
                              save_loc = '/content/drive/Shareddrives/Private Unlimited Drive #1/DDS/Analytics Project/Coding/',
                              rate = rate)
# Out:
# 1 : dm_Warmsen_Tuesday_31603-06_scenario_low_letter_50 : (148, 148)
# 2 : dm_Warmsen_Tuesday_31603-06_scenario_low_package_50 : (42, 42)
# 3 : dm_Warmsen_Tuesday_31603-06_scenario_low_others_50 : (125, 125)
# 4 : dm_Warmsen_Tuesday_31603-06_scenario_low_all_50 : (240, 240)
# 5 : dm_Warmsen_Tuesday_31603-06_scenario_medium_letter_50 : (243, 243)
# 6 : dm_Warmsen_Tuesday_31603-06_scenario_medium_package_50 : (63, 63)
# 7 : dm_Warmsen_Tuesday_31603-06_scenario_medium_others_50 : (168, 168)
# 8 : dm_Warmsen_Tuesday_31603-06_scenario_medium_all_50 : (319, 319)
# 9 : dm_Warmsen_Tuesday_31603-06_scenario_high_letter_50 : (292, 292)
# 10 : dm_Warmsen_Tuesday_31603-06_scenario_high_package_50 : (107, 107)
# 11 : dm_Warmsen_Tuesday_31603-06_scenario_high_others_50 : (240, 240)
# 12 : dm_Warmsen_Tuesday_31603-06_scenario_high_all_50 : (369, 369)
# 13 : dm_Warmsen_Tuesday_31600-01_scenario_low_letter_50 : (149, 149)
# 14 : dm_Warmsen_Tuesday_31600-01_scenario_low_package_50 : (33, 33)
# 15 : dm_Warmsen_Tuesday_31600-01_scenario_low_others_50 : (77, 77)
# 16 : dm_Warmsen_Tuesday_31600-01_scenario_low_all_50 : (212, 212)
# 17 : dm_Warmsen_Tuesday_31600-01_scenario_medium_letter_50 : (253, 253)
# 18 : dm_Warmsen_Tuesday_31600-01_scenario_medium_package_50 : (66, 66)
# 19 : dm_Warmsen_Tuesday_31600-01_scenario_medium_others_50 : (128, 128)
# 20 : dm_Warmsen_Tuesday_31600-01_scenario_medium_all_50 : (306, 306)
# 21 : dm_Warmsen_Tuesday_31600-01_scenario_high_letter_50 : (271, 271)
# 22 : dm_Warmsen_Tuesday_31600-01_scenario_high_package_50 : (83, 83)
# 23 : dm_Warmsen_Tuesday_31600-01_scenario_high_others_50 : (160, 160)
# 24 : dm_Warmsen_Tuesday_31600-01_scenario_high_all_50 : (318, 318)
# 25 : dm_Warmsen_Tuesday_31606-12_scenario_low_letter_50 : (165, 165)
# 26 : dm_Warmsen_Tuesday_31606-12_scenario_low_package_50 : (36, 36)
# 27 : dm_Warmsen_Tuesday_31606-12_scenario_low_others_50 : (92, 92)
# 28 : dm_Warmsen_Tuesday_31606-12_scenario_low_all_50 : (234, 234)
# 29 : dm_Warmsen_Tuesday_31606-12_scenario_medium_letter_50 : (233, 233)
# 30 : dm_Warmsen_Tuesday_31606-12_scenario_medium_package_50 : (104, 104)
# 31 : dm_Warmsen_Tuesday_31606-12_scenario_medium_others_50 : (135, 135)
# 32 : dm_Warmsen_Tuesday_31606-12_scenario_medium_all_50 : (302, 302)
# 33 : dm_Warmsen_Tuesday_31606-12_scenario_high_letter_50 : (288, 288)
# 34 : dm_Warmsen_Tuesday_31606-12_scenario_high_package_50 : (118, 118)
# 35 : dm_Warmsen_Tuesday_31606-12_scenario_high_others_50 : (178, 178)
# 36 : dm_Warmsen_Tuesday_31606-12_scenario_high_all_50 : (344, 344)
# 37 : dm_Warmsen_Tuesday_31600-02_scenario_low_letter_50 : (122, 122)
# 38 : dm_Warmsen_Tuesday_31600-02_scenario_low_package_50 : (40, 40)
# 39 : dm_Warmsen_Tuesday_31600-02_scenario_low_others_50 : (83, 83)
# 40 : dm_Warmsen_Tuesday_31600-02_scenario_low_all_50 : (196, 196)
# 41 : dm_Warmsen_Tuesday_31600-02_scenario_medium_letter_50 : (209, 209)
# 42 : dm_Warmsen_Tuesday_31600-02_scenario_medium_package_50 : (82, 82)
# 43 : dm_Warmsen_Tuesday_31600-02_scenario_medium_others_50 : (149, 149)
# 44 : dm_Warmsen_Tuesday_31600-02_scenario_medium_all_50 : (295, 295)
# 45 : dm_Warmsen_Tuesday_31600-02_scenario_high_letter_50 : (259, 259)
# 46 : dm_Warmsen_Tuesday_31600-02_scenario_high_package_50 : (87, 87)
# 47 : dm_Warmsen_Tuesday_31600-02_scenario_high_others_50 : (186, 186)
# 48 : dm_Warmsen_Tuesday_31600-02_scenario_high_all_50 : (340, 340)
# 49 : dm_Warmsen_Tuesday_31604-09_scenario_low_letter_50 : (154, 154)
# 50 : dm_Warmsen_Tuesday_31604-09_scenario_low_package_50 : (37, 37)
# 51 : dm_Warmsen_Tuesday_31604-09_scenario_low_others_50 : (67, 67)
# 52 : dm_Warmsen_Tuesday_31604-09_scenario_low_all_50 : (211, 211)
# 53 : dm_Warmsen_Tuesday_31604-09_scenario_medium_letter_50 : (248, 248)
# 54 : dm_Warmsen_Tuesday_31604-09_scenario_medium_package_50 : (69, 69)
# 55 : dm_Warmsen_Tuesday_31604-09_scenario_medium_others_50 : (131, 131)
# 56 : dm_Warmsen_Tuesday_31604-09_scenario_medium_all_50 : (297, 297)
# 57 : dm_Warmsen_Tuesday_31604-09_scenario_high_letter_50 : (291, 291)
# 58 : dm_Warmsen_Tuesday_31604-09_scenario_high_package_50 : (110, 110)
# 59 : dm_Warmsen_Tuesday_31604-09_scenario_high_others_50 : (194, 194)
# 60 : dm_Warmsen_Tuesday_31604-09_scenario_high_all_50 : (356, 356)
# 61 : dm_Warmsen_Tuesday_31603-07_scenario_low_letter_50 : (159, 159)
# 62 : dm_Warmsen_Tuesday_31603-07_scenario_low_package_50 : (39, 39)
# 63 : dm_Warmsen_Tuesday_31603-07_scenario_low_others_50 : (101, 101)
# 64 : dm_Warmsen_Tuesday_31603-07_scenario_low_all_50 : (230, 230)
# 65 : dm_Warmsen_Tuesday_31603-07_scenario_medium_letter_50 : (245, 245)
# 66 : dm_Warmsen_Tuesday_31603-07_scenario_medium_package_50 : (70, 70)
# 67 : dm_Warmsen_Tuesday_31603-07_scenario_medium_others_50 : (158, 158)
# 68 : dm_Warmsen_Tuesday_31603-07_scenario_medium_all_50 : (311, 311)
# 69 : dm_Warmsen_Tuesday_31603-07_scenario_high_letter_50 : (284, 284)
# 70 : dm_Warmsen_Tuesday_31603-07_scenario_high_package_50 : (93, 93)
# 71 : dm_Warmsen_Tuesday_31603-07_scenario_high_others_50 : (236, 236)
# 72 : dm_Warmsen_Tuesday_31603-07_scenario_high_all_50 : (349, 349)
# 73 : dm_Warmsen_Tuesday_31604-10_scenario_low_letter_50 : (151, 151)
# 74 : dm_Warmsen_Tuesday_31604-10_scenario_low_package_50 : (31, 31)
# 75 : dm_Warmsen_Tuesday_31604-10_scenario_low_others_50 : (76, 76)
# 76 : dm_Warmsen_Tuesday_31604-10_scenario_low_all_50 : (205, 205)
# 77 : dm_Warmsen_Tuesday_31604-10_scenario_medium_letter_50 : (214, 214)
# 78 : dm_Warmsen_Tuesday_31604-10_scenario_medium_package_50 : (83, 83)
# 79 : dm_Warmsen_Tuesday_31604-10_scenario_medium_others_50 : (153, 153)
# 80 : dm_Warmsen_Tuesday_31604-10_scenario_medium_all_50 : (293, 293)
# 81 : dm_Warmsen_Tuesday_31604-10_scenario_high_letter_50 : (283, 283)
# 82 : dm_Warmsen_Tuesday_31604-10_scenario_high_package_50 : (108, 108)
# 83 : dm_Warmsen_Tuesday_31604-10_scenario_high_others_50 : (164, 164)
# 84 : dm_Warmsen_Tuesday_31604-10_scenario_high_all_50 : (328, 328)
# 85 : dm_Warmsen_Tuesday_31600-03_scenario_low_letter_50 : (137, 137)
# 86 : dm_Warmsen_Tuesday_31600-03_scenario_low_package_50 : (29, 29)
# 87 : dm_Warmsen_Tuesday_31600-03_scenario_low_others_50 : (67, 67)
# 88 : dm_Warmsen_Tuesday_31600-03_scenario_low_all_50 : (178, 178)
# 89 : dm_Warmsen_Tuesday_31600-03_scenario_medium_letter_50 : (236, 236)
# 90 : dm_Warmsen_Tuesday_31600-03_scenario_medium_package_50 : (74, 74)
# 91 : dm_Warmsen_Tuesday_31600-03_scenario_medium_others_50 : (145, 145)
# 92 : dm_Warmsen_Tuesday_31600-03_scenario_medium_all_50 : (277, 277)
# 93 : dm_Warmsen_Tuesday_31600-03_scenario_high_letter_50 : (269, 269)
# 94 : dm_Warmsen_Tuesday_31600-03_scenario_high_package_50 : (105, 105)
# 95 : dm_Warmsen_Tuesday_31600-03_scenario_high_others_50 : (166, 166)
# 96 : dm_Warmsen_Tuesday_31600-03_scenario_high_all_50 : (319, 319)
# 97 : dm_Warmsen_Tuesday_31603-05_scenario_low_letter_50 : (181, 181)
# 98 : dm_Warmsen_Tuesday_31603-05_scenario_low_package_50 : (36, 36)
# 99 : dm_Warmsen_Tuesday_31603-05_scenario_low_others_50 : (99, 99)
# 100 : dm_Warmsen_Tuesday_31603-05_scenario_low_all_50 : (232, 232)
# 101 : dm_Warmsen_Tuesday_31603-05_scenario_medium_letter_50 : (247, 247)
# 102 : dm_Warmsen_Tuesday_31603-05_scenario_medium_package_50 : (61, 61)
# 103 : dm_Warmsen_Tuesday_31603-05_scenario_medium_others_50 : (175, 175)
# 104 : dm_Warmsen_Tuesday_31603-05_scenario_medium_all_50 : (298, 298)
# 105 : dm_Warmsen_Tuesday_31603-05_scenario_high_letter_50 : (297, 297)
# 106 : dm_Warmsen_Tuesday_31603-05_scenario_high_package_50 : (95, 95)
# 107 : dm_Warmsen_Tuesday_31603-05_scenario_high_others_50 : (229, 229)
# 108 : dm_Warmsen_Tuesday_31603-05_scenario_high_all_50 : (338, 338)
# 109 : dm_Warmsen_Tuesday_31603-08_scenario_low_letter_50 : (157, 157)
# 110 : dm_Warmsen_Tuesday_31603-08_scenario_low_package_50 : (40, 40)
# 111 : dm_Warmsen_Tuesday_31603-08_scenario_low_others_50 : (92, 92)
# 112 : dm_Warmsen_Tuesday_31603-08_scenario_low_all_50 : (213, 213)
# 113 : dm_Warmsen_Tuesday_31603-08_scenario_medium_letter_50 : (241, 241)
# 114 : dm_Warmsen_Tuesday_31603-08_scenario_medium_package_50 : (71, 71)
# 115 : dm_Warmsen_Tuesday_31603-08_scenario_medium_others_50 : (161, 161)
# 116 : dm_Warmsen_Tuesday_31603-08_scenario_medium_all_50 : (293, 293)
# 117 : dm_Warmsen_Tuesday_31603-08_scenario_high_letter_50 : (264, 264)
# 118 : dm_Warmsen_Tuesday_31603-08_scenario_high_package_50 : (90, 90)
# 119 : dm_Warmsen_Tuesday_31603-08_scenario_high_others_50 : (193, 193)
# 120 : dm_Warmsen_Tuesday_31603-08_scenario_high_all_50 : (315, 315)
# 121 : dm_Warmsen_Tuesday_31606-11_scenario_low_letter_50 : (139, 139)
# 122 : dm_Warmsen_Tuesday_31606-11_scenario_low_package_50 : (33, 33)
# 123 : dm_Warmsen_Tuesday_31606-11_scenario_low_others_50 : (70, 70)
# 124 : dm_Warmsen_Tuesday_31606-11_scenario_low_all_50 : (194, 194)
# 125 : dm_Warmsen_Tuesday_31606-11_scenario_medium_letter_50 : (236, 236)
# 126 : dm_Warmsen_Tuesday_31606-11_scenario_medium_package_50 : (69, 69)
# 127 : dm_Warmsen_Tuesday_31606-11_scenario_medium_others_50 : (135, 135)
# 128 : dm_Warmsen_Tuesday_31606-11_scenario_medium_all_50 : (289, 289)
# 129 : dm_Warmsen_Tuesday_31606-11_scenario_high_letter_50 : (260, 260)
# 130 : dm_Warmsen_Tuesday_31606-11_scenario_high_package_50 : (90, 90)
# 131 : dm_Warmsen_Tuesday_31606-11_scenario_high_others_50 : (150, 150)
# 132 : dm_Warmsen_Tuesday_31606-11_scenario_high_all_50 : (295, 295)
# 133 : dm_Warmsen_Tuesday_31606-14_scenario_low_letter_50 : (133, 133)
# 134 : dm_Warmsen_Tuesday_31606-14_scenario_low_package_50 : (25, 25)
# 135 : dm_Warmsen_Tuesday_31606-14_scenario_low_others_50 : (56, 56)
# 136 : dm_Warmsen_Tuesday_31606-14_scenario_low_all_50 : (174, 174)
# 137 : dm_Warmsen_Tuesday_31606-14_scenario_medium_letter_50 : (197, 197)
# 138 : dm_Warmsen_Tuesday_31606-14_scenario_medium_package_50 : (63, 63)
# 139 : dm_Warmsen_Tuesday_31606-14_scenario_medium_others_50 : (118, 118)
# 140 : dm_Warmsen_Tuesday_31606-14_scenario_medium_all_50 : (248, 248)
# 141 : dm_Warmsen_Tuesday_31606-14_scenario_high_letter_50 : (241, 241)
# 142 : dm_Warmsen_Tuesday_31606-14_scenario_high_package_50 : (85, 85)
# 143 : dm_Warmsen_Tuesday_31606-14_scenario_high_others_50 : (134, 134)
# 144 : dm_Warmsen_Tuesday_31606-14_scenario_high_all_50 : (265, 265)
# 145 : dm_Warmsen_Tuesday_31606-13_scenario_low_letter_50 : (120, 120)
# 146 : dm_Warmsen_Tuesday_31606-13_scenario_low_package_50 : (28, 28)
# 147 : dm_Warmsen_Tuesday_31606-13_scenario_low_others_50 : (53, 53)
# 148 : dm_Warmsen_Tuesday_31606-13_scenario_low_all_50 : (155, 155)
# 149 : dm_Warmsen_Tuesday_31606-13_scenario_medium_letter_50 : (194, 194)
# 150 : dm_Warmsen_Tuesday_31606-13_scenario_medium_package_50 : (53, 53)
# 151 : dm_Warmsen_Tuesday_31606-13_scenario_medium_others_50 : (90, 90)
# 152 : dm_Warmsen_Tuesday_31606-13_scenario_medium_all_50 : (233, 233)
# 153 : dm_Warmsen_Tuesday_31606-13_scenario_high_letter_50 : (224, 224)
# 154 : dm_Warmsen_Tuesday_31606-13_scenario_high_package_50 : (76, 76)
# 155 : dm_Warmsen_Tuesday_31606-13_scenario_high_others_50 : (131, 131)
# 156 : dm_Warmsen_Tuesday_31606-13_scenario_high_all_50 : (262, 262)
# 157 : dm_Warmsen_Tuesday_31600-04_scenario_low_letter_50 : (97, 97)
# 158 : dm_Warmsen_Tuesday_31600-04_scenario_low_package_50 : (26, 26)
# 159 : dm_Warmsen_Tuesday_31600-04_scenario_low_others_50 : (55, 55)
# 160 : dm_Warmsen_Tuesday_31600-04_scenario_low_all_50 : (141, 141)
# 161 : dm_Warmsen_Tuesday_31600-04_scenario_medium_letter_50 : (151, 151)
# 162 : dm_Warmsen_Tuesday_31600-04_scenario_medium_package_50 : (57, 57)
# 163 : dm_Warmsen_Tuesday_31600-04_scenario_medium_others_50 : (95, 95)
# 164 : dm_Warmsen_Tuesday_31600-04_scenario_medium_all_50 : (196, 196)
# 165 : dm_Warmsen_Tuesday_31600-04_scenario_high_letter_50 : (193, 193)
# 166 : dm_Warmsen_Tuesday_31600-04_scenario_high_package_50 : (73, 73)
# 167 : dm_Warmsen_Tuesday_31600-04_scenario_high_others_50 : (133, 133)
# 168 : dm_Warmsen_Tuesday_31600-04_scenario_high_all_50 : (233, 233)
# 169 : dm_Warmsen_Thursday_31603-06_scenario_low_letter_50 : (201, 201)
# 170 : dm_Warmsen_Thursday_31603-06_scenario_low_package_50 : (39, 39)
# 171 : dm_Warmsen_Thursday_31603-06_scenario_low_others_50 : (76, 76)
# 172 : dm_Warmsen_Thursday_31603-06_scenario_low_all_50 : (249, 249)
# 173 : dm_Warmsen_Thursday_31603-06_scenario_medium_letter_50 : (293, 293)
# 174 : dm_Warmsen_Thursday_31603-06_scenario_medium_package_50 : (71, 71)
# 175 : dm_Warmsen_Thursday_31603-06_scenario_medium_others_50 : (144, 144)
# 176 : dm_Warmsen_Thursday_31603-06_scenario_medium_all_50 : (341, 341)
# 177 : dm_Warmsen_Thursday_31603-06_scenario_high_letter_50 : (332, 332)
# 178 : dm_Warmsen_Thursday_31603-06_scenario_high_package_50 : (100, 100)
# 179 : dm_Warmsen_Thursday_31603-06_scenario_high_others_50 : (191, 191)
# 180 : dm_Warmsen_Thursday_31603-06_scenario_high_all_50 : (378, 378)
# 181 : dm_Warmsen_Thursday_31600-01_scenario_low_letter_50 : (187, 187)
# 182 : dm_Warmsen_Thursday_31600-01_scenario_low_package_50 : (23, 23)
# 183 : dm_Warmsen_Thursday_31600-01_scenario_low_others_50 : (47, 47)
# 184 : dm_Warmsen_Thursday_31600-01_scenario_low_all_50 : (215, 215)
# 185 : dm_Warmsen_Thursday_31600-01_scenario_medium_letter_50 : (284, 284)
# 186 : dm_Warmsen_Thursday_31600-01_scenario_medium_package_50 : (69, 69)
# 187 : dm_Warmsen_Thursday_31600-01_scenario_medium_others_50 : (86, 86)
# 188 : dm_Warmsen_Thursday_31600-01_scenario_medium_all_50 : (312, 312)
# 189 : dm_Warmsen_Thursday_31600-01_scenario_high_letter_50 : (317, 317)
# 190 : dm_Warmsen_Thursday_31600-01_scenario_high_package_50 : (91, 91)
# 191 : dm_Warmsen_Thursday_31600-01_scenario_high_others_50 : (122, 122)
# 192 : dm_Warmsen_Thursday_31600-01_scenario_high_all_50 : (345, 345)
# 193 : dm_Warmsen_Thursday_31606-12_scenario_low_letter_50 : (187, 187)
# 194 : dm_Warmsen_Thursday_31606-12_scenario_low_package_50 : (42, 42)
# 195 : dm_Warmsen_Thursday_31606-12_scenario_low_others_50 : (41, 41)
# 196 : dm_Warmsen_Thursday_31606-12_scenario_low_all_50 : (221, 221)
# 197 : dm_Warmsen_Thursday_31606-12_scenario_medium_letter_50 : (285, 285)
# 198 : dm_Warmsen_Thursday_31606-12_scenario_medium_package_50 : (66, 66)
# 199 : dm_Warmsen_Thursday_31606-12_scenario_medium_others_50 : (95, 95)
# 200 : dm_Warmsen_Thursday_31606-12_scenario_medium_all_50 : (317, 317)
# 201 : dm_Warmsen_Thursday_31606-12_scenario_high_letter_50 : (303, 303)
# 202 : dm_Warmsen_Thursday_31606-12_scenario_high_package_50 : (92, 92)
# 203 : dm_Warmsen_Thursday_31606-12_scenario_high_others_50 : (149, 149)
# 204 : dm_Warmsen_Thursday_31606-12_scenario_high_all_50 : (349, 349)
# 205 : dm_Warmsen_Thursday_31600-02_scenario_low_letter_50 : (165, 165)
# 206 : dm_Warmsen_Thursday_31600-02_scenario_low_package_50 : (34, 34)
# 207 : dm_Warmsen_Thursday_31600-02_scenario_low_others_50 : (61, 61)
# 208 : dm_Warmsen_Thursday_31600-02_scenario_low_all_50 : (214, 214)
# 209 : dm_Warmsen_Thursday_31600-02_scenario_medium_letter_50 : (248, 248)
# 210 : dm_Warmsen_Thursday_31600-02_scenario_medium_package_50 : (76, 76)
# 211 : dm_Warmsen_Thursday_31600-02_scenario_medium_others_50 : (104, 104)
# 212 : dm_Warmsen_Thursday_31600-02_scenario_medium_all_50 : (290, 290)
# 213 : dm_Warmsen_Thursday_31600-02_scenario_high_letter_50 : (311, 311)
# 214 : dm_Warmsen_Thursday_31600-02_scenario_high_package_50 : (100, 100)
# 215 : dm_Warmsen_Thursday_31600-02_scenario_high_others_50 : (167, 167)
# 216 : dm_Warmsen_Thursday_31600-02_scenario_high_all_50 : (348, 348)
# 217 : dm_Warmsen_Thursday_31604-09_scenario_low_letter_50 : (179, 179)
# 218 : dm_Warmsen_Thursday_31604-09_scenario_low_package_50 : (50, 50)
# 219 : dm_Warmsen_Thursday_31604-09_scenario_low_others_50 : (41, 41)
# 220 : dm_Warmsen_Thursday_31604-09_scenario_low_all_50 : (222, 222)
# 221 : dm_Warmsen_Thursday_31604-09_scenario_medium_letter_50 : (287, 287)
# 222 : dm_Warmsen_Thursday_31604-09_scenario_medium_package_50 : (73, 73)
# 223 : dm_Warmsen_Thursday_31604-09_scenario_medium_others_50 : (97, 97)
# 224 : dm_Warmsen_Thursday_31604-09_scenario_medium_all_50 : (319, 319)
# 225 : dm_Warmsen_Thursday_31604-09_scenario_high_letter_50 : (329, 329)
# 226 : dm_Warmsen_Thursday_31604-09_scenario_high_package_50 : (120, 120)
# 227 : dm_Warmsen_Thursday_31604-09_scenario_high_others_50 : (136, 136)
# 228 : dm_Warmsen_Thursday_31604-09_scenario_high_all_50 : (363, 363)
# 229 : dm_Warmsen_Thursday_31603-07_scenario_low_letter_50 : (201, 201)
# 230 : dm_Warmsen_Thursday_31603-07_scenario_low_package_50 : (42, 42)
# 231 : dm_Warmsen_Thursday_31603-07_scenario_low_others_50 : (61, 61)
# 232 : dm_Warmsen_Thursday_31603-07_scenario_low_all_50 : (245, 245)
# 233 : dm_Warmsen_Thursday_31603-07_scenario_medium_letter_50 : (291, 291)
# 234 : dm_Warmsen_Thursday_31603-07_scenario_medium_package_50 : (64, 64)
# 235 : dm_Warmsen_Thursday_31603-07_scenario_medium_others_50 : (125, 125)
# 236 : dm_Warmsen_Thursday_31603-07_scenario_medium_all_50 : (331, 331)
# 237 : dm_Warmsen_Thursday_31603-07_scenario_high_letter_50 : (319, 319)
# 238 : dm_Warmsen_Thursday_31603-07_scenario_high_package_50 : (91, 91)
# 239 : dm_Warmsen_Thursday_31603-07_scenario_high_others_50 : (181, 181)
# 240 : dm_Warmsen_Thursday_31603-07_scenario_high_all_50 : (350, 350)
# 241 : dm_Warmsen_Thursday_31604-10_scenario_low_letter_50 : (171, 171)
# 242 : dm_Warmsen_Thursday_31604-10_scenario_low_package_50 : (31, 31)
# 243 : dm_Warmsen_Thursday_31604-10_scenario_low_others_50 : (47, 47)
# 244 : dm_Warmsen_Thursday_31604-10_scenario_low_all_50 : (211, 211)
# 245 : dm_Warmsen_Thursday_31604-10_scenario_medium_letter_50 : (267, 267)
# 246 : dm_Warmsen_Thursday_31604-10_scenario_medium_package_50 : (72, 72)
# 247 : dm_Warmsen_Thursday_31604-10_scenario_medium_others_50 : (84, 84)
# 248 : dm_Warmsen_Thursday_31604-10_scenario_medium_all_50 : (295, 295)
# 249 : dm_Warmsen_Thursday_31604-10_scenario_high_letter_50 : (303, 303)
# 250 : dm_Warmsen_Thursday_31604-10_scenario_high_package_50 : (96, 96)
# 251 : dm_Warmsen_Thursday_31604-10_scenario_high_others_50 : (97, 97)
# 252 : dm_Warmsen_Thursday_31604-10_scenario_high_all_50 : (331, 331)
# 253 : dm_Warmsen_Thursday_31600-03_scenario_low_letter_50 : (171, 171)
# 254 : dm_Warmsen_Thursday_31600-03_scenario_low_package_50 : (36, 36)
# 255 : dm_Warmsen_Thursday_31600-03_scenario_low_others_50 : (64, 64)
# 256 : dm_Warmsen_Thursday_31600-03_scenario_low_all_50 : (206, 206)
# 257 : dm_Warmsen_Thursday_31600-03_scenario_medium_letter_50 : (271, 271)
# 258 : dm_Warmsen_Thursday_31600-03_scenario_medium_package_50 : (67, 67)
# 259 : dm_Warmsen_Thursday_31600-03_scenario_medium_others_50 : (109, 109)
# 260 : dm_Warmsen_Thursday_31600-03_scenario_medium_all_50 : (300, 300)
# 261 : dm_Warmsen_Thursday_31600-03_scenario_high_letter_50 : (296, 296)
# 262 : dm_Warmsen_Thursday_31600-03_scenario_high_package_50 : (104, 104)
# 263 : dm_Warmsen_Thursday_31600-03_scenario_high_others_50 : (148, 148)
# 264 : dm_Warmsen_Thursday_31600-03_scenario_high_all_50 : (322, 322)
# 265 : dm_Warmsen_Thursday_31603-05_scenario_low_letter_50 : (178, 178)
# 266 : dm_Warmsen_Thursday_31603-05_scenario_low_package_50 : (33, 33)
# 267 : dm_Warmsen_Thursday_31603-05_scenario_low_others_50 : (86, 86)
# 268 : dm_Warmsen_Thursday_31603-05_scenario_low_all_50 : (222, 222)
# 269 : dm_Warmsen_Thursday_31603-05_scenario_medium_letter_50 : (256, 256)
# 270 : dm_Warmsen_Thursday_31603-05_scenario_medium_package_50 : (54, 54)
# 271 : dm_Warmsen_Thursday_31603-05_scenario_medium_others_50 : (141, 141)
# 272 : dm_Warmsen_Thursday_31603-05_scenario_medium_all_50 : (301, 301)
# 273 : dm_Warmsen_Thursday_31603-05_scenario_high_letter_50 : (309, 309)
# 274 : dm_Warmsen_Thursday_31603-05_scenario_high_package_50 : (87, 87)
# 275 : dm_Warmsen_Thursday_31603-05_scenario_high_others_50 : (177, 177)
# 276 : dm_Warmsen_Thursday_31603-05_scenario_high_all_50 : (342, 342)
# 277 : dm_Warmsen_Thursday_31603-08_scenario_low_letter_50 : (176, 176)
# 278 : dm_Warmsen_Thursday_31603-08_scenario_low_package_50 : (45, 45)
# 279 : dm_Warmsen_Thursday_31603-08_scenario_low_others_50 : (70, 70)
# 280 : dm_Warmsen_Thursday_31603-08_scenario_low_all_50 : (227, 227)
# 281 : dm_Warmsen_Thursday_31603-08_scenario_medium_letter_50 : (251, 251)
# 282 : dm_Warmsen_Thursday_31603-08_scenario_medium_package_50 : (76, 76)
# 283 : dm_Warmsen_Thursday_31603-08_scenario_medium_others_50 : (110, 110)
# 284 : dm_Warmsen_Thursday_31603-08_scenario_medium_all_50 : (289, 289)
# 285 : dm_Warmsen_Thursday_31603-08_scenario_high_letter_50 : (295, 295)
# 286 : dm_Warmsen_Thursday_31603-08_scenario_high_package_50 : (114, 114)
# 287 : dm_Warmsen_Thursday_31603-08_scenario_high_others_50 : (160, 160)
# 288 : dm_Warmsen_Thursday_31603-08_scenario_high_all_50 : (326, 326)
# 289 : dm_Warmsen_Thursday_31606-11_scenario_low_letter_50 : (189, 189)
# 290 : dm_Warmsen_Thursday_31606-11_scenario_low_package_50 : (29, 29)
# 291 : dm_Warmsen_Thursday_31606-11_scenario_low_others_50 : (47, 47)
# 292 : dm_Warmsen_Thursday_31606-11_scenario_low_all_50 : (217, 217)
# 293 : dm_Warmsen_Thursday_31606-11_scenario_medium_letter_50 : (244, 244)
# 294 : dm_Warmsen_Thursday_31606-11_scenario_medium_package_50 : (81, 81)
# 295 : dm_Warmsen_Thursday_31606-11_scenario_medium_others_50 : (69, 69)
# 296 : dm_Warmsen_Thursday_31606-11_scenario_medium_all_50 : (272, 272)
# 297 : dm_Warmsen_Thursday_31606-11_scenario_high_letter_50 : (283, 283)
# 298 : dm_Warmsen_Thursday_31606-11_scenario_high_package_50 : (89, 89)
# 299 : dm_Warmsen_Thursday_31606-11_scenario_high_others_50 : (99, 99)
# 300 : dm_Warmsen_Thursday_31606-11_scenario_high_all_50 : (304, 304)
# 301 : dm_Warmsen_Thursday_31606-14_scenario_low_letter_50 : (173, 173)
# 302 : dm_Warmsen_Thursday_31606-14_scenario_low_package_50 : (41, 41)
# 303 : dm_Warmsen_Thursday_31606-14_scenario_low_others_50 : (42, 42)
# 304 : dm_Warmsen_Thursday_31606-14_scenario_low_all_50 : (199, 199)
# 305 : dm_Warmsen_Thursday_31606-14_scenario_medium_letter_50 : (223, 223)
# 306 : dm_Warmsen_Thursday_31606-14_scenario_medium_package_50 : (58, 58)
# 307 : dm_Warmsen_Thursday_31606-14_scenario_medium_others_50 : (82, 82)
# 308 : dm_Warmsen_Thursday_31606-14_scenario_medium_all_50 : (252, 252)
# 309 : dm_Warmsen_Thursday_31606-14_scenario_high_letter_50 : (254, 254)
# 310 : dm_Warmsen_Thursday_31606-14_scenario_high_package_50 : (73, 73)
# 311 : dm_Warmsen_Thursday_31606-14_scenario_high_others_50 : (92, 92)
# 312 : dm_Warmsen_Thursday_31606-14_scenario_high_all_50 : (273, 273)
# 313 : dm_Warmsen_Thursday_31606-13_scenario_low_letter_50 : (152, 152)
# 314 : dm_Warmsen_Thursday_31606-13_scenario_low_package_50 : (31, 31)
# 315 : dm_Warmsen_Thursday_31606-13_scenario_low_others_50 : (38, 38)
# 316 : dm_Warmsen_Thursday_31606-13_scenario_low_all_50 : (181, 181)
# 317 : dm_Warmsen_Thursday_31606-13_scenario_medium_letter_50 : (218, 218)
# 318 : dm_Warmsen_Thursday_31606-13_scenario_medium_package_50 : (57, 57)
# 319 : dm_Warmsen_Thursday_31606-13_scenario_medium_others_50 : (67, 67)
# 320 : dm_Warmsen_Thursday_31606-13_scenario_medium_all_50 : (249, 249)
# 321 : dm_Warmsen_Thursday_31606-13_scenario_high_letter_50 : (242, 242)
# 322 : dm_Warmsen_Thursday_31606-13_scenario_high_package_50 : (75, 75)
# 323 : dm_Warmsen_Thursday_31606-13_scenario_high_others_50 : (94, 94)
# 324 : dm_Warmsen_Thursday_31606-13_scenario_high_all_50 : (264, 264)
# 325 : dm_Warmsen_Thursday_31600-04_scenario_low_letter_50 : (132, 132)
# 326 : dm_Warmsen_Thursday_31600-04_scenario_low_package_50 : (26, 26)
# 327 : dm_Warmsen_Thursday_31600-04_scenario_low_others_50 : (34, 34)
# 328 : dm_Warmsen_Thursday_31600-04_scenario_low_all_50 : (161, 161)
# 329 : dm_Warmsen_Thursday_31600-04_scenario_medium_letter_50 : (188, 188)
# 330 : dm_Warmsen_Thursday_31600-04_scenario_medium_package_50 : (59, 59)
# 331 : dm_Warmsen_Thursday_31600-04_scenario_medium_others_50 : (69, 69)
# 332 : dm_Warmsen_Thursday_31600-04_scenario_medium_all_50 : (219, 219)
# 333 : dm_Warmsen_Thursday_31600-04_scenario_high_letter_50 : (215, 215)
# 334 : dm_Warmsen_Thursday_31600-04_scenario_high_package_50 : (73, 73)
# 335 : dm_Warmsen_Thursday_31600-04_scenario_high_others_50 : (101, 101)
# 336 : dm_Warmsen_Thursday_31600-04_scenario_high_all_50 : (241, 241)
# 337 : dm_Warmsen_Friday_31603-06_scenario_low_letter_50 : (176, 176)
# 338 : dm_Warmsen_Friday_31603-06_scenario_low_package_50 : (37, 37)
# 339 : dm_Warmsen_Friday_31603-06_scenario_low_others_50 : (107, 107)
# 340 : dm_Warmsen_Friday_31603-06_scenario_low_all_50 : (247, 247)
# 341 : dm_Warmsen_Friday_31603-06_scenario_medium_letter_50 : (264, 264)
# 342 : dm_Warmsen_Friday_31603-06_scenario_medium_package_50 : (75, 75)
# 343 : dm_Warmsen_Friday_31603-06_scenario_medium_others_50 : (174, 174)
# 344 : dm_Warmsen_Friday_31603-06_scenario_medium_all_50 : (328, 328)
# 345 : dm_Warmsen_Friday_31603-06_scenario_high_letter_50 : (323, 323)
# 346 : dm_Warmsen_Friday_31603-06_scenario_high_package_50 : (106, 106)
# 347 : dm_Warmsen_Friday_31603-06_scenario_high_others_50 : (229, 229)
# 348 : dm_Warmsen_Friday_31603-06_scenario_high_all_50 : (371, 371)
# 349 : dm_Warmsen_Friday_31600-01_scenario_low_letter_50 : (166, 166)
# 350 : dm_Warmsen_Friday_31600-01_scenario_low_package_50 : (30, 30)
# 351 : dm_Warmsen_Friday_31600-01_scenario_low_others_50 : (102, 102)
# 352 : dm_Warmsen_Friday_31600-01_scenario_low_all_50 : (220, 220)
# 353 : dm_Warmsen_Friday_31600-01_scenario_medium_letter_50 : (268, 268)
# 354 : dm_Warmsen_Friday_31600-01_scenario_medium_package_50 : (58, 58)
# 355 : dm_Warmsen_Friday_31600-01_scenario_medium_others_50 : (168, 168)
# 356 : dm_Warmsen_Friday_31600-01_scenario_medium_all_50 : (327, 327)
# 357 : dm_Warmsen_Friday_31600-01_scenario_high_letter_50 : (308, 308)
# 358 : dm_Warmsen_Friday_31600-01_scenario_high_package_50 : (84, 84)
# 359 : dm_Warmsen_Friday_31600-01_scenario_high_others_50 : (209, 209)
# 360 : dm_Warmsen_Friday_31600-01_scenario_high_all_50 : (351, 351)
# 361 : dm_Warmsen_Friday_31606-12_scenario_low_letter_50 : (167, 167)
# 362 : dm_Warmsen_Friday_31606-12_scenario_low_package_50 : (37, 37)
# 363 : dm_Warmsen_Friday_31606-12_scenario_low_others_50 : (107, 107)
# 364 : dm_Warmsen_Friday_31606-12_scenario_low_all_50 : (248, 248)
# 365 : dm_Warmsen_Friday_31606-12_scenario_medium_letter_50 : (256, 256)
# 366 : dm_Warmsen_Friday_31606-12_scenario_medium_package_50 : (77, 77)
# 367 : dm_Warmsen_Friday_31606-12_scenario_medium_others_50 : (178, 178)
# 368 : dm_Warmsen_Friday_31606-12_scenario_medium_all_50 : (323, 323)
# 369 : dm_Warmsen_Friday_31606-12_scenario_high_letter_50 : (297, 297)
# 370 : dm_Warmsen_Friday_31606-12_scenario_high_package_50 : (107, 107)
# 371 : dm_Warmsen_Friday_31606-12_scenario_high_others_50 : (211, 211)
# 372 : dm_Warmsen_Friday_31606-12_scenario_high_all_50 : (364, 364)
# 373 : dm_Warmsen_Friday_31600-02_scenario_low_letter_50 : (160, 160)
# 374 : dm_Warmsen_Friday_31600-02_scenario_low_package_50 : (31, 31)
# 375 : dm_Warmsen_Friday_31600-02_scenario_low_others_50 : (97, 97)
# 376 : dm_Warmsen_Friday_31600-02_scenario_low_all_50 : (229, 229)
# 377 : dm_Warmsen_Friday_31600-02_scenario_medium_letter_50 : (239, 239)
# 378 : dm_Warmsen_Friday_31600-02_scenario_medium_package_50 : (58, 58)
# 379 : dm_Warmsen_Friday_31600-02_scenario_medium_others_50 : (175, 175)
# 380 : dm_Warmsen_Friday_31600-02_scenario_medium_all_50 : (311, 311)
# 381 : dm_Warmsen_Friday_31600-02_scenario_high_letter_50 : (287, 287)
# 382 : dm_Warmsen_Friday_31600-02_scenario_high_package_50 : (101, 101)
# 383 : dm_Warmsen_Friday_31600-02_scenario_high_others_50 : (239, 239)
# 384 : dm_Warmsen_Friday_31600-02_scenario_high_all_50 : (359, 359)
# 385 : dm_Warmsen_Friday_31604-09_scenario_low_letter_50 : (161, 161)
# 386 : dm_Warmsen_Friday_31604-09_scenario_low_package_50 : (41, 41)
# 387 : dm_Warmsen_Friday_31604-09_scenario_low_others_50 : (95, 95)
# 388 : dm_Warmsen_Friday_31604-09_scenario_low_all_50 : (225, 225)
# 389 : dm_Warmsen_Friday_31604-09_scenario_medium_letter_50 : (261, 261)
# 390 : dm_Warmsen_Friday_31604-09_scenario_medium_package_50 : (77, 77)
# 391 : dm_Warmsen_Friday_31604-09_scenario_medium_others_50 : (191, 191)
# 392 : dm_Warmsen_Friday_31604-09_scenario_medium_all_50 : (325, 325)
# 393 : dm_Warmsen_Friday_31604-09_scenario_high_letter_50 : (298, 298)
# 394 : dm_Warmsen_Friday_31604-09_scenario_high_package_50 : (100, 100)
# 395 : dm_Warmsen_Friday_31604-09_scenario_high_others_50 : (220, 220)
# 396 : dm_Warmsen_Friday_31604-09_scenario_high_all_50 : (360, 360)
# 397 : dm_Warmsen_Friday_31603-07_scenario_low_letter_50 : (195, 195)
# 398 : dm_Warmsen_Friday_31603-07_scenario_low_package_50 : (29, 29)
# 399 : dm_Warmsen_Friday_31603-07_scenario_low_others_50 : (94, 94)
# 400 : dm_Warmsen_Friday_31603-07_scenario_low_all_50 : (251, 251)
# 401 : dm_Warmsen_Friday_31603-07_scenario_medium_letter_50 : (286, 286)
# 402 : dm_Warmsen_Friday_31603-07_scenario_medium_package_50 : (59, 59)
# 403 : dm_Warmsen_Friday_31603-07_scenario_medium_others_50 : (176, 176)
# 404 : dm_Warmsen_Friday_31603-07_scenario_medium_all_50 : (337, 337)
# 405 : dm_Warmsen_Friday_31603-07_scenario_high_letter_50 : (314, 314)
# 406 : dm_Warmsen_Friday_31603-07_scenario_high_package_50 : (83, 83)
# 407 : dm_Warmsen_Friday_31603-07_scenario_high_others_50 : (213, 213)
# 408 : dm_Warmsen_Friday_31603-07_scenario_high_all_50 : (355, 355)
# 409 : dm_Warmsen_Friday_31604-10_scenario_low_letter_50 : (182, 182)
# 410 : dm_Warmsen_Friday_31604-10_scenario_low_package_50 : (26, 26)
# 411 : dm_Warmsen_Friday_31604-10_scenario_low_others_50 : (100, 100)
# 412 : dm_Warmsen_Friday_31604-10_scenario_low_all_50 : (229, 229)
# 413 : dm_Warmsen_Friday_31604-10_scenario_medium_letter_50 : (259, 259)
# 414 : dm_Warmsen_Friday_31604-10_scenario_medium_package_50 : (62, 62)
# 415 : dm_Warmsen_Friday_31604-10_scenario_medium_others_50 : (177, 177)
# 416 : dm_Warmsen_Friday_31604-10_scenario_medium_all_50 : (317, 317)
# 417 : dm_Warmsen_Friday_31604-10_scenario_high_letter_50 : (288, 288)
# 418 : dm_Warmsen_Friday_31604-10_scenario_high_package_50 : (95, 95)
# 419 : dm_Warmsen_Friday_31604-10_scenario_high_others_50 : (217, 217)
# 420 : dm_Warmsen_Friday_31604-10_scenario_high_all_50 : (342, 342)
# 421 : dm_Warmsen_Friday_31600-03_scenario_low_letter_50 : (170, 170)
# 422 : dm_Warmsen_Friday_31600-03_scenario_low_package_50 : (25, 25)
# 423 : dm_Warmsen_Friday_31600-03_scenario_low_others_50 : (95, 95)
# 424 : dm_Warmsen_Friday_31600-03_scenario_low_all_50 : (220, 220)
# 425 : dm_Warmsen_Friday_31600-03_scenario_medium_letter_50 : (240, 240)
# 426 : dm_Warmsen_Friday_31600-03_scenario_medium_package_50 : (60, 60)
# 427 : dm_Warmsen_Friday_31600-03_scenario_medium_others_50 : (166, 166)
# 428 : dm_Warmsen_Friday_31600-03_scenario_medium_all_50 : (291, 291)
# 429 : dm_Warmsen_Friday_31600-03_scenario_high_letter_50 : (292, 292)
# 430 : dm_Warmsen_Friday_31600-03_scenario_high_package_50 : (87, 87)
# 431 : dm_Warmsen_Friday_31600-03_scenario_high_others_50 : (184, 184)
# 432 : dm_Warmsen_Friday_31600-03_scenario_high_all_50 : (318, 318)
# 433 : dm_Warmsen_Friday_31603-05_scenario_low_letter_50 : (179, 179)
# 434 : dm_Warmsen_Friday_31603-05_scenario_low_package_50 : (29, 29)
# 435 : dm_Warmsen_Friday_31603-05_scenario_low_others_50 : (98, 98)
# 436 : dm_Warmsen_Friday_31603-05_scenario_low_all_50 : (242, 242)
# 437 : dm_Warmsen_Friday_31603-05_scenario_medium_letter_50 : (265, 265)
# 438 : dm_Warmsen_Friday_31603-05_scenario_medium_package_50 : (66, 66)
# 439 : dm_Warmsen_Friday_31603-05_scenario_medium_others_50 : (167, 167)
# 440 : dm_Warmsen_Friday_31603-05_scenario_medium_all_50 : (314, 314)
# 441 : dm_Warmsen_Friday_31603-05_scenario_high_letter_50 : (314, 314)
# 442 : dm_Warmsen_Friday_31603-05_scenario_high_package_50 : (80, 80)
# 443 : dm_Warmsen_Friday_31603-05_scenario_high_others_50 : (202, 202)
# 444 : dm_Warmsen_Friday_31603-05_scenario_high_all_50 : (349, 349)
# 445 : dm_Warmsen_Friday_31603-08_scenario_low_letter_50 : (167, 167)
# 446 : dm_Warmsen_Friday_31603-08_scenario_low_package_50 : (35, 35)
# 447 : dm_Warmsen_Friday_31603-08_scenario_low_others_50 : (87, 87)
# 448 : dm_Warmsen_Friday_31603-08_scenario_low_all_50 : (225, 225)
# 449 : dm_Warmsen_Friday_31603-08_scenario_medium_letter_50 : (241, 241)
# 450 : dm_Warmsen_Friday_31603-08_scenario_medium_package_50 : (70, 70)
# 451 : dm_Warmsen_Friday_31603-08_scenario_medium_others_50 : (163, 163)
# 452 : dm_Warmsen_Friday_31603-08_scenario_medium_all_50 : (303, 303)
# 453 : dm_Warmsen_Friday_31603-08_scenario_high_letter_50 : (279, 279)
# 454 : dm_Warmsen_Friday_31603-08_scenario_high_package_50 : (80, 80)
# 455 : dm_Warmsen_Friday_31603-08_scenario_high_others_50 : (187, 187)
# 456 : dm_Warmsen_Friday_31603-08_scenario_high_all_50 : (322, 322)
# 457 : dm_Warmsen_Friday_31606-11_scenario_low_letter_50 : (175, 175)
# 458 : dm_Warmsen_Friday_31606-11_scenario_low_package_50 : (31, 31)
# 459 : dm_Warmsen_Friday_31606-11_scenario_low_others_50 : (86, 86)
# 460 : dm_Warmsen_Friday_31606-11_scenario_low_all_50 : (216, 216)
# 461 : dm_Warmsen_Friday_31606-11_scenario_medium_letter_50 : (242, 242)
# 462 : dm_Warmsen_Friday_31606-11_scenario_medium_package_50 : (52, 52)
# 463 : dm_Warmsen_Friday_31606-11_scenario_medium_others_50 : (156, 156)
# 464 : dm_Warmsen_Friday_31606-11_scenario_medium_all_50 : (283, 283)
# 465 : dm_Warmsen_Friday_31606-11_scenario_high_letter_50 : (278, 278)
# 466 : dm_Warmsen_Friday_31606-11_scenario_high_package_50 : (79, 79)
# 467 : dm_Warmsen_Friday_31606-11_scenario_high_others_50 : (204, 204)
# 468 : dm_Warmsen_Friday_31606-11_scenario_high_all_50 : (313, 313)
# 469 : dm_Warmsen_Friday_31606-14_scenario_low_letter_50 : (137, 137)
# 470 : dm_Warmsen_Friday_31606-14_scenario_low_package_50 : (30, 30)
# 471 : dm_Warmsen_Friday_31606-14_scenario_low_others_50 : (83, 83)
# 472 : dm_Warmsen_Friday_31606-14_scenario_low_all_50 : (191, 191)
# 473 : dm_Warmsen_Friday_31606-14_scenario_medium_letter_50 : (208, 208)
# 474 : dm_Warmsen_Friday_31606-14_scenario_medium_package_50 : (56, 56)
# 475 : dm_Warmsen_Friday_31606-14_scenario_medium_others_50 : (147, 147)
# 476 : dm_Warmsen_Friday_31606-14_scenario_medium_all_50 : (259, 259)
# 477 : dm_Warmsen_Friday_31606-14_scenario_high_letter_50 : (240, 240)
# 478 : dm_Warmsen_Friday_31606-14_scenario_high_package_50 : (76, 76)
# 479 : dm_Warmsen_Friday_31606-14_scenario_high_others_50 : (191, 191)
# 480 : dm_Warmsen_Friday_31606-14_scenario_high_all_50 : (283, 283)
# 481 : dm_Warmsen_Friday_31606-13_scenario_low_letter_50 : (135, 135)
# 482 : dm_Warmsen_Friday_31606-13_scenario_low_package_50 : (29, 29)
# 483 : dm_Warmsen_Friday_31606-13_scenario_low_others_50 : (78, 78)
# 484 : dm_Warmsen_Friday_31606-13_scenario_low_all_50 : (184, 184)
# 485 : dm_Warmsen_Friday_31606-13_scenario_medium_letter_50 : (217, 217)
# 486 : dm_Warmsen_Friday_31606-13_scenario_medium_package_50 : (50, 50)
# 487 : dm_Warmsen_Friday_31606-13_scenario_medium_others_50 : (146, 146)
# 488 : dm_Warmsen_Friday_31606-13_scenario_medium_all_50 : (259, 259)
# 489 : dm_Warmsen_Friday_31606-13_scenario_high_letter_50 : (233, 233)
# 490 : dm_Warmsen_Friday_31606-13_scenario_high_package_50 : (77, 77)
# 491 : dm_Warmsen_Friday_31606-13_scenario_high_others_50 : (177, 177)
# 492 : dm_Warmsen_Friday_31606-13_scenario_high_all_50 : (266, 266)
# 493 : dm_Warmsen_Friday_31600-04_scenario_low_letter_50 : (114, 114)
# 494 : dm_Warmsen_Friday_31600-04_scenario_low_package_50 : (25, 25)
# 495 : dm_Warmsen_Friday_31600-04_scenario_low_others_50 : (62, 62)
# 496 : dm_Warmsen_Friday_31600-04_scenario_low_all_50 : (159, 159)
# 497 : dm_Warmsen_Friday_31600-04_scenario_medium_letter_50 : (179, 179)
# 498 : dm_Warmsen_Friday_31600-04_scenario_medium_package_50 : (42, 42)
# 499 : dm_Warmsen_Friday_31600-04_scenario_medium_others_50 : (124, 124)
# 500 : dm_Warmsen_Friday_31600-04_scenario_medium_all_50 : (227, 227)
# 501 : dm_Warmsen_Friday_31600-04_scenario_high_letter_50 : (206, 206)
# 502 : dm_Warmsen_Friday_31600-04_scenario_high_package_50 : (63, 63)
# 503 : dm_Warmsen_Friday_31600-04_scenario_high_others_50 : (155, 155)
# 504 : dm_Warmsen_Friday_31600-04_scenario_high_all_50 : (249, 249)
# 505 : dm_Warmsen_Wednesday_31603-06_scenario_low_letter_50 : (186, 186)
# 506 : dm_Warmsen_Wednesday_31603-06_scenario_low_package_50 : (39, 39)
# 507 : dm_Warmsen_Wednesday_31603-06_scenario_low_others_50 : (115, 115)
# 508 : dm_Warmsen_Wednesday_31603-06_scenario_low_all_50 : (253, 253)
# 509 : dm_Warmsen_Wednesday_31603-06_scenario_medium_letter_50 : (290, 290)
# 510 : dm_Warmsen_Wednesday_31603-06_scenario_medium_package_50 : (83, 83)
# 511 : dm_Warmsen_Wednesday_31603-06_scenario_medium_others_50 : (182, 182)
# 512 : dm_Warmsen_Wednesday_31603-06_scenario_medium_all_50 : (356, 356)
# 513 : dm_Warmsen_Wednesday_31603-06_scenario_high_letter_50 : (341, 341)
# 514 : dm_Warmsen_Wednesday_31603-06_scenario_high_package_50 : (103, 103)
# 515 : dm_Warmsen_Wednesday_31603-06_scenario_high_others_50 : (230, 230)
# 516 : dm_Warmsen_Wednesday_31603-06_scenario_high_all_50 : (389, 389)
# 517 : dm_Warmsen_Wednesday_31600-01_scenario_low_letter_50 : (193, 193)
# 518 : dm_Warmsen_Wednesday_31600-01_scenario_low_package_50 : (36, 36)
# 519 : dm_Warmsen_Wednesday_31600-01_scenario_low_others_50 : (56, 56)
# 520 : dm_Warmsen_Wednesday_31600-01_scenario_low_all_50 : (223, 223)
# 521 : dm_Warmsen_Wednesday_31600-01_scenario_medium_letter_50 : (261, 261)
# 522 : dm_Warmsen_Wednesday_31600-01_scenario_medium_package_50 : (62, 62)
# 523 : dm_Warmsen_Wednesday_31600-01_scenario_medium_others_50 : (108, 108)
# 524 : dm_Warmsen_Wednesday_31600-01_scenario_medium_all_50 : (299, 299)
# 525 : dm_Warmsen_Wednesday_31600-01_scenario_high_letter_50 : (306, 306)
# 526 : dm_Warmsen_Wednesday_31600-01_scenario_high_package_50 : (83, 83)
# 527 : dm_Warmsen_Wednesday_31600-01_scenario_high_others_50 : (162, 162)
# 528 : dm_Warmsen_Wednesday_31600-01_scenario_high_all_50 : (342, 342)
# 529 : dm_Warmsen_Wednesday_31606-12_scenario_low_letter_50 : (167, 167)
# 530 : dm_Warmsen_Wednesday_31606-12_scenario_low_package_50 : (54, 54)
# 531 : dm_Warmsen_Wednesday_31606-12_scenario_low_others_50 : (90, 90)
# 532 : dm_Warmsen_Wednesday_31606-12_scenario_low_all_50 : (234, 234)
# 533 : dm_Warmsen_Wednesday_31606-12_scenario_medium_letter_50 : (236, 236)
# 534 : dm_Warmsen_Wednesday_31606-12_scenario_medium_package_50 : (75, 75)
# 535 : dm_Warmsen_Wednesday_31606-12_scenario_medium_others_50 : (122, 122)
# 536 : dm_Warmsen_Wednesday_31606-12_scenario_medium_all_50 : (305, 305)
# 537 : dm_Warmsen_Wednesday_31606-12_scenario_high_letter_50 : (324, 324)
# 538 : dm_Warmsen_Wednesday_31606-12_scenario_high_package_50 : (113, 113)
# 539 : dm_Warmsen_Wednesday_31606-12_scenario_high_others_50 : (161, 161)
# 540 : dm_Warmsen_Wednesday_31606-12_scenario_high_all_50 : (363, 363)
# 541 : dm_Warmsen_Wednesday_31600-02_scenario_low_letter_50 : (165, 165)
# 542 : dm_Warmsen_Wednesday_31600-02_scenario_low_package_50 : (39, 39)
# 543 : dm_Warmsen_Wednesday_31600-02_scenario_low_others_50 : (59, 59)
# 544 : dm_Warmsen_Wednesday_31600-02_scenario_low_all_50 : (213, 213)
# 545 : dm_Warmsen_Wednesday_31600-02_scenario_medium_letter_50 : (255, 255)
# 546 : dm_Warmsen_Wednesday_31600-02_scenario_medium_package_50 : (73, 73)
# 547 : dm_Warmsen_Wednesday_31600-02_scenario_medium_others_50 : (119, 119)
# 548 : dm_Warmsen_Wednesday_31600-02_scenario_medium_all_50 : (304, 304)
# 549 : dm_Warmsen_Wednesday_31600-02_scenario_high_letter_50 : (295, 295)
# 550 : dm_Warmsen_Wednesday_31600-02_scenario_high_package_50 : (91, 91)
# 551 : dm_Warmsen_Wednesday_31600-02_scenario_high_others_50 : (160, 160)
# 552 : dm_Warmsen_Wednesday_31600-02_scenario_high_all_50 : (347, 347)
# 553 : dm_Warmsen_Wednesday_31604-09_scenario_low_letter_50 : (181, 181)
# 554 : dm_Warmsen_Wednesday_31604-09_scenario_low_package_50 : (53, 53)
# 555 : dm_Warmsen_Wednesday_31604-09_scenario_low_others_50 : (59, 59)
# 556 : dm_Warmsen_Wednesday_31604-09_scenario_low_all_50 : (227, 227)
# 557 : dm_Warmsen_Wednesday_31604-09_scenario_medium_letter_50 : (258, 258)
# 558 : dm_Warmsen_Wednesday_31604-09_scenario_medium_package_50 : (93, 93)
# 559 : dm_Warmsen_Wednesday_31604-09_scenario_medium_others_50 : (107, 107)
# 560 : dm_Warmsen_Wednesday_31604-09_scenario_medium_all_50 : (315, 315)
# 561 : dm_Warmsen_Wednesday_31604-09_scenario_high_letter_50 : (315, 315)
# 562 : dm_Warmsen_Wednesday_31604-09_scenario_high_package_50 : (113, 113)
# 563 : dm_Warmsen_Wednesday_31604-09_scenario_high_others_50 : (128, 128)
# 564 : dm_Warmsen_Wednesday_31604-09_scenario_high_all_50 : (346, 346)
# 565 : dm_Warmsen_Wednesday_31603-07_scenario_low_letter_50 : (177, 177)
# 566 : dm_Warmsen_Wednesday_31603-07_scenario_low_package_50 : (30, 30)
# 567 : dm_Warmsen_Wednesday_31603-07_scenario_low_others_50 : (94, 94)
# 568 : dm_Warmsen_Wednesday_31603-07_scenario_low_all_50 : (229, 229)
# 569 : dm_Warmsen_Wednesday_31603-07_scenario_medium_letter_50 : (278, 278)
# 570 : dm_Warmsen_Wednesday_31603-07_scenario_medium_package_50 : (72, 72)
# 571 : dm_Warmsen_Wednesday_31603-07_scenario_medium_others_50 : (172, 172)
# 572 : dm_Warmsen_Wednesday_31603-07_scenario_medium_all_50 : (322, 322)
# 573 : dm_Warmsen_Wednesday_31603-07_scenario_high_letter_50 : (308, 308)
# 574 : dm_Warmsen_Wednesday_31603-07_scenario_high_package_50 : (98, 98)
# 575 : dm_Warmsen_Wednesday_31603-07_scenario_high_others_50 : (221, 221)
# 576 : dm_Warmsen_Wednesday_31603-07_scenario_high_all_50 : (355, 355)
# 577 : dm_Warmsen_Wednesday_31604-10_scenario_low_letter_50 : (176, 176)
# 578 : dm_Warmsen_Wednesday_31604-10_scenario_low_package_50 : (47, 47)
# 579 : dm_Warmsen_Wednesday_31604-10_scenario_low_others_50 : (63, 63)
# 580 : dm_Warmsen_Wednesday_31604-10_scenario_low_all_50 : (217, 217)
# 581 : dm_Warmsen_Wednesday_31604-10_scenario_medium_letter_50 : (247, 247)
# 582 : dm_Warmsen_Wednesday_31604-10_scenario_medium_package_50 : (69, 69)
# 583 : dm_Warmsen_Wednesday_31604-10_scenario_medium_others_50 : (107, 107)
# 584 : dm_Warmsen_Wednesday_31604-10_scenario_medium_all_50 : (291, 291)
# 585 : dm_Warmsen_Wednesday_31604-10_scenario_high_letter_50 : (303, 303)
# 586 : dm_Warmsen_Wednesday_31604-10_scenario_high_package_50 : (102, 102)
# 587 : dm_Warmsen_Wednesday_31604-10_scenario_high_others_50 : (133, 133)
# 588 : dm_Warmsen_Wednesday_31604-10_scenario_high_all_50 : (328, 328)
# 589 : dm_Warmsen_Wednesday_31600-03_scenario_low_letter_50 : (162, 162)
# 590 : dm_Warmsen_Wednesday_31600-03_scenario_low_package_50 : (44, 44)
# 591 : dm_Warmsen_Wednesday_31600-03_scenario_low_others_50 : (58, 58)
# 592 : dm_Warmsen_Wednesday_31600-03_scenario_low_all_50 : (207, 207)
# 593 : dm_Warmsen_Wednesday_31600-03_scenario_medium_letter_50 : (256, 256)
# 594 : dm_Warmsen_Wednesday_31600-03_scenario_medium_package_50 : (71, 71)
# 595 : dm_Warmsen_Wednesday_31600-03_scenario_medium_others_50 : (113, 113)
# 596 : dm_Warmsen_Wednesday_31600-03_scenario_medium_all_50 : (293, 293)
# 597 : dm_Warmsen_Wednesday_31600-03_scenario_high_letter_50 : (279, 279)
# 598 : dm_Warmsen_Wednesday_31600-03_scenario_high_package_50 : (96, 96)
# 599 : dm_Warmsen_Wednesday_31600-03_scenario_high_others_50 : (154, 154)
# 600 : dm_Warmsen_Wednesday_31600-03_scenario_high_all_50 : (316, 316)
# 601 : dm_Warmsen_Wednesday_31603-05_scenario_low_letter_50 : (186, 186)
# 602 : dm_Warmsen_Wednesday_31603-05_scenario_low_package_50 : (49, 49)
# 603 : dm_Warmsen_Wednesday_31603-05_scenario_low_others_50 : (90, 90)
# 604 : dm_Warmsen_Wednesday_31603-05_scenario_low_all_50 : (240, 240)
# 605 : dm_Warmsen_Wednesday_31603-05_scenario_medium_letter_50 : (261, 261)
# 606 : dm_Warmsen_Wednesday_31603-05_scenario_medium_package_50 : (72, 72)
# 607 : dm_Warmsen_Wednesday_31603-05_scenario_medium_others_50 : (178, 178)
# 608 : dm_Warmsen_Wednesday_31603-05_scenario_medium_all_50 : (313, 313)
# 609 : dm_Warmsen_Wednesday_31603-05_scenario_high_letter_50 : (307, 307)
# 610 : dm_Warmsen_Wednesday_31603-05_scenario_high_package_50 : (97, 97)
# 611 : dm_Warmsen_Wednesday_31603-05_scenario_high_others_50 : (208, 208)
# 612 : dm_Warmsen_Wednesday_31603-05_scenario_high_all_50 : (339, 339)
# 613 : dm_Warmsen_Wednesday_31603-08_scenario_low_letter_50 : (170, 170)
# 614 : dm_Warmsen_Wednesday_31603-08_scenario_low_package_50 : (45, 45)
# 615 : dm_Warmsen_Wednesday_31603-08_scenario_low_others_50 : (92, 92)
# 616 : dm_Warmsen_Wednesday_31603-08_scenario_low_all_50 : (226, 226)
# 617 : dm_Warmsen_Wednesday_31603-08_scenario_medium_letter_50 : (272, 272)
# 618 : dm_Warmsen_Wednesday_31603-08_scenario_medium_package_50 : (81, 81)
# 619 : dm_Warmsen_Wednesday_31603-08_scenario_medium_others_50 : (171, 171)
# 620 : dm_Warmsen_Wednesday_31603-08_scenario_medium_all_50 : (320, 320)
# 621 : dm_Warmsen_Wednesday_31603-08_scenario_high_letter_50 : (286, 286)
# 622 : dm_Warmsen_Wednesday_31603-08_scenario_high_package_50 : (100, 100)
# 623 : dm_Warmsen_Wednesday_31603-08_scenario_high_others_50 : (187, 187)
# 624 : dm_Warmsen_Wednesday_31603-08_scenario_high_all_50 : (328, 328)
# 625 : dm_Warmsen_Wednesday_31606-11_scenario_low_letter_50 : (152, 152)
# 626 : dm_Warmsen_Wednesday_31606-11_scenario_low_package_50 : (42, 42)
# 627 : dm_Warmsen_Wednesday_31606-11_scenario_low_others_50 : (86, 86)
# 628 : dm_Warmsen_Wednesday_31606-11_scenario_low_all_50 : (208, 208)
# 629 : dm_Warmsen_Wednesday_31606-11_scenario_medium_letter_50 : (242, 242)
# 630 : dm_Warmsen_Wednesday_31606-11_scenario_medium_package_50 : (71, 71)
# 631 : dm_Warmsen_Wednesday_31606-11_scenario_medium_others_50 : (125, 125)
# 632 : dm_Warmsen_Wednesday_31606-11_scenario_medium_all_50 : (282, 282)
# 633 : dm_Warmsen_Wednesday_31606-11_scenario_high_letter_50 : (287, 287)
# 634 : dm_Warmsen_Wednesday_31606-11_scenario_high_package_50 : (104, 104)
# 635 : dm_Warmsen_Wednesday_31606-11_scenario_high_others_50 : (163, 163)
# 636 : dm_Warmsen_Wednesday_31606-11_scenario_high_all_50 : (317, 317)
# 637 : dm_Warmsen_Wednesday_31606-14_scenario_low_letter_50 : (138, 138)
# 638 : dm_Warmsen_Wednesday_31606-14_scenario_low_package_50 : (34, 34)
# 639 : dm_Warmsen_Wednesday_31606-14_scenario_low_others_50 : (76, 76)
# 640 : dm_Warmsen_Wednesday_31606-14_scenario_low_all_50 : (193, 193)
# 641 : dm_Warmsen_Wednesday_31606-14_scenario_medium_letter_50 : (213, 213)
# 642 : dm_Warmsen_Wednesday_31606-14_scenario_medium_package_50 : (64, 64)
# 643 : dm_Warmsen_Wednesday_31606-14_scenario_medium_others_50 : (114, 114)
# 644 : dm_Warmsen_Wednesday_31606-14_scenario_medium_all_50 : (255, 255)
# 645 : dm_Warmsen_Wednesday_31606-14_scenario_high_letter_50 : (250, 250)
# 646 : dm_Warmsen_Wednesday_31606-14_scenario_high_package_50 : (92, 92)
# 647 : dm_Warmsen_Wednesday_31606-14_scenario_high_others_50 : (133, 133)
# 648 : dm_Warmsen_Wednesday_31606-14_scenario_high_all_50 : (277, 277)
# 649 : dm_Warmsen_Wednesday_31606-13_scenario_low_letter_50 : (139, 139)
# 650 : dm_Warmsen_Wednesday_31606-13_scenario_low_package_50 : (34, 34)
# 651 : dm_Warmsen_Wednesday_31606-13_scenario_low_others_50 : (71, 71)
# 652 : dm_Warmsen_Wednesday_31606-13_scenario_low_all_50 : (181, 181)
# 653 : dm_Warmsen_Wednesday_31606-13_scenario_medium_letter_50 : (213, 213)
# 654 : dm_Warmsen_Wednesday_31606-13_scenario_medium_package_50 : (48, 48)
# 655 : dm_Warmsen_Wednesday_31606-13_scenario_medium_others_50 : (112, 112)
# 656 : dm_Warmsen_Wednesday_31606-13_scenario_medium_all_50 : (246, 246)
# 657 : dm_Warmsen_Wednesday_31606-13_scenario_high_letter_50 : (250, 250)
# 658 : dm_Warmsen_Wednesday_31606-13_scenario_high_package_50 : (86, 86)
# 659 : dm_Warmsen_Wednesday_31606-13_scenario_high_others_50 : (136, 136)
# 660 : dm_Warmsen_Wednesday_31606-13_scenario_high_all_50 : (271, 271)
# 661 : dm_Warmsen_Wednesday_31600-04_scenario_low_letter_50 : (104, 104)
# 662 : dm_Warmsen_Wednesday_31600-04_scenario_low_package_50 : (29, 29)
# 663 : dm_Warmsen_Wednesday_31600-04_scenario_low_others_50 : (40, 40)
# 664 : dm_Warmsen_Wednesday_31600-04_scenario_low_all_50 : (144, 144)
# 665 : dm_Warmsen_Wednesday_31600-04_scenario_medium_letter_50 : (181, 181)
# 666 : dm_Warmsen_Wednesday_31600-04_scenario_medium_package_50 : (63, 63)
# 667 : dm_Warmsen_Wednesday_31600-04_scenario_medium_others_50 : (75, 75)
# 668 : dm_Warmsen_Wednesday_31600-04_scenario_medium_all_50 : (220, 220)
# 669 : dm_Warmsen_Wednesday_31600-04_scenario_high_letter_50 : (203, 203)
# 670 : dm_Warmsen_Wednesday_31600-04_scenario_high_package_50 : (76, 76)
# 671 : dm_Warmsen_Wednesday_31600-04_scenario_high_others_50 : (102, 102)
# 672 : dm_Warmsen_Wednesday_31600-04_scenario_high_all_50 : (240, 240)
# 673 : dm_Warmsen_Monday_31603-06_scenario_low_letter_50 : (30, 30)
# 674 : dm_Warmsen_Monday_31603-06_scenario_low_package_50 : (19, 19)
# 675 : dm_Warmsen_Monday_31603-06_scenario_low_others_50 : (2, 2)
# 676 : dm_Warmsen_Monday_31603-06_scenario_low_all_50 : (46, 46)
# 677 : dm_Warmsen_Monday_31603-06_scenario_medium_letter_50 : (44, 44)
# 678 : dm_Warmsen_Monday_31603-06_scenario_medium_package_50 : (25, 25)
# 679 : dm_Warmsen_Monday_31603-06_scenario_medium_others_50 : (2, 2)
# 680 : dm_Warmsen_Monday_31603-06_scenario_medium_all_50 : (64, 64)
# ...
# 783 : dm_Warmsen_Monday_31603-08_scenario_low_others_50 : (2, 2)
# 784 : dm_Warmsen_Monday_31603-08_scenario_low_all_50 : (48, 48)
# 785 : dm_Warmsen_Monday_31603-08_scenario_medium_letter_50 : (45, 45)
# 786 : dm_Warmsen_Monday_31603-08_scenario_medium_package_50 : (28, 28)
# 787 : dm_Warmsen_Monday_31603-08_scenario_medium_others_50 : (2, 2)
# 788 : dm_Warmsen_Monday_31603-08_scenario_medium_all_50 : (63, 63)
# 789 : dm_Warmsen_Monday_31603-08_scenario_high_letter_50 : (77, 77)
# 790 : dm_Warmsen_Monday_31603-08_scenario_high_package_50 : (37, 37)
# 791 : dm_Warmsen_Monday_31603-08_scenario_high_others_50 : (2, 2)
# 792 : dm_Warmsen_Monday_31603-08_scenario_high_all_50 : (98, 98)
# 793 : dm_Warmsen_Monday_31606-11_scenario_low_letter_50 : (33, 33)
# 794 : dm_Warmsen_Monday_31606-11_scenario_low_package_50 : (11, 11)
# 795 : dm_Warmsen_Monday_31606-11_scenario_low_others_50 : (2, 2)
# 796 : dm_Warmsen_Monday_31606-11_scenario_low_all_50 : (40, 40)
# 797 : dm_Warmsen_Monday_31606-11_scenario_medium_letter_50 : (50, 50)
# 798 : dm_Warmsen_Monday_31606-11_scenario_medium_package_50 : (23, 23)
# 799 : dm_Warmsen_Monday_31606-11_scenario_medium_others_50 : (2, 2)
# 800 : dm_Warmsen_Monday_31606-11_scenario_medium_all_50 : (67, 67)
# 801 : dm_Warmsen_Monday_31606-11_scenario_high_letter_50 : (79, 79)
# 802 : dm_Warmsen_Monday_31606-11_scenario_high_package_50 : (16, 16)
# 803 : dm_Warmsen_Monday_31606-11_scenario_high_others_50 : (2, 2)
# 804 : dm_Warmsen_Monday_31606-11_scenario_high_all_50 : (87, 87)
# 805 : dm_Warmsen_Monday_31606-14_scenario_low_letter_50 : (25, 25)
# 806 : dm_Warmsen_Monday_31606-14_scenario_low_package_50 : (13, 13)
# 807 : dm_Warmsen_Monday_31606-14_scenario_low_others_50 : (2, 2)
# 808 : dm_Warmsen_Monday_31606-14_scenario_low_all_50 : (36, 36)
# 809 : dm_Warmsen_Monday_31606-14_scenario_medium_letter_50 : (56, 56)
# 810 : dm_Warmsen_Monday_31606-14_scenario_medium_package_50 : (31, 31)
# 811 : dm_Warmsen_Monday_31606-14_scenario_medium_others_50 : (2, 2)
# 812 : dm_Warmsen_Monday_31606-14_scenario_medium_all_50 : (78, 78)
# 813 : dm_Warmsen_Monday_31606-14_scenario_high_letter_50 : (70, 70)
# 814 : dm_Warmsen_Monday_31606-14_scenario_high_package_50 : (35, 35)
# 815 : dm_Warmsen_Monday_31606-14_scenario_high_others_50 : (2, 2)
# 816 : dm_Warmsen_Monday_31606-14_scenario_high_all_50 : (94, 94)
# 817 : dm_Warmsen_Monday_31606-13_scenario_low_letter_50 : (23, 23)
# 818 : dm_Warmsen_Monday_31606-13_scenario_low_package_50 : (11, 11)
# 819 : dm_Warmsen_Monday_31606-13_scenario_low_others_50 : (2, 2)
# 820 : dm_Warmsen_Monday_31606-13_scenario_low_all_50 : (32, 32)
# 821 : dm_Warmsen_Monday_31606-13_scenario_medium_letter_50 : (34, 34)
# 822 : dm_Warmsen_Monday_31606-13_scenario_medium_package_50 : (23, 23)
# 823 : dm_Warmsen_Monday_31606-13_scenario_medium_others_50 : (2, 2)
# 824 : dm_Warmsen_Monday_31606-13_scenario_medium_all_50 : (52, 52)
# 825 : dm_Warmsen_Monday_31606-13_scenario_high_letter_50 : (76, 76)
# 826 : dm_Warmsen_Monday_31606-13_scenario_high_package_50 : (31, 31)
# 827 : dm_Warmsen_Monday_31606-13_scenario_high_others_50 : (2, 2)
# 828 : dm_Warmsen_Monday_31606-13_scenario_high_all_50 : (96, 96)
# 829 : dm_Warmsen_Monday_31600-04_scenario_low_letter_50 : (20, 20)
# 830 : dm_Warmsen_Monday_31600-04_scenario_low_package_50 : (11, 11)
# 831 : dm_Warmsen_Monday_31600-04_scenario_low_others_50 : (1, 1)
# 832 : dm_Warmsen_Monday_31600-04_scenario_low_all_50 : (30, 30)
# 833 : dm_Warmsen_Monday_31600-04_scenario_medium_letter_50 : (33, 33)
# 834 : dm_Warmsen_Monday_31600-04_scenario_medium_package_50 : (12, 12)
# 835 : dm_Warmsen_Monday_31600-04_scenario_medium_others_50 : (1, 1)
# 836 : dm_Warmsen_Monday_31600-04_scenario_medium_all_50 : (42, 42)
# 837 : dm_Warmsen_Monday_31600-04_scenario_high_letter_50 : (48, 48)
# 838 : dm_Warmsen_Monday_31600-04_scenario_high_package_50 : (14, 14)
# 839 : dm_Warmsen_Monday_31600-04_scenario_high_others_50 : (1, 1)
# 840 : dm_Warmsen_Monday_31600-04_scenario_high_all_50 : (59, 59)
# 841 : dm_Warmsen_Saturday_31603-06_scenario_low_letter_50 : (166, 166)
# 842 : dm_Warmsen_Saturday_31603-06_scenario_low_package_50 : (28, 28)
# 843 : dm_Warmsen_Saturday_31603-06_scenario_low_others_50 : (106, 106)
# 844 : dm_Warmsen_Saturday_31603-06_scenario_low_all_50 : (235, 235)
# 845 : dm_Warmsen_Saturday_31603-06_scenario_medium_letter_50 : (266, 266)
# 846 : dm_Warmsen_Saturday_31603-06_scenario_medium_package_50 : (62, 62)
# 847 : dm_Warmsen_Saturday_31603-06_scenario_medium_others_50 : (169, 169)
# 848 : dm_Warmsen_Saturday_31603-06_scenario_medium_all_50 : (335, 335)
# 849 : dm_Warmsen_Saturday_31603-06_scenario_high_letter_50 : (321, 321)
# 850 : dm_Warmsen_Saturday_31603-06_scenario_high_package_50 : (86, 86)
# 851 : dm_Warmsen_Saturday_31603-06_scenario_high_others_50 : (226, 226)
# 852 : dm_Warmsen_Saturday_31603-06_scenario_high_all_50 : (371, 371)
# 853 : dm_Warmsen_Saturday_31600-01_scenario_low_letter_50 : (161, 161)
# 854 : dm_Warmsen_Saturday_31600-01_scenario_low_package_50 : (28, 28)
# 855 : dm_Warmsen_Saturday_31600-01_scenario_low_others_50 : (108, 108)
# 856 : dm_Warmsen_Saturday_31600-01_scenario_low_all_50 : (235, 235)
# 857 : dm_Warmsen_Saturday_31600-01_scenario_medium_letter_50 : (246, 246)
# 858 : dm_Warmsen_Saturday_31600-01_scenario_medium_package_50 : (49, 49)
# 859 : dm_Warmsen_Saturday_31600-01_scenario_medium_others_50 : (157, 157)
# 860 : dm_Warmsen_Saturday_31600-01_scenario_medium_all_50 : (306, 306)
# 861 : dm_Warmsen_Saturday_31600-01_scenario_high_letter_50 : (294, 294)
# 862 : dm_Warmsen_Saturday_31600-01_scenario_high_package_50 : (87, 87)
# 863 : dm_Warmsen_Saturday_31600-01_scenario_high_others_50 : (193, 193)
# 864 : dm_Warmsen_Saturday_31600-01_scenario_high_all_50 : (341, 341)
# 865 : dm_Warmsen_Saturday_31606-12_scenario_low_letter_50 : (150, 150)
# 866 : dm_Warmsen_Saturday_31606-12_scenario_low_package_50 : (40, 40)
# 867 : dm_Warmsen_Saturday_31606-12_scenario_low_others_50 : (104, 104)
# 868 : dm_Warmsen_Saturday_31606-12_scenario_low_all_50 : (228, 228)
# 869 : dm_Warmsen_Saturday_31606-12_scenario_medium_letter_50 : (233, 233)
# 870 : dm_Warmsen_Saturday_31606-12_scenario_medium_package_50 : (67, 67)
# 871 : dm_Warmsen_Saturday_31606-12_scenario_medium_others_50 : (179, 179)
# 872 : dm_Warmsen_Saturday_31606-12_scenario_medium_all_50 : (313, 313)
# 873 : dm_Warmsen_Saturday_31606-12_scenario_high_letter_50 : (304, 304)
# 874 : dm_Warmsen_Saturday_31606-12_scenario_high_package_50 : (93, 93)
# 875 : dm_Warmsen_Saturday_31606-12_scenario_high_others_50 : (226, 226)
# 876 : dm_Warmsen_Saturday_31606-12_scenario_high_all_50 : (363, 363)
# 877 : dm_Warmsen_Saturday_31600-02_scenario_low_letter_50 : (143, 143)
# 878 : dm_Warmsen_Saturday_31600-02_scenario_low_package_50 : (27, 27)
# 879 : dm_Warmsen_Saturday_31600-02_scenario_low_others_50 : (103, 103)
# 880 : dm_Warmsen_Saturday_31600-02_scenario_low_all_50 : (215, 215)
# 881 : dm_Warmsen_Saturday_31600-02_scenario_medium_letter_50 : (243, 243)
# 882 : dm_Warmsen_Saturday_31600-02_scenario_medium_package_50 : (58, 58)
# 883 : dm_Warmsen_Saturday_31600-02_scenario_medium_others_50 : (166, 166)
# 884 : dm_Warmsen_Saturday_31600-02_scenario_medium_all_50 : (313, 313)
# 885 : dm_Warmsen_Saturday_31600-02_scenario_high_letter_50 : (291, 291)
# 886 : dm_Warmsen_Saturday_31600-02_scenario_high_package_50 : (89, 89)
# 887 : dm_Warmsen_Saturday_31600-02_scenario_high_others_50 : (225, 225)
# 888 : dm_Warmsen_Saturday_31600-02_scenario_high_all_50 : (357, 357)
# 889 : dm_Warmsen_Saturday_31604-09_scenario_low_letter_50 : (155, 155)
# 890 : dm_Warmsen_Saturday_31604-09_scenario_low_package_50 : (36, 36)
# 891 : dm_Warmsen_Saturday_31604-09_scenario_low_others_50 : (95, 95)
# 892 : dm_Warmsen_Saturday_31604-09_scenario_low_all_50 : (221, 221)
# 893 : dm_Warmsen_Saturday_31604-09_scenario_medium_letter_50 : (240, 240)
# 894 : dm_Warmsen_Saturday_31604-09_scenario_medium_package_50 : (66, 66)
# 895 : dm_Warmsen_Saturday_31604-09_scenario_medium_others_50 : (172, 172)
# 896 : dm_Warmsen_Saturday_31604-09_scenario_medium_all_50 : (314, 314)
# 897 : dm_Warmsen_Saturday_31604-09_scenario_high_letter_50 : (307, 307)
# 898 : dm_Warmsen_Saturday_31604-09_scenario_high_package_50 : (108, 108)
# 899 : dm_Warmsen_Saturday_31604-09_scenario_high_others_50 : (219, 219)
# 900 : dm_Warmsen_Saturday_31604-09_scenario_high_all_50 : (359, 359)
# 901 : dm_Warmsen_Saturday_31603-07_scenario_low_letter_50 : (167, 167)
# 902 : dm_Warmsen_Saturday_31603-07_scenario_low_package_50 : (37, 37)
# 903 : dm_Warmsen_Saturday_31603-07_scenario_low_others_50 : (86, 86)
# 904 : dm_Warmsen_Saturday_31603-07_scenario_low_all_50 : (227, 227)
# 905 : dm_Warmsen_Saturday_31603-07_scenario_medium_letter_50 : (246, 246)
# 906 : dm_Warmsen_Saturday_31603-07_scenario_medium_package_50 : (57, 57)
# 907 : dm_Warmsen_Saturday_31603-07_scenario_medium_others_50 : (168, 168)
# 908 : dm_Warmsen_Saturday_31603-07_scenario_medium_all_50 : (311, 311)
# 909 : dm_Warmsen_Saturday_31603-07_scenario_high_letter_50 : (317, 317)
# 910 : dm_Warmsen_Saturday_31603-07_scenario_high_package_50 : (83, 83)
# 911 : dm_Warmsen_Saturday_31603-07_scenario_high_others_50 : (206, 206)
# 912 : dm_Warmsen_Saturday_31603-07_scenario_high_all_50 : (358, 358)
# 913 : dm_Warmsen_Saturday_31604-10_scenario_low_letter_50 : (182, 182)
# 914 : dm_Warmsen_Saturday_31604-10_scenario_low_package_50 : (34, 34)
# 915 : dm_Warmsen_Saturday_31604-10_scenario_low_others_50 : (120, 120)
# 916 : dm_Warmsen_Saturday_31604-10_scenario_low_all_50 : (245, 245)
# 917 : dm_Warmsen_Saturday_31604-10_scenario_medium_letter_50 : (238, 238)
# 918 : dm_Warmsen_Saturday_31604-10_scenario_medium_package_50 : (55, 55)
# 919 : dm_Warmsen_Saturday_31604-10_scenario_medium_others_50 : (155, 155)
# 920 : dm_Warmsen_Saturday_31604-10_scenario_medium_all_50 : (307, 307)
# 921 : dm_Warmsen_Saturday_31604-10_scenario_high_letter_50 : (302, 302)
# 922 : dm_Warmsen_Saturday_31604-10_scenario_high_package_50 : (73, 73)
# 923 : dm_Warmsen_Saturday_31604-10_scenario_high_others_50 : (203, 203)
# 924 : dm_Warmsen_Saturday_31604-10_scenario_high_all_50 : (340, 340)
# 925 : dm_Warmsen_Saturday_31600-03_scenario_low_letter_50 : (162, 162)
# 926 : dm_Warmsen_Saturday_31600-03_scenario_low_package_50 : (30, 30)
# 927 : dm_Warmsen_Saturday_31600-03_scenario_low_others_50 : (89, 89)
# 928 : dm_Warmsen_Saturday_31600-03_scenario_low_all_50 : (211, 211)
# 929 : dm_Warmsen_Saturday_31600-03_scenario_medium_letter_50 : (243, 243)
# 930 : dm_Warmsen_Saturday_31600-03_scenario_medium_package_50 : (47, 47)
# 931 : dm_Warmsen_Saturday_31600-03_scenario_medium_others_50 : (155, 155)
# 932 : dm_Warmsen_Saturday_31600-03_scenario_medium_all_50 : (288, 288)
# 933 : dm_Warmsen_Saturday_31600-03_scenario_high_letter_50 : (267, 267)
# 934 : dm_Warmsen_Saturday_31600-03_scenario_high_package_50 : (72, 72)
# 935 : dm_Warmsen_Saturday_31600-03_scenario_high_others_50 : (205, 205)
# 936 : dm_Warmsen_Saturday_31600-03_scenario_high_all_50 : (319, 319)
# 937 : dm_Warmsen_Saturday_31603-05_scenario_low_letter_50 : (168, 168)
# 938 : dm_Warmsen_Saturday_31603-05_scenario_low_package_50 : (34, 34)
# 939 : dm_Warmsen_Saturday_31603-05_scenario_low_others_50 : (114, 114)
# 940 : dm_Warmsen_Saturday_31603-05_scenario_low_all_50 : (240, 240)
# 941 : dm_Warmsen_Saturday_31603-05_scenario_medium_letter_50 : (252, 252)
# 942 : dm_Warmsen_Saturday_31603-05_scenario_medium_package_50 : (59, 59)
# 943 : dm_Warmsen_Saturday_31603-05_scenario_medium_others_50 : (158, 158)
# 944 : dm_Warmsen_Saturday_31603-05_scenario_medium_all_50 : (305, 305)
# 945 : dm_Warmsen_Saturday_31603-05_scenario_high_letter_50 : (285, 285)
# 946 : dm_Warmsen_Saturday_31603-05_scenario_high_package_50 : (76, 76)
# 947 : dm_Warmsen_Saturday_31603-05_scenario_high_others_50 : (215, 215)
# 948 : dm_Warmsen_Saturday_31603-05_scenario_high_all_50 : (330, 330)
# 949 : dm_Warmsen_Saturday_31603-08_scenario_low_letter_50 : (156, 156)
# 950 : dm_Warmsen_Saturday_31603-08_scenario_low_package_50 : (37, 37)
# 951 : dm_Warmsen_Saturday_31603-08_scenario_low_others_50 : (89, 89)
# 952 : dm_Warmsen_Saturday_31603-08_scenario_low_all_50 : (215, 215)
# 953 : dm_Warmsen_Saturday_31603-08_scenario_medium_letter_50 : (247, 247)
# 954 : dm_Warmsen_Saturday_31603-08_scenario_medium_package_50 : (55, 55)
# 955 : dm_Warmsen_Saturday_31603-08_scenario_medium_others_50 : (145, 145)
# 956 : dm_Warmsen_Saturday_31603-08_scenario_medium_all_50 : (291, 291)
# 957 : dm_Warmsen_Saturday_31603-08_scenario_high_letter_50 : (290, 290)
# 958 : dm_Warmsen_Saturday_31603-08_scenario_high_package_50 : (81, 81)
# 959 : dm_Warmsen_Saturday_31603-08_scenario_high_others_50 : (186, 186)
# 960 : dm_Warmsen_Saturday_31603-08_scenario_high_all_50 : (328, 328)
# 961 : dm_Warmsen_Saturday_31606-11_scenario_low_letter_50 : (160, 160)
# 962 : dm_Warmsen_Saturday_31606-11_scenario_low_package_50 : (29, 29)
# 963 : dm_Warmsen_Saturday_31606-11_scenario_low_others_50 : (90, 90)
# 964 : dm_Warmsen_Saturday_31606-11_scenario_low_all_50 : (210, 210)
# 965 : dm_Warmsen_Saturday_31606-11_scenario_medium_letter_50 : (227, 227)
# 966 : dm_Warmsen_Saturday_31606-11_scenario_medium_package_50 : (58, 58)
# 967 : dm_Warmsen_Saturday_31606-11_scenario_medium_others_50 : (168, 168)
# 968 : dm_Warmsen_Saturday_31606-11_scenario_medium_all_50 : (287, 287)
# 969 : dm_Warmsen_Saturday_31606-11_scenario_high_letter_50 : (262, 262)
# 970 : dm_Warmsen_Saturday_31606-11_scenario_high_package_50 : (77, 77)
# 971 : dm_Warmsen_Saturday_31606-11_scenario_high_others_50 : (198, 198)
# 972 : dm_Warmsen_Saturday_31606-11_scenario_high_all_50 : (303, 303)
# 973 : dm_Warmsen_Saturday_31606-14_scenario_low_letter_50 : (140, 140)
# 974 : dm_Warmsen_Saturday_31606-14_scenario_low_package_50 : (31, 31)
# 975 : dm_Warmsen_Saturday_31606-14_scenario_low_others_50 : (84, 84)
# 976 : dm_Warmsen_Saturday_31606-14_scenario_low_all_50 : (188, 188)
# 977 : dm_Warmsen_Saturday_31606-14_scenario_medium_letter_50 : (204, 204)
# 978 : dm_Warmsen_Saturday_31606-14_scenario_medium_package_50 : (60, 60)
# 979 : dm_Warmsen_Saturday_31606-14_scenario_medium_others_50 : (147, 147)
# 980 : dm_Warmsen_Saturday_31606-14_scenario_medium_all_50 : (251, 251)
# 981 : dm_Warmsen_Saturday_31606-14_scenario_high_letter_50 : (244, 244)
# 982 : dm_Warmsen_Saturday_31606-14_scenario_high_package_50 : (66, 66)
# 983 : dm_Warmsen_Saturday_31606-14_scenario_high_others_50 : (169, 169)
# 984 : dm_Warmsen_Saturday_31606-14_scenario_high_all_50 : (269, 269)
# 985 : dm_Warmsen_Saturday_31606-13_scenario_low_letter_50 : (141, 141)
# 986 : dm_Warmsen_Saturday_31606-13_scenario_low_package_50 : (37, 37)
# 987 : dm_Warmsen_Saturday_31606-13_scenario_low_others_50 : (85, 85)
# 988 : dm_Warmsen_Saturday_31606-13_scenario_low_all_50 : (192, 192)
# 989 : dm_Warmsen_Saturday_31606-13_scenario_medium_letter_50 : (205, 205)
# 990 : dm_Warmsen_Saturday_31606-13_scenario_medium_package_50 : (47, 47)
# 991 : dm_Warmsen_Saturday_31606-13_scenario_medium_others_50 : (120, 120)
# 992 : dm_Warmsen_Saturday_31606-13_scenario_medium_all_50 : (233, 233)
# 993 : dm_Warmsen_Saturday_31606-13_scenario_high_letter_50 : (231, 231)
# 994 : dm_Warmsen_Saturday_31606-13_scenario_high_package_50 : (72, 72)
# 995 : dm_Warmsen_Saturday_31606-13_scenario_high_others_50 : (175, 175)
# 996 : dm_Warmsen_Saturday_31606-13_scenario_high_all_50 : (269, 269)
# 997 : dm_Warmsen_Saturday_31600-04_scenario_low_letter_50 : (105, 105)
# 998 : dm_Warmsen_Saturday_31600-04_scenario_low_package_50 : (28, 28)
# 999 : dm_Warmsen_Saturday_31600-04_scenario_low_others_50 : (65, 65)
# 1000 : dm_Warmsen_Saturday_31600-04_scenario_low_all_50 : (154, 154)
# 1001 : dm_Warmsen_Saturday_31600-04_scenario_medium_letter_50 : (173, 173)
# 1002 : dm_Warmsen_Saturday_31600-04_scenario_medium_package_50 : (41, 41)
# 1003 : dm_Warmsen_Saturday_31600-04_scenario_medium_others_50 : (129, 129)
# 1004 : dm_Warmsen_Saturday_31600-04_scenario_medium_all_50 : (223, 223)
# 1005 : dm_Warmsen_Saturday_31600-04_scenario_high_letter_50 : (208, 208)
# 1006 : dm_Warmsen_Saturday_31600-04_scenario_high_package_50 : (60, 60)
# 1007 : dm_Warmsen_Saturday_31600-04_scenario_high_others_50 : (164, 164)
# 1008 : dm_Warmsen_Saturday_31600-04_scenario_high_all_50 : (248, 248)
# CPU times: user 1min 10s, sys: 8.31 s, total: 1min 19s
# Wall time: 1min 43s

# %%
# result_region

name = 'warmsen_instances'

pickle.dump(result_region, open('/content/drive/Shareddrives/Private Unlimited Drive #1/DDS/Analytics Project/Coding/Results' + '/' + "%s.p"%name, "wb"))

# %%
warmze_instances= pickle.load(open("/content/drive/Shareddrives/Private Unlimited Drive #1/DDS/Analytics Project/Coding/Results/warmsen_instances.p", "rb"))

# %%
warmze_instances.keys()
# Out:
# dict_keys(['Tuesday', 'Thursday', 'Friday', 'Wednesday', 'Monday', 'Saturday'])

# %%
warmze_instances['Saturday'].keys()
# Out:
# dict_keys(['31603-06', '31600-01', '31606-12', '31600-02', '31604-09', '31603-07', '31604-10', '31600-03', '31603-05', '31603-08', '31606-11', '31606-14', '31606-13', '31600-04'])

# %%
warmze_instances['Saturday']['31603-06'].keys()
# Out:
# dict_keys(['letter_low', 'package_low', 'others_low', 'all_low', 'letter_medium', 'package_medium', 'others_medium', 'all_medium', 'letter_high', 'package_high', 'others_high', 'all_high'])

# %%
warmze_instances['Saturday']['31603-06']['all_high'].keys()
# Out:
# dict_keys(['dm', 'map'])

# %%
warmze_instances['Saturday']['31603-06']['all_high']['dm']
# Out:
# array([[   0.  , 5879.32, 4906.21, ..., 6145.72, 6257.77, 6246.6 ],
#        [5893.75,    0.  , 1388.68, ..., 1615.98, 1728.03, 1716.86],
#        [4915.2 , 1356.05,    0.  , ..., 1733.57, 1845.62, 1834.45],
#        ...,
#        [6153.22, 1634.76, 1764.21, ...,    0.  ,  112.05,  123.22],
#        [6265.27, 1746.81, 1876.26, ...,  112.05,    0.  ,  235.27],
#        [6254.1 , 1735.64, 1865.09, ...,  123.22,  235.27,    0.  ]])

# %%
# %%time

# original distance matrix

ori_region_dict = ori_generate_distance_matrix_map(region_name = 'Warmsen', save_loc = '/content/drive/Shareddrives/Private Unlimited Drive #1/DDS/Analytics Project/Coding')
# Out:
# /content/drive/Shareddrives/Private Unlimited Drive #1/DDS/Analytics Project/Coding/Warmsen_original
# dir_region doesnt exist
# 1 : 31606-14 : 311
# 2 : 31600-01 : 427
# 3 : 31606-13 : 306
# 4 : 31600-04 : 293
# 5 : 31600-02 : 417
# 6 : 31606-11 : 349
# 7 : 31603-08 : 360
# 8 : 31603-05 : 376
# 9 : 31603-06 : 424
# 10 : 31604-09 : 405
# 11 : 31604-10 : 380
# 12 : 31606-12 : 420
# 13 : 31600-03 : 372
# 14 : 31603-07 : 397
# CPU times: user 1.22 s, sys: 102 ms, total: 1.32 s
# Wall time: 1.65 s

# %%
ori_region_dict.keys()
# Out:
# dict_keys(['31606-14', '31600-01', '31606-13', '31600-04', '31600-02', '31606-11', '31603-08', '31603-05', '31603-06', '31604-09', '31604-10', '31606-12', '31600-03', '31603-07'])

# %%
ori_region_dict['31606-14'].keys()
# Out:
# dict_keys(['dm', 'map'])

# %%
# original region

name = 'warmsen_original'

pickle.dump(ori_region_dict, open('/content/drive/Shareddrives/Private Unlimited Drive #1/DDS/Analytics Project/Coding/Results' + '/' + "%s.p"%name, "wb"))

# %%
# ori_region_dict['31606-14']['map']

# %%
# %%time

tes = [[1,2,3],[3,4,5],[9,10,11]]

concord_result_1, concord_result_2 = concord_solver(tes)
# Out:
# CPU times: user 2.5 ms, sys: 1.68 ms, total: 4.18 ms
# Wall time: 4.2 ms

# %%
concord_result_1
# Out:
# [0, 1, 2]

# %%
concord_result_2
# Out:
# 16.0

# %%
# %%time

s1 = lkh("dm_Warmsen_Saturday_31600-01_scenario_high_all.p")
length , tour_section = s1.solve()
